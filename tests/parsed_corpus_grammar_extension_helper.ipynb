# %%
import json
import numpy
import tqdm
import numpy as np

from tr_syntactic_parser.helper import *

# %% [markdown]
# # Noun Suffix Morphemes to CNF

# %%
suffix_classes = json.loads(open("tr_syntactic_parser/grammar/all_suffix_classes.json", encoding="utf-8").read())

# %%
cnf_suff = ""
for org, targ in CNF_TAG_DICT_NOUN_SUFF.items():
    for item in suffix_classes[org]:
        cnf_suff += targ + " -> " + item + "\n"

print(cnf_suff)
# Out:
# POSPRO1 -> m
# POSPRO1 -> üm
# POSPRO1 -> ım
# POSPRO1 -> yım
# POSPRO1 -> i
# POSPRO1 -> um
# POSPRO1 -> yim
# POSPRO1 -> yum
# POSPRO1 -> im
# POSPROPL1 -> yiz
# POSPROPL1 -> yüz
# POSPROPL1 -> ız
# POSPROPL1 -> üz
# POSPROPL1 -> yuz
# POSPROPL1 -> iz
# POSPROPL1 -> yız
# POSPROPL1 -> lım
# POSPROPL1 -> uz
# POSPROPL1 -> k
# POSPRO2 -> sin
# POSPRO2 -> s
# POSPRO2 -> ı
# POSPRO2 -> n
# POSPRO2 -> sun
# POSPRO2 -> sın
# POSPROPL2 -> yin
# POSPROPL2 -> ın
# POSPROPL2 -> nüz
# POSPROPL2 -> siniz
# POSPROPL2 -> niz
# POSPROPL2 -> sınız
# POSPROPL2 -> ı
# POSPROPL2 -> n
# POSPROPL2 -> nız
# POSPROPL2 -> sunuz
# POSPROPL2 -> nuz
# POSPRO3  -> ı
# POSPRO3  -> s
# POSPRO3  -> n
# POSPRONPL3  -> ler
# POSPRONPL3  -> r
# POSPRONPL3  -> lar
# POSPRONPL3  -> l
# POSPRONPL3  -> a

# %% [markdown]
# # Lexicon

# %%
lexicon = json.loads(open("tr_syntactic_parser/grammar/the_lexicon_reversed.json", encoding="utf-8").read())

# %%
POS_CONVERT_DICT = {
    "ADP" : "PP",
    "CCONJ" : "PP",
    "SCONJ" : "pp",
    "VERB" : "VP",
    "NOUN" : "NP",
    "PUNCT" : "PUNC"
}

POS_IMP = {
    "PUNC" : 0,
    "NUM" : 1,
    "VP" : 2,
    "NP" : 3
}

# %%
CNF_lexicon = {}
for key, values in lexicon.items():
    for val in values:
        if key in POS_CONVERT_DICT.keys(): key = POS_CONVERT_DICT[key]
            
        if val in CNF_lexicon.keys():
            if CNF_lexicon[val] in POS_IMP.keys(): cost = POS_IMP[CNF_lexicon[val]]
            else: cost = 100
            
            if key in POS_IMP.keys(): curr_cost = POS_IMP[key]
            else: curr_cost = 99
            if cost > curr_cost: CNF_lexicon[val] = key
        else: 
            CNF_lexicon[val] = key

# %%
with open("tr_syntactic_parser/grammar/the_lexicon.json","w", encoding='utf-8') as f:
    json.dump(CNF_lexicon, f)

print("Lexicon was saved to :", "tr_syntactic_parser/grammar/the_lexicon.json")
# Out:
# Lexicon was saved to : tr_syntactic_parser/grammar/the_lexicon.json

# %%
lex = ""

for key, val in CNF_lexicon.items():
    lex += val + " -> " + key + "\n"

# %% [markdown]
# # Merged Verb Suffixes

# %%
verb_suff_comb = json.loads(open("tr_syntactic_parser/grammar/combined_verb_suffix_morphemes.json", encoding="utf-8").read())

# %%
suff_comb = ""
for key in verb_suff_comb.keys():
    if "Past" in key: tense = "PAST"
    elif "Prog" in key: tense = "PRE"
    elif "Fut" in key: tense = "FUT"
    else: continue

    if "1" in key: finalkey = tense+"1"
    elif "2" in key: finalkey = tense+"2"
    elif "3" in key: finalkey = tense+"3"
    else: finalkey = tense+"3"

    for suff in verb_suff_comb[key]:
        suff_comb += "\n" + finalkey + " -> " + suff
print(suff_comb)
# Out:
# PAST3 -> ydi
# PAST3 -> tı
# PAST3 -> du
# PAST3 -> tu
# PAST3 -> ydı
# PAST3 -> dü
# PAST3 -> tü
# PAST3 -> ydu
# PAST3 -> dı
# PAST3 -> ydü
# PAST3 -> di
# PAST3 -> ti
# PAST3 -> medi
# PAST3 -> madı
# PRE1 -> iyor
# PRE1 -> ıyor
# PRE1 -> yor
# FUT1 -> eceğim
# PAST1 -> dım
# PAST1 -> dum
# PAST1 -> dim
# PAST1 -> tım
# PAST1 -> dük
# PAST1 -> dık
# PAST1 -> dik
# FUT3 -> yecek
# PAST3 -> emediler
# FUT3 -> ecektir
# FUT1 -> meyeceğiz
# FUT3 -> meyecek
# FUT3 -> mayacak
# PRE1 -> mıyorlar
# PRE1 -> miyor
# PAST3 -> tiler
# PAST3 -> dılar
# PAST3 -> rdı
# FUT3 -> meyecekler
# PRE2 -> maktadır
# PAST3 -> mişti
# PAST3 -> mıştı
# PRE2 -> mekte
# PAST2 -> din
# PAST1 -> iyordu
# PRE1 -> ıyorum
# PAST2 -> dunuz
# PRE1 -> yorlar
# PRE1 -> ıyorlar
# PRE1 -> ıyorsun

# %% [markdown]
# # Predefined Rules

# %%
pre_rules = open("tr_syntactic_parser/grammar/tr_cnf_rules.txt", encoding="utf-8").read()

# %%
lines = pre_rules + suff_comb + cnf_suff + lex
print(lines)
# Out:
# ###### PAST TENSE ######
# ########################
# # Pronoun, Verb+past
# S -> PRO1 VPPAST1
# S -> PRO2 VPPAST2
# S -> PRO3 VPPAST3
#
# # NounPhrase, Verb+past
# S -> NP VPPAST1
# S -> NP VPPAST2
# S -> NP VPPAST3
#
# # PronounClause(Pronoun + NounPhrase), Verb+past
# S -> PRONOUNCLAUSE1 VPPAST1
# S -> PRONOUNCLAUSE2 VPPAST2
# S -> PRONOUNCLAUSE3 VPPAST3
#
# VPPAST1 -> VP PAST1
# VPPAST2 -> VP PAST2
# VPPAST3 -> VP PAST3
#
# ###### PRESENT TENSE ######
# ###########################
# # Pronoun, Verb+present
# S -> PRO1 VPPRE1
# S -> PRO2 VPPRE2
# S -> PRO3 VPPRE3
#
# # NounPhrase, Verb+present
# S -> NP VPPRE1
# S -> NP VPPRE2
# S -> NP VPPRE3
#
# # PronounClause(Pronoun + NounPhrase), Verb+present
# S -> PRONOUNCLAUSE1 VPPRE1
# S -> PRONOUNCLAUSE2 VPPRE2
# S -> PRONOUNCLAUSE3 VPPRE3
#
# VPPRE1 -> VP PRE1
# VPPRE2 -> VP PRE2
# VPPRE3 -> VP PRE3
#
# ###### FUTURE TENSE ######
# ##########################
# # Pronoun, Verb+future
# S -> PRO1 VPFUT1
# S -> PRO2 VPFUT2
# S -> PRO3 VPFUT3
#
# # NounPhrase, Verb+future
# S -> NP VPFUT1
# S -> NP VPFUT2
# S -> NP VPFUT3
#
# # PronounClause(Pronoun + NounPhrase), Verb+future
# S -> PRONOUNCLAUSE1 VPFUT1
# S -> PRONOUNCLAUSE2 VPFUT2
# S -> PRONOUNCLAUSE3 VPFUT3
#
# VPFUT1 -> VP FUT1
# VPFUT2 -> VP FUT2
# VPFUT3 -> VP FUT3
#
# ###### MISC ######
# ##################
# # Pronoun, NounPhrase+Suffix
# S -> PRO1 NP POSPRO1
# S -> PRO2 NP POSPRO2
# S -> PRO3 NP POSPRO3
#
# NP -> NP POSPRO1
# NP -> NP POSPRO2
# NP -> NP POSPRO3
#
# # Pronoun + NounPhrase
# PRONOUNCLAUSE1 -> PRO1 NP
# PRONOUNCLAUSE2 -> PRO2 NP
# PRONOUNCLAUSE3 -> PRO3 NP
#
# S -> NP VP PREPARTICLE
#
# NP -> ADJ NP
# NP -> ADJ NP PL
# NP -> ADJ SING NP
# PLNOUN -> NP PL
# SINGNP -> SING NP
# NP -> SING ADJ NP
# ADJCLAUSE -> ADJ NP
# NP -> NP PL
# NP -> NP NP
# NP -> NP PP
# ADJ -> ADJ ADJ
# VP -> ADV NP VP
# NPVP -> NP VP
# VP -> ADV VP
# VP -> QP VP
# QP -> Q NP
#
# QCLAUSE1 -> Q POSPROPL1
# QCLAUSE2 -> Q POSPROPL2
# QCLAUSE3 -> Q POSPROPL3
#
# Q -> mı
# Q -> mi
# Q -> ne
#
# PRO1 -> ben
# PRO2 -> sen
# PRO3 -> o
# PROPL1 -> biz
# PROPL2 -> siz
# PROPL3 -> onlar
# PAST3 -> ydi
# PAST3 -> tı
# PAST3 -> du
# PAST3 -> tu
# PAST3 -> ydı
# PAST3 -> dü
# PAST3 -> tü
# PAST3 -> ydu
# PAST3 -> dı
# PAST3 -> ydü
# PAST3 -> di
# PAST3 -> ti
# PAST3 -> medi
# PAST3 -> madı
# PRE1 -> iyor
# PRE1 -> ıyor
# PRE1 -> yor
# FUT1 -> eceğim
# PAST1 -> dım
# PAST1 -> dum
# PAST1 -> dim
# PAST1 -> tım
# PAST1 -> dük
# PAST1 -> dık
# PAST1 -> dik
# FUT3 -> yecek
# PAST3 -> emediler
# FUT3 -> ecektir
# FUT1 -> meyeceğiz
# FUT3 -> meyecek
# FUT3 -> mayacak
# PRE1 -> mıyorlar
# PRE1 -> miyor
# PAST3 -> tiler
# PAST3 -> dılar
# PAST3 -> rdı
# FUT3 -> meyecekler
# PRE2 -> maktadır
# PAST3 -> mişti
# PAST3 -> mıştı
# PRE2 -> mekte
# PAST2 -> din
# PAST1 -> iyordu
# PRE1 -> ıyorum
# PAST2 -> dunuz
# PRE1 -> yorlar
# PRE1 -> ıyorlar
# PRE1 -> ıyorsunPOSPRO1 -> m
# POSPRO1 -> üm
# POSPRO1 -> ım
# POSPRO1 -> yım
# POSPRO1 -> i
# POSPRO1 -> um
# POSPRO1 -> yim
# POSPRO1 -> yum
# POSPRO1 -> im
# POSPROPL1 -> yiz
# POSPROPL1 -> yüz
# POSPROPL1 -> ız
# POSPROPL1 -> üz
# POSPROPL1 -> yuz
# POSPROPL1 -> iz
# POSPROPL1 -> yız
# POSPROPL1 -> lım
# POSPROPL1 -> uz
# POSPROPL1 -> k
# POSPRO2 -> sin
# POSPRO2 -> s
# POSPRO2 -> ı
# POSPRO2 -> n
# POSPRO2 -> sun
# POSPRO2 -> sın
# POSPROPL2 -> yin
# POSPROPL2 -> ın
# POSPROPL2 -> nüz
# POSPROPL2 -> siniz
# POSPROPL2 -> niz
# POSPROPL2 -> sınız
# POSPROPL2 -> ı
# POSPROPL2 -> n
# POSPROPL2 -> nız
# POSPROPL2 -> sunuz
# POSPROPL2 -> nuz
# POSPRO3  -> ı
# POSPRO3  -> s
# POSPRO3  -> n
# POSPRONPL3  -> ler
# POSPRONPL3  -> r
# POSPRONPL3  -> lar
# POSPRONPL3  -> l
# POSPRONPL3  -> a
# NP -> 35-uluslu
# NP -> bakiye
# NP -> amerikalı
# NP -> broncs
# NP -> ikmal
# VP -> mahvet
# NP -> istirham
# VP -> yer
# NP -> yıkama
# NP -> üstün
# VP -> dosyala
# VP -> hafta
# NP -> raslantı
# NP -> link
# NP -> 508-puanlık
# NP -> ala
# NP -> pens
# NP -> defter
# NP -> muharebe
# NP -> kürek
# NP -> sonat
# NP -> dedikodu
# NP -> adliye
# NP -> hazırlık
# NUM -> 3.69
# NP -> teknik
# NP -> pompa
# VP -> seç
# NP -> karakteristik
# NP -> dük
# NP -> havaliman
# NP -> kasti
# NP -> anti
# NP -> topaz
# NP -> külfet
# NP -> masum
# VP -> bayi
# VP -> adım
# NP -> gelgit
# NP -> gümrükle
# NP -> evreleme
# NP -> tüvit
# NUM -> 1990
# NP -> söyledi.
# NP -> bonus
# NP -> dün
# NP -> dernek
# NP -> şişe
# NP -> belirtilen
# NP -> 197
# NP -> barınak
# VP -> ek
# NP -> 7.875,
# NP -> şaşkınlık
# NP -> nabız
# NP -> conta
# VP -> güç
# VP -> karar
# NP -> söylerimleyle
# NP -> ateş
# NP -> casusluk
# VP -> rakip
# NP -> kolajen
# NP -> selef
# NP -> parıltı
# VP -> sınır
# NP -> parola
# NP -> aksiyom
# NP -> açım
# NP -> terminal
# NP -> onkogenler
# NP -> kapitone
# VP -> hat
# NP -> kuruş
# NP -> hekim
# NP -> 821
# VP -> üstlen
# NP -> kârın
# NP -> doğum
# NP -> teslim
# NP -> somatostatin
# NP -> karyola
# NP -> uzatma
# NP -> yılbaş
# NP -> müteahhit
# NUM -> 1980
# VP -> zarar
# VP -> dil
# NP -> ideal
# NP -> 1890
# NP -> umar
# NP -> tercüman
# NP -> vaat
# NP -> mahsul
# NP -> filo
# NP -> yağmala
# VP -> destek
# NP -> güneş
# NP -> darma
# NP -> 455
# VP -> alt
# NP -> istila
# NP -> tantana
# NP -> kumaş
# NP -> ihtiva
# NP -> aslan
# NP -> başkaldır
# VP -> taşı
# VP -> kır
# NP -> b
# NP -> anlayış
# NP -> ağır
# NP -> süreçin
# NP -> katalog
# NP -> aleyh
# NP -> 123.5
# NP -> zorlama
# NP -> muğlaklık
# NP -> doktrin
# NP -> dizel
# NP -> lise
# NP -> oyalayıcı
# NP -> mermi
# NP -> bilet
# NP -> 'inc.,
# NP -> 49-uluslu
# NP -> türk
# NP -> yaşan
# VP -> sabit
# NP -> komisyoncu
# NP -> isteksiz
# NP -> oturum
# NP -> 2890
# NP -> gündüz
# NP -> 368
# NP -> radyasyon
# NP -> boykot
# NP -> rota
# NP -> ​​ayarlamak
# NP -> 414
# VP -> ilk
# NP -> kalorifer
# VP -> yol
# NP -> eşdeğerlik
# NP -> franchise
# NP -> kuzen
# NP -> aks
# NUM -> ikinci
# NP -> riyakarlık
# NP -> tecrit
# NP -> ayak
# NP -> makbuz
# NP -> hakaret
# NP -> ikonoklastik
# NP -> kayarak
# NP -> leh
# NP -> kesimhane
# NP -> vaha
# NP -> kılıç
# NP -> eldiven
# NP -> yönerge
# NP -> inç
# NP -> kazı
# NP -> eklenti
# NP -> boğmaca
# NP -> 23-5'lik
# NP -> değişim
# NP -> orman
# NP -> 2653.28
# NP -> teşviki
# NP -> asalet
# NP -> yanlışlık
# NP -> alay
# NP -> gözetle
# NP -> kovalamaca
# NP -> doğruluk
# VP -> öngör
# NUM -> 7.93
# NP -> ons'luk
# NP -> piyasısı
# NP -> uyuştur
# NP -> esinti
# VP -> yaka
# NP -> plastik
# NP -> var.
# NP -> orkestra
# NP -> kontra
# VP -> baba
# VP -> öde
# VP -> koca
# VP -> yüzleş
# NP -> çöp
# NP -> onarım
# NP -> ikame
# VP -> çarp
# NP -> kısas
# NP -> gözalt
# VP -> bil
# NP -> matine
# NP -> göl
# NP -> italyan
# NP -> babaerkil
# NP -> dargınlık
# VP -> kara
# NP -> çamur
# NP -> saygıdeğer
# VP -> doğ
# NP -> alıcılar'
# NP -> domine
# NP -> metal
# NP -> kırılgan
# NP -> akvaryum
# NP -> teveccüh
# NUM -> 43
# NP -> tekamül
# NP -> %70
# NP -> soylu
# VP -> rafine
# NP -> deforme
# NP -> lüks-araba
# NP -> km
# NP -> soğut
# NP -> nohut
# NP -> ingiliz
# VP -> incele
# NP -> dip
# NP -> 7.22
# VP -> şaşır
# NP -> gayrimenkuldeydi
# VP -> alıntı
# NP -> tat
# NP -> mobilya
# NP -> %10.3'ünü
# NP -> ayna
# NP -> inziva
# NP -> çalın
# NP -> salon
# NP -> sempati
# NUM -> 1959
# NP -> bilge
# NP -> kobay
# NP -> bebeklik
# NP -> bina
# NP -> 130.80
# NP -> köylü
# NP -> ince
# NP -> bacak
# VP -> kapat
# NP -> üstünlük
# VP -> sahte
# NP -> seramik
# NP -> jaguar
# NP -> applause
# NP -> diyabetik
# NP -> cin
# NP -> metafor
# NP -> patika
# NP -> kösteklen
# NP -> ifade
# NP -> çağırılan
# NP -> yoğunluk
# NP -> dost
# NP -> davetiye
# NP -> şablon
# NP -> davet
# NP -> fıkra
# NP -> 1190.43
# NP -> keman
# NP -> merdiven
# NP -> genç
# NP -> fabrika
# NP -> ispanyol
# NP -> sistem
# NP -> taze
# NP -> artçı
# NP -> alçı
# NP -> antibiyotik
# VP -> yük
# NP -> manipülatif
# NP -> mayala
# NP -> pohpohla
# NUM -> 7.89
# VP -> ekle
# VP -> göster
# NP -> hiç
# NP -> birik
# NP -> brokerları
# NP -> hüsran
# NP -> akrelik
# NP -> vezin
# NP -> gayrimenkuller
# NP -> sonra
# NP -> leke
# NP -> resesyon
# VP -> kelime
# NP -> basmakalıp
# VP -> gerile
# NP -> göz
# NP -> klinik
# NP -> panama
# NP -> avantacı
# NUM -> 13
# NP -> ekipman
# NUM -> 61
# NP -> izlenim
# NP -> bolluk
# NP -> %20'lik
# NP -> tasarlanmıştır.
# NP -> 120-günlük
# NP -> f
# NP -> ot
# NP -> türbin
# NP -> yassı
# NP -> prospektüs
# NP -> varyasyon
# NP -> anti-tröst
# NP -> antika
# VP -> sok
# NP -> dehşet
# NP -> analizci
# NP -> anahtar
# VP -> garantile
# NP -> özelleştirme
# NP -> burbonudur
# VP -> bağlı
# NP -> dayak
# NP -> kakao
# NP -> simsarlık
# NP -> yoksunluk
# NP -> bulaş
# NP -> gerçeklik
# NP -> 4440
# NP -> yıprat
# NP -> milliyetçi
# NP -> köşe
# NP -> öncül
# NP -> mercek
# NP -> ödeme
# NP -> platform
# NP -> fiyat/kazanç
# NP -> tahammül
# VP -> ilerle
# NP -> gayri
# NP -> dansçı
# NP -> eyalet
# NP -> 18.125
# NP -> alamet
# NP -> dudak
# VP -> sırala
# NP -> çimenlik
# VP -> oluş
# NP -> şimdiye
# VP -> mal
# NP -> 445.23
# NP -> 382
# NP -> protokol
# NP -> yaşam
# NP -> iyi.
# NP -> eziyet
# NP -> le
# NP -> diz
# VP -> aşama
# NP -> damga
# NP -> saygı
# NP -> un
# NP -> şömine
# NP -> feda
# NP -> rüşvet
# NP -> temas
# NP -> bağlam(lar)ında
# NP -> bağımsız
# NP -> odak
# NP -> moda
# NP -> alet
# NP -> gelen
# NP -> kumarhane
# NP -> antitröst
# NP -> vızıltı
# NP -> ,10:30-13:30
# NP -> tahmini
# NP -> teşvik
# NP -> hücum
# NP -> mercan
# NP -> ideolog
# NP -> implantasyon
# NP -> bunalım
# NP -> öğretmen
# NP -> devrimci
# NP -> oynaklık
# NP -> %6.25
# NP -> meraklı
# NP -> gözde
# NP -> iletken
# NP -> cila
# NP -> şerefiye
# NP -> deri
# NP -> gözdağ
# NP -> yumruk
# VP -> kastet
# NP -> elektrik
# NP -> benzerlik
# NP -> site
# NP -> ümit
# NP -> ekran
# NP -> beylik
# NP -> hayvan
# VP -> ön
# NP -> saye
# NP -> 3.çeyreğinde
# NP -> indeks
# NP -> füzyon
# NP -> lisanslama
# VP -> yoğun
# NP -> ambalaj
# VP -> yar
# NP -> örüntü
# NP -> müslüman
# NP -> kapama
# VP -> çağrı
# NP -> reklamverenlerle
# NP -> ehliyet
# NP -> malpraktis
# NP -> 2.659.22
# NP -> konserve
# NP -> işbirliğiden
# NP -> kârına
# NP -> alışkan
# NP -> dava
# NP -> olasılık
# NP -> broker-bayi
# NP -> adaylık
# VP -> diktatör
# NUM -> 47
# NP -> eksi
# NP -> taahhüt
# NP -> diyor.
# NP -> 130.73
# NP -> yumurta
# NP -> borsacı
# NP -> franchiselarınız
# NP -> balistik
# NP -> amortisman
# NP -> çoğalıyor.
# NP -> 130.36
# NP -> kopya
# NP -> tutanak
# NP -> aracı-bayi
# NP -> tank
# NP -> sanayici
# NP -> hareketsizlik
# NP -> 1975
# NP -> saçık
# NP -> makineli
# NP -> 1978
# NP -> lanet
# NP -> pasaport
# NP -> genel
# NP -> kurultay
# NP -> sigortalı
# NP -> (mpi)'dır
# VP -> birleş
# NP -> masaj
# NP -> erkek-verimli
# NP -> asıl
# NP -> havayol
# NP -> harici
# NP -> jumbos
# NUM -> 7.25
# NP -> kayalık
# NP -> abd
# NP -> %40'ından
# NP -> tedirgin
# NP -> yönetmenlik
# NP -> talip
# NP -> içerik
# NP -> yıldönüm
# NP -> 131.64'de
# VP -> değ
# NP -> kıpırtı
# NP -> gazetecilik
# NP -> hakim
# NP -> %52'sini
# NP -> 74.125
# NP -> perşembe
# VP -> genişlet
# NP -> ucube
# NP -> partner
# NP -> teknisyen
# NP -> 00.01
# VP -> patla
# VP -> kurul
# NP -> nakliye
# NUM -> 22
# NP -> itfaiyeci
# NP -> sağlama
# NP -> product
# NP -> teşvikinin
# NP -> müdafi
# VP -> yatış
# NP -> anlam
# NP -> birmingham
# NP -> yayılma
# VP -> süreç
# NP -> lokanta
# NP -> kısıntı
# NP -> türban
# NP -> ekspres
# NP -> ihraççıları
# NP -> bitim
# NP -> %70'inden
# NP -> verecek
# NP -> liyakat
# NP -> gözbebeğimiz
# VP -> sebep
# VP -> orta
# NP -> bataklık
# NP -> sertifikasyon
# VP -> iyimser
# VP -> emir
# NP -> konteyner
# NP -> hacmi-testi
# NP -> tahsil
# NP -> ayçiçek
# NP -> kardeş
# VP -> açık
# NP -> dank
# NP -> gecikme
# NP -> küpe
# NP -> itiraf
# NP -> pekiş
# NP -> hasır
# NP -> anti-damping
# NP -> kovboy
# NP -> aksilik
# NP -> boğa
# NP -> oda
# VP -> boğ
# NP -> kulüp
# NP -> makinelerininin
# NP -> alım-satıma
# NP -> katılan
# NP -> akis
# NP -> ilahiyatçı
# NP -> federasyon
# NP -> düzenleme
# NP -> hayal
# NP -> diğer
# VP -> performans
# VP -> gerileme
# NP -> atasöz
# NP -> manşet
# NP -> çelik
# NUM -> 48
# NP -> kürkçü
# NP -> ihmal
# NP -> ittifak
# NP -> duruşma
# NP -> hacim
# NP -> hurdalık
# NP -> aylık
# NP -> inkar
# NP -> rıza
# NP -> basınç
# NP -> müphem
# NP -> ironik
# VP -> miktar
# NP -> savcılık
# NP -> keçi
# NUM -> 2645.08
# NUM -> 54
# NP -> kozmetik
# NP -> icracı
# NP -> kargo
# NP -> moral
# NP -> kaygı
# NP -> ünite
# NP -> ayrımcılığı
# NP -> food
# NP -> kılıf
# NP -> monte
# NP -> mükellef
# NP -> yazılı
# VP -> konuş
# NP -> rehin
# VP -> komisyon
# NP -> mesai
# NP -> gıda
# NP -> 20-hisseli
# VP -> doğru
# NP -> maç
# NP -> fuar
# NP -> soğukluk
# VP -> yavaşla
# NP -> zorluk
# NP -> müracaat
# NP -> turizm
# NUM -> 1\/8
# NP -> peşinat
# NP -> imtiyaz
# NP -> eğer
# NP -> ant
# NP -> çip
# VP -> pazarla
# NP -> psikanaliz
# NP -> ball
# NP -> giyim
# NP -> anapara
# VP -> yetiştir
# NP -> çekiş
# NP -> işgücü
# NP -> lisanslamayla
# NP -> zihin
# NP -> belirti
# NP -> akor
# NP -> lübnanlı
# NP -> global
# NP -> depo
# NP -> denizci
# NP -> teamül
# NP -> maymun
# NP -> karpit
# NP -> 5.651
# NP -> darbe-kuvveti
# NP -> flört
# NP -> sukunet
# NP -> kepenk
# NP -> poz
# NP -> varis
# NP -> tek-a
# NP -> and
# VP -> yatak
# NP -> kışın
# NP -> rampa
# NP -> ayı
# NP -> sayfa
# NP -> kararname
# NP -> propogandayı
# NP -> ihracat
# NP -> 16:30
# NP -> buzdolaplarını
# NP -> rating
# VP -> sev
# NP -> özür
# NP -> söyleşi
# NP -> saldırma
# NP -> emperyal
# NP -> hurda
# NP -> psilyumu
# NP -> yeryüz
# NP -> 1960'da
# NP -> garip
# NP -> evrak
# NP -> biriktir
# NP -> lastik
# NP -> ananas
# NP -> eleştiri
# NP -> içindekiler
# NP -> lider
# NP -> ergenlik
# NP -> eğitmen
# NP -> acentelik
# NP -> başkanlık
# NP -> insanoğlu
# NP -> yurt
# VP -> uç
# NP -> alım-satımına
# NP -> %30
# NP -> dinlen
# VP -> al
# NP -> pachinko
# NP -> ihtimal
# NP -> toynak
# VP -> önemse
# NP -> yapılandırma
# NP -> hissedarlıklara
# NP -> egemenlik
# NP -> konsorsiyum
# NP -> dr.
# NP -> gittikça
# VP -> sonlan
# NP -> proaktif
# VP -> girişimcilik
# NP -> rahibe
# VP -> temizle
# NP -> sırt
# NP -> amir
# NP -> muhafaza
# NP -> dayanıklılık
# NP -> toy
# NP -> yanlılık
# NP -> işbirliği
# NP -> katılımcı
# VP -> kategori
# NP -> %15'ini
# NP -> imal
# NP -> sürüklen
# NP -> hücre
# NP -> arzet
# NP -> canlılık
# NP -> yelpaze
# NUM -> 6
# VP -> giy
# NP -> %51'ini
# NP -> öngören/savunan
# NP -> çıkarma
# NP -> are
# NP -> tahsilat
# NP -> 936
# NP -> 1730
# NP -> gezin
# VP -> yerleştir
# NP -> saygısız
# VP -> çılgınlık
# NP -> disiplin
# NP -> faz
# VP -> başkan
# NP -> ispat
# NP -> ciddi
# VP -> öte
# NP -> büyüklük
# NP -> tüzük
# NP -> üniversite
# NP -> ifa
# NP -> ithalat-ihracat
# NUM -> 1.6055
# VP -> top
# NP -> jogging
# VP -> kay
# NP -> müzayede
# NP -> esna
# NP -> kardiyovasküler
# NP -> blok
# NP -> çit
# NP -> volatilite
# NP -> suitindeki
# NP -> şahit
# NP -> tadil
# NP -> tartma
# NP -> oksit
# NP -> eylemci
# VP -> yanlış
# VP -> danış
# NP -> batak
# NP -> bilim
# NP -> nadas
# NUM -> 1997
# VP -> hoşlan
# NP -> itaat
# VP -> çiz
# NP -> konjonktür
# NP -> tüketim
# NP -> muhafazakar
# NP -> ortadirek
# VP -> görünüm
# NP -> yarışmacı
# VP -> yaklaş
# NP -> tuğla
# NP -> işlev
# NP -> bilgilen
# NP -> dolaşım
# NP -> ekmek
# NP -> bir-paya-300
# VP -> baskıla
# VP -> çiftçi
# NP -> delegasyon
# NP -> yurtdışında
# NP -> psilyum
# NP -> bekleme
# NP -> çete
# NP -> tecrübe
# NUM -> 1\/2
# NP -> depresyon
# NP -> pamuk
# NP -> misyon
# NP -> yapım
# VP -> ödül
# NP -> endüstri
# VP -> çevir
# NP -> debelen
# NP -> olgunluk
# NP -> tatilci
# NP -> itele
# NP -> kelebek
# VP -> özel
# NP -> opera
# NP -> yıkı
# VP -> başarı
# NP -> şaşkın
# NP -> dar
# NP -> votka
# NP -> grip
# VP -> düzen
# VP -> yöntem
# NP -> serbestleş
# NP -> armadillo
# NP -> cevher
# NP -> kral
# VP -> tırman
# NP -> dans
# NP -> konser
# VP -> öl
# NP -> ayrıldı?
# NP -> %12'lik
# NP -> uyarlama
# NP -> üstelik
# NP -> mücadele
# NP -> yurtdışı
# NP -> gazi
# NUM -> 2005
# VP -> uğraş
# NP -> 84
# NP -> özsermaye
# NP -> buğday
# NP -> evet
# NP -> kote
# NP -> oy
# VP -> pazarlan
# NP -> birçoğuyle
# NP -> tereyağ
# NP -> endeksle
# VP -> karmaşık
# NP -> etiket
# NP -> 2638.73
# NP -> boya
# NP -> aktris
# NP -> bozgun
# VP -> sayfala
# NP -> temel
# NP -> kârlar
# NP -> ​​otomobil
# NP -> tişört
# NP -> telekomünikasyon
# NP -> motor
# NP -> baskın
# NP -> 30-pay
# VP -> tetik
# NP -> kanım
# NP -> seleksiyon
# NP -> şizofreni
# NP -> broşür
# NP -> d'alene
# NP -> 470'den
# NP -> fiber
# NP -> hâlihazır
# NP -> dayat
# NP -> kuşatma
# NP -> 60-gün
# NP -> empoze
# NP -> ilham
# NP -> 378.07
# VP -> iş
# NP -> hırpala
# NP -> tamir
# NP -> dert
# NP -> 10.13
# NP -> klorin
# NP -> felsefik
# NP -> karnaval
# NP -> master
# NP -> mola
# NP -> deyiş
# NP -> pediyatrik
# NP -> boru
# NP -> ficus
# NP -> geçme
# NP -> akçe
# VP -> sürükle
# NP -> silikon
# NP -> mülayim
# NUM -> 1991
# NP -> siper
# NP -> intihar
# NP -> dikkat
# NP -> a.m
# NP -> özellik
# NP -> kâr
# VP -> çatla
# VP -> üretici
# NP -> beden
# NP -> kylix
# NP -> fransız
# NP -> törpü
# NP -> 10.98
# NP -> sonbahar
# NP -> kaçık
# VP -> kuşku
# NP -> 4.çeyrekteki
# NP -> büyücülük
# NP -> gayrimenkule
# NUM -> 4
# NP -> enflasyon
# NP -> kaplama
# NP -> aksama
# NP -> punt
# NP -> uzmanlaş
# VP -> uğrat
# NP -> rapor
# NP -> tuz
# NP -> ''dedi
# NP -> polemik
# NP -> hayret
# NP -> taktik
# NP -> podyum
# NP -> içerdekilerin
# NP -> yatıştır
# VP -> kapasite
# NP -> şövalye
# NP -> cevap
# NP -> c
# NP -> avantaj
# NP -> stopaj
# NUM -> 1977
# NP -> arayış
# NP -> var:
# VP -> kent
# NP -> klasik
# VP -> satıl
# NP -> 3m'in
# NP -> bezybol
# NP -> dogs
# VP -> nokta
# NUM -> 289
# NP -> alkışlama
# NP -> pekin
# NP -> gasp
# VP -> cins
# VP -> koşul
# NP -> üyelik
# NP -> 1739.3
# NP -> merci
# NP -> davalı
# NP -> eczane
# NP -> kıyı
# NP -> gösteri
# NP -> kuzeybatı
# VP -> kanıtla
# VP -> büyük
# NP -> pizza
# NP -> %7.20
# NP -> 132,8
# VP -> acı
# NP -> şema
# VP -> harca
# NP -> taksi
# NP -> kanat
# NP -> form
# NP -> ayin
# NUM -> üç
# NP -> blues
# NP -> gala
# NP -> bürokrasi
# NP -> kanal
# NP -> öğreneceğim.
# NP -> karşıt
# NUM -> 1972
# NUM -> 7.92
# NP -> topçu
# NP -> eşitsizlik
# NP -> retinoblastoma
# NP -> menfaat
# NP -> şükür
# NP -> inşaa
# VP -> teklif
# NP -> palamedes
# NP -> madalya
# NP -> kek
# NP -> otobüs
# NP -> zift
# NP -> aerobik
# NP -> yemek
# VP -> felaket
# NP -> fırsatçı
# VP -> yetkili
# NP -> eser
# NP -> ömür
# NP -> ayrıntılrı
# NP -> sarsıntı
# NP -> ambargo
# NP -> %8.17'lik
# VP -> dur
# NP -> saldırganları
# NP -> kornea
# NP -> erken
# NP -> %9.9'luk
# NP -> özkaynak
# NP -> dizginle
# NP -> 951
# VP -> normal
# NP -> krem
# NP -> dün`''
# NP -> dürüst
# NP -> yaşlan
# NP -> kurban
# NP -> albeni
# NP -> nevi
# NP -> hafif
# NP -> 100-paylık
# NP -> uğrak
# NP -> elitistleri
# NP -> çekilme
# NP -> bakımev
# NP -> %50
# NP -> 7/8'ye
# NP -> şikâyet
# NP -> asker
# NP -> cumhurbaşkan
# NP -> büyükbaba
# NP -> kanama
# NP -> puan
# VP -> çoğal
# NP -> süt
# NP -> sefalet
# NP -> kart
# VP -> asistan
# NP -> realite
# NP -> bağnaz
# NP -> kayak
# NP -> tarikat
# NP -> bide
# NP -> sakınca
# NP -> mil
# NP -> nişan
# NP -> rejim
# VP -> tedarikçi
# NUM -> 1.7
# NP -> talimat
# VP -> yaygınlaş
# NUM -> 27.5
# NP -> gsmh
# NP -> vasıta
# VP -> yara
# VP -> yık
# NP -> 0.0015
# NP -> 3/4'den
# NP -> sözleş
# NP -> itibar
# NP -> ruhsat
# NP -> öncü
# NP -> zig-zag
# NP -> dolgu
# NP -> çukur
# NP -> siyaset
# NP -> hububat
# NP -> işbaş
# NP -> tonlamam
# NP -> tezgah
# NP -> potansiyel
# NP -> ,devlet
# NP -> feminist
# VP -> eğ
# NP -> 186
# NP -> vuruş''
# NUM -> 300
# NP -> tarihçi
# VP -> kap
# VP -> abart
# NP -> 209.000'lik
# NP -> lirizm
# NP -> lokma
# VP -> otomobil
# NP -> hırs
# NP -> hizmetçi
# NP -> istatiksel
# NP -> alsatçılar
# NP -> artist
# NP -> lüks
# VP -> ebeveyn
# NP -> kupon
# NP -> kamp
# NP -> limited
# NP -> hobi
# NP -> sulh
# NP -> ediyor:
# NP -> minibüs
# NP -> alsatlarından
# NP -> eleştirmen
# NP -> köpek
# VP -> sözleşme
# NP -> charter
# NP -> troleybüs
# NP -> irrasyonel
# VP -> gözük
# VP -> müşavir
# NP -> kaygılan
# NP -> dekor
# VP -> um
# NP -> akademisyen
# NP -> perestroikanın
# NP -> ihsan
# VP -> ıskala
# NP -> demokrat
# NP -> durakla
# VP -> ulaş
# NP -> aktör
# NP -> %8-10
# NP -> şarkıcı
# NP -> sız
# NP -> solucan
# NP -> sevk
# NP -> ısı
# NP -> mükellefiyet
# NP -> hasar
# NP -> ceo
# NUM -> 170
# VP -> rekabetçi
# NP -> telif
# NP -> ortada
# NP -> komşu
# NP -> statü
# NP -> tescil
# NP -> koyun
# NP -> general
# NP -> heyecan
# NP -> yasama
# NP -> kabin
# NP -> açıklık
# VP -> bar
# NP -> cilveleş
# NP -> işletim
# NP -> gidişat
# NP -> 215.86
# NUM -> 40
# NP -> önder
# VP -> eleştir
# VP -> atlat
# VP -> değer
# NP -> kürsü
# VP -> tep
# VP -> halk
# NP -> gecelik
# VP -> zorun
# NP -> inch
# NP -> üreme
# NP -> sansasyon
# NP -> ıskonto
# NP -> roket
# VP -> frank
# NP -> jenerik
# NP -> fiş
# VP -> yaz
# NP -> takviye
# NP -> langırt
# NP -> şikayetçi
# NP -> aynısı
# NP -> kanaat
# NP -> saksı
# NP -> psikanalist
# NP -> fil
# NP -> di
# VP -> sürpriz
# NP -> 4348
# NP -> akım
# NP -> yüklenim
# NP -> 2.çeyrekte
# NP -> hemoroit
# NP -> dünya
# VP -> sefer
# NP -> çıkış
# VP -> düzey
# NP -> 19/32
# NP -> denek
# NP -> konsolidasyon
# VP -> sürdür
# NP -> kredi
# NP -> kalem
# VP -> zorunlu
# VP -> iste
# NP -> alım-satımcıların
# NP -> erkek
# NP -> sıkışık
# NP -> pist
# NP -> etkin
# NP -> solist
# NP -> petrol-hizmeti
# NP -> 11/2
# NP -> 4.çeyrekte
# NP -> mezarlık
# NP -> tahta
# NP -> genelle
# VP -> ülke
# NP -> sürerlik
# NP -> stok
# NP -> yazıl
# NP -> mikro
# VP -> öğren
# NP -> pazartesi
# NP -> 5.86
# NP -> birleşik
# NP -> delta
# NP -> lazer
# NP -> başkaldırı
# NP -> eşik
# NP -> %8'inden
# NP -> fotoğrafçı
# NP -> 1950
# NP -> sabah
# NP -> handikap
# NP -> kriptografisi
# NP -> vazo
# NP -> edilmememesi
# NP -> bilgilendirme
# NP -> mesaj
# NP -> tedarik
# NP -> tane
# NP -> 215.35'de
# NP -> nbc
# NP -> rehber
# NP -> elmas
# NP -> bilek
# NP -> taşikardi
# NP -> deprem
# NP -> şöhret
# VP -> karşıla
# NP -> dram
# NP -> eğim
# NP -> jour
# NP -> entelektüel
# NP -> icra
# NP -> fizik
# NP -> sedir
# NP -> itimatname
# VP -> betimle
# VP -> kayyum
# NUM -> 4.3
# VP -> gez
# VP -> yorumcu
# NP -> süspansiyon
# NP -> fasulye
# NP -> karartı
# NP -> fast-food
# NP -> ağustos
# NP -> dikim
# NP -> yenilikçi
# VP -> hatıra
# NP -> okuyucu
# NP -> konik
# NP -> brifing
# NP -> marka
# VP -> hükmet
# NP -> öğrenci
# NP -> iyidir.
# VP -> bölün
# NP -> pasta
# NP -> sicilya
# VP -> uyarla
# NP -> kraliçe
# NUM -> 1906
# NP -> buz
# NP -> günlük
# NP -> alternatif
# NP -> mini-bileşen
# NP -> mülakat
# VP -> sakla
# NP -> 1/4-1/2
# VP -> öfke
# NP -> sokak
# NP -> mimar
# NP -> teleferik
# NP -> aleyhtar
# NP -> yumuşama
# VP -> seviye
# NP -> paladyum
# NP -> avcı
# NP -> rehine
# VP -> eğilim
# NP -> nane
# VP -> segment
# VP -> kaz
# VP -> yönlendir
# NP -> edepsiz
# NP -> altı-maçlık
# NP -> üç-a
# NP -> şekilde.
# NP -> ustabaş
# NP -> reseptör
# NP -> tazminat
# VP -> dolu
# NP -> dosya
# NP -> yemin
# NP -> pazarlık
# NP -> soya
# VP -> yararlan
# NP -> pound
# NP -> kooperatif
# NUM -> 1.75
# NP -> megabillion
# NP -> balta
# NP -> milyoner
# NP -> meyve
# NP -> jigolo
# NP -> 131.34'de
# NUM -> 85
# NP -> eşya
# NP -> skandal
# NP -> suç
# NP -> gözetmen
# VP -> kur
# NP -> idam
# NP -> teknoloji
# NUM -> 2643.65
# NP -> v.
# NP -> bileşen
# NP -> %3.6'sını
# NP -> tv
# NP -> düşman
# NP -> rönesans
# VP -> rekor
# NP -> protestocu
# NP -> korumacılık
# NP -> teklifçileri
# NP -> materyal
# VP -> haber
# NP -> montaj
# NP -> buzdolabı
# NP -> elektro
# NP -> komutan
# NP -> bayrak
# NP -> %2.52'lik
# NP -> katılmadı.
# NP -> dramatize
# VP -> ata
# NP -> soyad
# NP -> ilga
# NP -> nahoş
# NP -> kıvılcım
# VP -> devret
# NP -> genişmeme
# NP -> oluşturdu.
# NP -> ödün
# NP -> prodüktör
# VP -> gerçek
# VP -> faktör
# NP -> tatminkar
# VP -> gerçekleş
# VP -> dahil
# NP -> 7580
# NP -> bulak
# NP -> %7.8
# VP -> çözül
# NP -> sap
# NP -> tirat
# NP -> revaç
# NP -> saygısızlık
# NP -> çizgi
# NP -> faydalanma
# NP -> leasing
# NP -> buyout
# NP -> ilave
# NUM -> 81
# NP -> abartma
# NP -> 3363949
# NP -> jonron
# NP -> nüfus-kontrolü
# NP -> sendika
# NP -> idare
# NP -> amca
# NP -> ozon
# NP -> parmaklık
# NP -> donanma
# NUM -> 4.8
# NP -> hareket
# NP -> demirbaş
# NP -> açıklama
# NP -> yolculuk
# NP -> safra
# NP -> ehil
# NP -> rüya
# NP -> rezillik
# NP -> amiral
# NP -> makara
# VP -> sür
# NP -> güçlük
# NP -> tela
# VP -> ucuz
# NP -> karat
# NP -> aygıt
# NP -> vitrin
# VP -> kaçır
# NUM -> 500
# NP -> dolay
# NP -> düşünme
# NP -> ziyaret
# NP -> farmasötik
# NP -> yumuşaklık
# NP -> detay
# NP -> sürücü
# NP -> 1141
# NP -> uyku
# NP -> bütünlük
# NP -> masa
# NP -> tedariğine
# NP -> meşguldu
# NP -> fast-food'un
# NP -> ithal
# VP -> şok
# VP -> dinle
# NP -> %15
# NP -> birleşim
# NP -> fiyat-seviyesi
# NP -> protesto
# NP -> fin
# NP -> vali
# NP -> kepek
# VP -> hal
# NP -> yozlaşma
# NP -> %6'nın
# NP -> defa
# NP -> takipçi
# NP -> efor
# NP -> standart
# NP -> 129.90
# NP -> aşk
# VP -> içeri
# NUM -> 1986
# NP -> karın
# NP -> karşılaştırma
# NP -> destekleme
# NP -> yen'den
# NP -> bank
# NP -> eczacı
# NUM -> 107
# NP -> tüp
# NP -> oyuncu
# NP -> single-b-2
# NP -> tatmin
# NP -> mısır
# VP -> sık
# VP -> maaş
# NP -> yengeç
# NP -> yükseltil
# NUM -> 6.4
# NP -> piyango
# VP -> kurtar
# NP -> talih
# VP -> opsiyon
# VP -> cevapla
# VP -> öldür
# NUM -> 95
# NP -> etek
# NP -> devre
# NP -> trajedi
# NP -> iğne
# NP -> halükarda
# NP -> kaolin
# NP -> belirsizlik
# VP -> alan
# NP -> icat
# NP -> villa
# NP -> boşan
# NP -> tümsek
# NP -> dek
# NP -> konut
# NP -> çürüt
# NP -> öksürük
# NP -> ten
# NP -> lisans
# NP -> vuruşçusunun
# NP -> ulaştırma
# NP -> abone
# NP -> bürokrat
# VP -> yayın
# NP -> küme
# NP -> alım-satımlarda
# NUM -> 3\/4
# NP -> kafes
# NP -> olumsuz
# NP -> tadilat
# NUM -> 1.05
# NP -> alevlen
# NP -> ünlü
# NP -> ortodoks
# NP -> tüyo
# NP -> bakkal
# NP -> kızgın
# NP -> inanç
# NP -> otomatik-kotasyon
# NP -> tahkikat
# NP -> garaj
# NP -> çöplük
# NP -> karşılık
# NP -> acınası
# NP -> megabit
# NP -> tıpın
# NP -> kadı
# NP -> mesele
# NP -> deyim
# VP -> güzel
# NP -> tehvili
# VP -> sars
# NP -> kuşak
# NP -> ab
# VP -> çeşit
# NP -> istikrar
# VP -> çalış
# VP -> hak
# NP -> leş
# NP -> karışım
# NP -> yasak
# NP -> yurtdışına
# NP -> düşürül
# VP -> katolik
# NP -> söğüş
# NP -> halı
# NP -> çeşitlilik
# NP -> vaka
# VP -> araştır
# NP -> etme
# NP -> otantik
# NP -> ipuc
# NP -> içme
# NP -> damlalık
# VP -> canlan
# NP -> omuz
# NP -> rastlantı
# NP -> ün
# NP -> maraton
# NP -> spiker
# VP -> ağırlık
# VP -> döndür
# NP -> imge
# NP -> mikroişlemci
# NP -> kartpostal
# NP -> kader
# NP -> ödememe
# NP -> yapımcılık
# NP -> macun
# NP -> görüntü
# VP -> şükret
# NP -> şamdan
# NP -> tanrı
# NP -> 1772.6
# VP -> bağla
# NP -> atıştırmalık
# NP -> zırh
# NP -> yönlü
# NP -> demir
# NP -> %23'ünü
# NP -> işbirliğ
# NP -> %4.5'lik
# NP -> şaka
# NP -> afet
# VP -> sallan
# NP -> fıstık
# NP -> 4.çeyrek
# NP -> kahve
# NP -> kartel
# VP -> destekle
# NP -> fiyatlandırma
# NP -> stagflasyon
# NP -> barış
# NP -> pico
# NP -> misafir
# VP -> vur
# NP -> çatışma
# VP -> sınıf
# NP -> teşebbüs
# VP -> hız
# NP -> ıslah
# VP -> imalatçı
# NP -> sovyet
# VP -> prens
# NP -> denetim
# VP -> düş
# NP -> heyelan
# NP -> ​​meslektaşlarına
# NP -> lira
# VP -> kurumsal
# NP -> antiviral
# NP -> yürüten
# NP -> 1.980
# NP -> çok
# NP -> vari
# NP -> uluslararasılaşma
# NP -> enstitü
# NP -> sakatla
# VP -> makine
# NP -> ilgili
# NP -> mikrop
# NP -> nesnellik
# NP -> final
# NP -> futbol
# NP -> hâla
# VP -> banyo
# NP -> kiracı
# NP -> terim
# VP -> doldur
# NP -> rahat
# VP -> takın
# NP -> yıldız
# NP -> 2660
# NP -> 212.5
# NP -> boyun
# NP -> folkun
# NP -> şebeke
# VP -> fon
# NP -> doktor
# NP -> balık
# NP -> vurucu
# NP -> advancer
# NP -> bourbon
# NP -> tökezle
# NP -> heyet
# NP -> baklagil
# VP -> bozul
# NP -> per
# NP -> fare
# VP -> sorgula
# VP -> ihtiyaç
# NUM -> 35
# NP -> piyasa
# VP -> dök
# NP -> ret
# VP -> biç
# VP -> masraf
# VP -> adam
# NP -> tekrar
# NP -> danışma
# NP -> tanker
# VP -> yapı
# VP -> katıl
# VP -> cumhuriyetçi
# NP -> teklik
# NP -> vadesiz
# NP -> bilgin
# NP -> yetişkin
# NP -> tar
# NP -> çemenotu
# NP -> mega-hisse
# NP -> bilişim
# NP -> hesap
# NP -> idareci
# NP -> devralım
# NP -> resmi
# NP -> stabilize
# NP -> süreliğine
# NP -> hasatı
# NP -> patinaj
# NP -> tan
# NP -> istasyon
# NP -> anlama
# VP -> azalt
# NP -> sepet
# NP -> plaka
# VP -> suçla
# NP -> ayıkla
# NP -> bilanço
# NP -> posta
# VP -> bas
# VP -> atış
# NP -> kaçakçı
# NP -> cuma
# NP -> gayret
# VP -> yenileş
# NP -> jilet
# NP -> sözlük
# NP -> sever
# NP -> kabile
# NP -> açgözlülük
# NP -> aylaklık
# NP -> 662
# VP -> din
# NP -> toplanan
# VP -> ayrım
# NP -> pezo
# NP -> parti
# NP -> eleman
# NP -> torun
# NP -> dizüstü
# NP -> 7.96
# NP -> edinim
# NUM -> 14
# NP -> motosiklet
# NP -> marksist
# NP -> dalgakıran
# NP -> ocak
# NP -> mütabakat
# NP -> bülten
# NP -> sevgi
# NP -> evlilik
# NP -> şasi
# NP -> 458.32'e
# NP -> fraksiyonel
# NP -> biyoteknoloji
# NP -> ödenme
# NP -> manastır
# NP -> irtibat
# NP -> finansçıları
# NP -> talep
# NP -> makul
# NP -> eş
# NP -> araştırma
# NP -> franchising
# NP -> gol
# NP -> somun
# NP -> teşkilat
# NP -> \
# NP -> tercih
# NP -> suikast
# NP -> şov
# NP -> şehire
# NP -> lok
# VP -> gözlemle
# NP -> 216.74'de
# NP -> hukuk
# NP -> arsa
# NP -> duvar
# NP -> 1.125$
# NP -> rahatsızlık
# NP -> ihraç
# NP -> testere
# NP -> dedektör
# NP -> hafriyat
# VP -> karala
# NP -> peş
# NP -> ,viroqua
# NP -> çanta
# NP -> klip
# VP -> tamam
# NP -> beta
# NP -> dayanak
# NP -> söylem
# NP -> kuş
# NP -> randevu
# VP -> ilişki
# NP -> kumla
# NP -> 88.100.000
# NP -> tasarım
# NP -> manşon
# NP -> kamyon
# NP -> volatiliteden
# NP -> 1,100
# NP -> cumartesi
# VP -> kaydet
# NP -> 65-gün
# NP -> bugün
# NP -> koruyuculuk
# VP -> inan
# VP -> yarar
# NP -> hindistanlı
# NP -> sıvılaş
# NP -> teminatçıya
# NUM -> 42
# VP -> uyan
# NP -> doksan
# NP -> mahkeme
# VP -> üret
# VP -> kuruluş
# NP -> teselli
# VP -> olabilir
# NP -> doğu
# NP -> başarızlığına
# NP -> finansman
# NP -> yanlış?
# NP -> temerrütünü
# NP -> terör
# NP -> bulantı
# NP -> şemsiye
# NP -> turna
# NP -> iade
# NP -> dispaşörleri
# NP -> perakendecilik
# NP -> takıl
# NP -> vakit
# NP -> 1930
# NP -> d
# NP -> şampanya
# NP -> pekiştir
# NP -> 3/4'de
# VP -> dolar
# NP -> aktivite
# NP -> favori
# NP -> nesil
# NUM -> dört
# NP -> kriter
# NP -> mentor
# NP -> arena
# NP -> dei
# NP -> kaydadeğer
# VP -> sendikalaş
# NP -> el
# NP -> gerekçe
# NP -> ayrımcılığın
# NP -> baskıncı
# NP -> deneme
# NP -> şeker
# VP -> ad
# NP -> fenomen
# VP -> tut
# NP -> çarşamba
# NP -> izahname
# VP -> küçük
# NP -> istatistik
# VP -> vazgeç
# NP -> duty-free
# NP -> yükselti
# NP -> dadır
# NP -> rütbe
# NP -> nebze
# NP -> mutabakat
# NP -> sağlık
# VP -> beklenti
# NP -> ülser
# NUM -> 57
# NP -> kasa
# VP -> bakan
# NUM -> 3/8
# VP -> danışman
# NP -> trilyonluk
# NP -> pabuç
# NP -> pastırma
# NP -> kompozit
# NP -> nörolog
# NP -> müdahale
# NP -> $'
# NP -> konkordato
# NP -> kazanç
# NUM -> 5/8
# NP -> %42
# VP -> yayıl
# NP -> yabancılaş
# NP -> servet
# NP -> düşünce
# NP -> kolon
# NP -> özgecilik
# NP -> 3.çeyrek
# NP -> bencillik
# NUM -> 24.4
# NP -> ''erkek
# NP -> 6.45
# VP -> kapa
# VP -> kaçın
# NP -> cıa
# VP -> gerilla
# NP -> spekülatör
# NP -> tarz
# NP -> argüman
# NP -> verdi.
# VP -> ters
# NP -> intikam
# NP -> göğüs
# VP -> girişimci
# VP -> hizmet
# NP -> hoşbeş
# NP -> geri
# NP -> dedektif
# VP -> kalk
# NP -> üniforma
# NP -> kanadalı
# NP -> patron
# NP -> sıra)
# VP -> dol
# VP -> ortaklık
# VP -> baskı
# NP -> uyuşmazlık
# NP -> delesyon
# VP -> eğit
# NP -> star
# NP -> arama
# VP -> aşağıla
# NP -> ruh
# NP -> şubat
# NP -> dostluk
# NP -> bulmaca
# NP -> çay
# NP -> trafik
# NP -> boy
# NP -> işçi
# NP -> ekip
# NP -> erteleme
# VP -> kına
# VP -> kapla
# NP -> bilmiş
# NP -> zor.
# NP -> baron
# NP -> kıyas
# NP -> video
# VP -> parçala
# VP -> canlandır
# NP -> resif
# NP -> tokuşlarını
# VP -> darbe
# NP -> coşku
# NP -> sağduyu
# NP -> gin
# NP -> data
# NP -> merkeziyetçilik
# NP -> devriye
# NP -> fotoğraf
# NP -> koşum
# NP -> kolestrol
# NP -> kaldırım
# NP -> çare
# NP -> yenilgi
# VP -> bay
# NP -> dinozor
# VP -> ol
# VP -> toparla
# NP -> %100
# NP -> dükkan
# NP -> ivme
# NP -> dolarlık
# VP -> bulundur
# NP -> pusula
# NP -> süpermarket
# NP -> 1.012
# NP -> 7.10
# NP -> gemi
# NP -> bakiş
# VP -> azınlık
# NP -> dölle
# NP -> tarım
# NP -> yanıt
# NP -> mektup
# NP -> ilköğretim
# VP -> uzaklaştır
# NP -> koruyucu
# VP -> çekici
# NP -> cüret
# VP -> yüksek
# VP -> parça
# NP -> tren
# NP -> sihir
# NP -> faaliyet
# NUM -> 700
# VP -> çöz
# NP -> depolama
# NP -> hâline
# NP -> müessese
# NP -> taş
# NP -> nerdeyse
# NP -> liste
# NP -> uluslararasılaştırılmasında
# NP -> nesile
# NP -> %0.6'lık
# NP -> kimyager
# NP -> amut
# VP -> güçlen
# NP -> yaratıcılık
# VP -> avukat
# NP -> post
# NP -> volatilitesine
# NP -> 7.875,%
# NP -> kesinti
# NP -> disket
# NP -> döşeme
# NP -> sirenleri
# VP -> düşük
# NP -> savuştur
# NP -> 1,120-806
# NP -> çaba
# NP -> tasdik
# VP -> endişe
# NP -> odeon
# NP -> rezervasyon
# NP -> miting
# NP -> müsteşar
# NP -> mark
# NP -> affet
# NP -> 70.000
# NP -> polis
# NP -> kabine
# NP -> (iki
# NP -> burası
# NP -> yayma
# NP -> şarkı
# NP -> sindir
# NP -> müfettiş
# NP -> kelepirci
# NP -> asansör
# NP -> mühendislik
# NP -> alım-satımda
# NP -> koleksiyon
# NP -> buhar
# VP -> heyecanlan
# NP -> %60'ına
# VP -> otur
# NP -> mentalite
# NP -> haciz
# NP -> sohbet
# NP -> arzu
# NP -> kule
# NP -> iman
# NP -> saat
# NP -> havale
# NP -> pazar
# NP -> daralt
# NP -> %42'sini
# NP -> işyer
# NP -> ima
# NUM -> 459.93
# NP -> promosyon
# NP -> tahribat
# NP -> içki
# NP -> samimiyet
# NP -> sürüm
# NP -> biracılık
# NP -> ban
# NP -> teyit
# NP -> zeka
# NP -> %8.03
# NP -> çerçeve
# NP -> ikraz
# NP -> dördün
# VP -> fiyatlandır
# NP -> şiketleri
# NP -> çevre
# NP -> 1845
# NP -> ıhlamur
# NP -> 3.çeyrekte
# VP -> pozisyon
# NP -> cinnet
# NP -> ilkokul
# NP -> mizah
# NP -> mikro-elektronik
# NP -> projeksiyon
# NP -> keyif
# VP -> zirve
# NP -> kurt
# NP -> uçak-elektronik
# NP -> pc
# NP -> çatlak
# NP -> intex
# NP -> eğitim
# NP -> brokerler
# NP -> 1191.86'de
# NP -> çevrecilik
# NP -> metrik
# NP -> ördek
# NUM -> 2662.91
# VP -> endeks
# NP -> sahne
# NP -> tecavüz
# VP -> ölç
# NP -> 1891
# NP -> feet
# NP -> galibiyet
# NP -> mermer
# NP -> sondajcı
# VP -> bitir
# NP -> had
# NP -> sadaka
# NP -> koçu
# NP -> yaşlı
# NP -> değerlendiyor
# NP -> kalpli
# NP -> sütyen
# NP -> 08:30
# VP -> yetki
# VP -> ilgilen
# NP -> korku
# NP -> alım-satımı
# NP -> kayış
# NP -> prenatal
# NP -> unsur
# NP -> suitlere
# NP -> uzay-bilim
# NP -> telaş
# NP -> termal
# NP -> kırışık
# NP -> dönemeç
# NP -> etiğini
# VP -> dağıtıcı
# NP -> terhis
# NP -> yogi
# NP -> işleme
# NP -> emeklilik
# NP -> portföy
# NP -> yalancı
# NUM -> 69
# NP -> bey
# VP -> konum
# NP -> sayaç
# NP -> mantıksızlık
# VP -> beyaz
# NP -> kese
# VP -> tasarla
# NP -> %70'ini
# NP -> dinamik
# NP -> tanıtım
# NP -> revize
# NP -> açma
# NP -> ferroelektrik
# NP -> öğütücü
# NP -> temsil
# VP -> siyah
# NP -> nesir
# NP -> volatile
# NP -> garantör
# NP -> 1074
# VP -> anlaş
# NP -> iplik
# NP -> kova
# NP -> 44796
# VP -> hissedar
# VP -> yanıl
# NP -> başkent
# NP -> muayene
# VP -> gör
# NP -> laboratuar
# NP -> %10'luk
# NP -> verimsizlik
# NP -> platin
# NP -> diyet
# NP -> kimya
# NP -> katılım
# NP -> esas
# NP -> deklarasyon
# NP -> sos
# NP -> borçlanma
# NP -> ihtiyat
# VP -> mantık
# NP -> parite
# NP -> sosyete
# NP -> zayıflık
# NP -> kambiyo
# VP -> bük
# VP -> borçlan
# NP -> tokat
# NP -> am
# NP -> hamilelik
# NP -> müzisyen
# NP -> tespit
# NP -> hikmet
# NP -> takdir
# NP -> açıkça
# NP -> iktidar
# NP -> efsane
# NP -> soygun
# NP -> kota
# NP -> megabayt
# NP -> teğmen
# VP -> üre
# VP -> az
# NP -> gücü
# VP -> faydalan
# NP -> doğrultu
# NP -> kontrat
# NP -> başka
# NP -> keselen
# NP -> 215.42
# NP -> .'dur
# VP -> şüpheli
# NP -> düzenbaz
# NP -> kovan
# NP -> franchise'larına
# VP -> tekrarla
# NP -> ölçekli
# NP -> tango
# NP -> cinsiyet
# NP -> c-yields
# NP -> numune
# NP -> 27.125$'a
# NP -> kıyamet
# NUM -> 1/2
# NP -> cephanelik
# NP -> manzara
# NP -> paddleball
# NP -> geyiriği
# NP -> son
# NP -> ter
# NP -> ayrılış
# NP -> kırıcı
# NP -> ayrıcalık
# NP -> pürüz
# NP -> lanet-torpido
# NP -> tema
# NUM -> altı
# NP -> 543.5
# NP -> konsensusunun
# NP -> sevinç
# NP -> mayın
# NP -> ameliyat
# NP -> kurnazlık
# VP -> ons
# NUM -> 1989
# NP -> sanatçı
# NP -> listening
# NP -> stimülatörle
# NP -> broker
# NP -> bitki
# VP -> bulgu
# NP -> koç
# NP -> toplam
# VP -> kaynak
# NP -> triphosphorous
# NP -> kez
# NP -> tanıklık
# NP -> tüy
# NP -> kampüs
# VP -> dönem
# NP -> takolarının
# NP -> sabitleş
# NP -> dürtü
# NP -> düzine
# VP -> umut
# VP -> geçmiş
# NP -> sendikasyon
# VP -> paketle
# NP -> abonman
# NP -> seneti
# NP -> katip
# VP -> yeni
# NP -> saygınlık
# VP -> yönetici
# VP -> gergin
# VP -> durgunlaş
# NP -> restorasyon
# NP -> verimlilik
# NP -> yürütme
# VP -> yok
# NP -> boşaltı
# NP -> teçhizat
# NP -> rövanş
# NP -> kabus
# NP -> beysbol
# NP -> benzersiz
# NP -> titanyum
# VP -> engel
# NP -> 1993'de
# NP -> ödenek
# NP -> muhafazakarlık
# NP -> alıcı
# NP -> kristal
# NP -> görünüyor.
# NP -> 1205.01
# VP -> çatırda
# VP -> hüküm
# VP -> paylaş
# VP -> üst
# NP -> konumsal
# NP -> polip
# NP -> deneyimsizlik
# NP -> beş-yıllık
# VP -> banka
# NP -> likit
# NP -> kadeh
# NP -> tabanca
# NP -> kapı
# NP -> mahalle
# NP -> stres
# NP -> tekli
# NP -> newport
# VP -> tak
# NP -> komite
# NP -> sprey
# NP -> temmuz
# NP -> gövde
# NP -> makro-ekonomik
# VP -> raporla
# NP -> anlaşmazlık
# NP -> güvensizlik
# NP -> sunucu
# NP -> filistinli
# NP -> nakit
# NP -> açan
# VP -> beceri
# VP -> sağlam
# NP -> işlem
# NP -> hariç
# NP -> kaçakçılık
# NP -> ayakkabı
# NP -> vize
# NP -> %50'sine
# NP -> glukozu
# NP -> silme
# NP -> kik
# VP -> aciliyet
# NP -> edeme
# NP -> pil
# NP -> saçma
# NP -> idealizm
# NP -> kolej
# NP -> konsunda
# NP -> teşkil
# NP -> 2161.9
# NUM -> 90
# NUM -> 1/4
# NP -> sermaye-kazanç
# NP -> stokunun
# VP -> birleştir
# NP -> kömür
# NP -> avukatlık
# NP -> konsept
# NP -> umur
# VP -> bak
# NP -> kapanış
# VP -> sarsıl
# NP -> 30-hisse
# VP -> yayımcı
# VP -> dik
# NP -> tutma
# NP -> elektronik
# NP -> kârlarının
# NP -> hayat
# NUM -> 3.23
# VP -> onar
# NP -> tersane
# NP -> 7.05
# NP -> cerrah
# NP -> koyucu
# NP -> dizi
# NP -> ekonomist
# VP -> taraftar
# VP -> evril
# VP -> don
# NP -> röportaj
# VP -> külçe
# VP -> art
# NP -> hepatit
# NP -> taşıyıcı
# NP -> masör
# NP -> kanunlaş
# NP -> kamyonet
# VP -> yazar
# NP -> otomotiv-emisyon
# NP -> yahudi
# NP -> nüsha
# NP -> noel
# VP -> yoğunlaş
# NP -> zam
# NUM -> 5\/8
# NUM -> 2009
# NP -> arıza
# NP -> yaran
# NP -> bayan
# NP -> kolektif
# NP -> gümrük
# NP -> taşımacılık
# NP -> %9
# NP -> şantaj
# NP -> vizyon
# NP -> artırım
# VP -> hisset
# VP -> sınırla
# VP -> ara
# NP -> saray
# NP -> glasnost
# VP -> şüphelen
# NP -> banliyö
# NP -> yemlik
# NP -> asimetrik
# NP -> papaz
# NP -> zaaf
# NUM -> 1994
# NP -> barometre
# NP -> vagon
# NP -> başvuru
# VP -> istek
# NUM -> 4/32
# NP -> sözel
# NP -> gayrimenkul
# NP -> biçimlendir
# NP -> atmosfer
# NP -> libre
# NP -> vinç
# NP -> mülk
# NP -> besi
# NP -> 2569.72
# NP -> seyirci
# NP -> yavru
# NP -> kılavuz
# NP -> anavatan
# NP -> kitap
# NP -> doku
# NP -> dolar-yen
# VP -> tepki
# NP -> tayfun
# NP -> maya
# NP -> liberalleş
# NP -> toplama
# NP -> çekirdek
# NP -> reji
# NP -> kaş
# VP -> git
# VP -> savaş
# NP -> arter
# NP -> aracı
# NP -> enfekte
# NP -> istifade
# NP -> 183.467
# NP -> teori
# NP -> çıkma
# VP -> uyum
# NP -> çeyrek
# NP -> %29
# NP -> konsantre
# NP -> 754'den
# VP -> vergi
# NP -> $'dan
# NP -> makiyetlerine
# NP -> diyoruz.
# NP -> alman
# NP -> değişik
# VP -> sorumluluk
# NP -> sosyolog
# NP -> federal
# NP -> oto
# VP -> belirle
# NP -> grev
# NP -> tasarı
# NP -> krema
# NP -> tali
# NP -> ortala
# VP -> aş
# NUM -> 7/8
# NP -> transplanttan
# NP -> kalega
# NP -> finanse
# NP -> disk
# NP -> onur
# NP -> ders
# NP -> verici
# NP -> kariyer
# NP -> emeklilik-
# NP -> filtre
# NP -> asyalı
# NP -> uyuşturucu
# NP -> japonyalı
# NP -> eşitlikçilik
# NP -> tezgahüstü
# NP -> referans
# NP -> guguk
# NP -> fonlamak
# NP -> şimdi
# NP -> şifre
# NP -> monetarist
# NP -> 454.86
# NP -> kirlilik
# VP -> benze
# NP -> dul
# NP -> temiz
# NP -> nakiti
# NP -> supraventriküler
# NP -> hapis
# NUM -> 8.65
# NP -> bursiyer
# NP -> kuyumcu
# NP -> gürültü
# NP -> ağaç
# NP -> sütun
# NP -> bağnazlık
# NP -> gezinti
# NP -> 98523
# NP -> kostüm
# NP -> patlak
# NP -> fakir
# VP -> taban
# VP -> kapsa
# NP -> vakıf
# NP -> cilve
# NP -> şarlatan
# VP -> tutum
# VP -> yığ
# NP -> dağ
# NP -> radar-tehdit
# NP -> nefes
# NP -> yen
# NP -> motif
# VP -> savun
# NP -> temyiz
# NP -> tenor
# NP -> faks
# NP -> simsar
# NP -> lisansladı
# NP -> 1947
# NUM -> 1/8
# NP -> norm
# NP -> yenileme
# NP -> bildirge
# NP -> ateşkes
# NP -> politikacı
# NP -> mahal
# VP -> yayınla
# NP -> korsan
# NP -> demeç
# VP -> tamamla
# NP -> ayrış
# NP -> paket
# NP -> somon
# NP -> turkuaz
# NP -> dönüm
# NP -> yükselme
# NUM -> 15
# NP -> çinli
# NP -> mezun
# VP -> bat
# NP -> iş-yönetim
# NP -> tanık
# NP -> 1199.32
# NP -> avaz
# NP -> kutup
# VP -> istisna
# NP -> kış
# NP -> programcılık
# NP -> ceset
# NP -> yıldırım
# NP -> sermaye
# VP -> kaybol
# NP -> 1975'de
# VP -> politika
# NP -> bağımlılık
# NP -> iletişim
# NP -> piskopos
# VP -> geliş
# NP -> malik
# NP -> motive
# VP -> planla
# NP -> dilekçe
# NP -> sapan
# NP -> bakma
# NP -> diet
# NP -> delin
# NP -> tiryaki
# NP -> kimse
# NP -> 213.97
# NP -> eksiklik
# NP -> damıtıcı
# NP -> kliring
# NP -> 219.19'de
# NUM -> 9
# VP -> emin
# NP -> acenta
# VP -> aktif
# NP -> balon
# NP -> islam
# NP -> mt
# NP -> aldat
# VP -> çıkar
# NP -> 6.kez
# NP -> revak
# NP -> sonuçla
# NP -> çıktı.
# NP -> karşı-devrimci
# VP -> uzunluk
# VP -> kaç
# NP -> cinayet
# NP -> alış-veriş
# NUM -> 12.5
# VP -> onay
# NUM -> 2200
# NP -> piyano
# VP -> araştırmacı
# VP -> kurtul
# NP -> espri
# NP -> ayaklanma
# NP -> 694
# NP -> 35670
# VP -> dön
# NP -> itfa
# NP -> indikatör
# NUM -> 465
# NP -> güncelle
# NP -> p53
# NP -> basit
# NP -> köprü
# VP -> hikaye
# NP -> sertifika
# NP -> baloncu
# NP -> figür
# NP -> hardal
# NP -> ajan
# NP -> varak
# VP -> tüken
# VP -> kışkırt
# NP -> bordro
# NP -> epileptik
# NP -> bağcık
# NP -> kışkırtma
# NP -> single-b
# NP -> manken
# NP -> hissi
# NP -> tel
# VP -> satı
# NP -> yoldaş
# NP -> tahmis
# NP -> diril
# NP -> bayii
# NP -> 130.46
# NP -> tahrip
# NP -> ana
# NP -> postala
# NP -> ünite/birim
# NP -> tasarımcı
# NP -> tekabül
# NP -> batarya
# NP -> fener
# NP -> %10.4
# NP -> lejyon
# VP -> ilet
# NP -> salınım
# NP -> yürürlük
# NP -> ikram
# NP -> kıyafet
# NP -> edebiyat
# VP -> profesyonel
# NP -> neon
# NP -> optik
# NP -> tenis
# NP -> sevkiyat
# VP -> karşı
# NP -> haşere
# NP -> yönelim
# NP -> sızıntı
# NUM -> 240
# VP -> sektör
# NP -> algı
# NP -> çarpı
# NP -> marina
# NP -> tahıl
# VP -> önlem
# VP -> artış
# NP -> nüfuz
# NP -> döngü
# NP -> klor
# NP -> örtü
# NP -> üstat
# NP -> kaldıraç
# NP -> reorganizasyon
# NP -> bahar
# NP -> ünvan
# VP -> önemsen
# NP -> kopuk
# NP -> nezaket
# NP -> lezzet
# NP -> 1974'deydi
# NP -> 1.222
# NP -> azaltım
# NP -> kitapçı
# VP -> başar
# NP -> 40.6
# NP -> hiddet
# NP -> aflatoksin
# NP -> uzmanlık
# NP -> yüksek.
# NP -> hareketlen
# VP -> kaynaklan
# NP -> referandum
# NP -> isabet
# NP -> egzersiz
# NP -> nakliyeci
# NP -> harcama
# VP -> yat
# VP -> aksa
# NP -> ilişkilerinde:
# VP -> dönüş
# NP -> mahsülü
# VP -> bono
# NP -> sabun
# NP -> telafi
# NP -> belirsizdir.
# VP -> böl
# VP -> söz
# NP -> tümor
# NP -> kafeterya
# NP -> traktör
# NP -> ekarte
# VP -> zayıfla
# NP -> kağıt
# NP -> lojistik
# VP -> oyna
# NP -> damızlık
# NP -> kabiliyet
# NP -> bildiri
# NP -> eylem
# NP -> fırlatma
# NP -> telgraf
# NP -> som
# NP -> gözlemci
# VP -> düşür
# NP -> limoni
# NP -> memurluk
# NP -> muhasebe
# NP -> çingene
# NP -> bilinç
# NP -> teneke
# NP -> denetçi
# NP -> masaüstü
# NP -> bezelye
# NP -> 2018
# NP -> arbede
# NP -> konuşmacı
# NUM -> 572
# VP -> sor
# NP -> transitde
# NP -> ithalatçı
# NP -> iptal
# NP -> gözlük
# VP -> net
# VP -> öğe
# NP -> mühimmat
# VP -> sıçra
# NUM -> 12.75
# NP -> 1990-model
# NP -> tutucu
# VP -> işletmeci
# NP -> bağırsak
# NP -> özürlü
# NP -> kaygılı
# NP -> %7.90
# NP -> atari
# NP -> isveçli
# NP -> nakavt
# NP -> yalan
# VP -> yasakla
# VP -> yumuşa
# NP -> %2'dir
# NP -> fast-track
# NP -> gölge
# NP -> kaset
# NP -> çökme
# NP -> ustabaşısı
# NP -> karne
# NP -> parlamento
# NP -> %2'lik
# NP -> seçki
# NP -> kürk
# NP -> yazarlık
# NP -> kadro
# NP -> iz
# NP -> konyak
# NP -> meditasyon
# VP -> değiştir
# NUM -> ı
# NP -> yapılanma
# VP -> davran
# NP -> doğurganlık
# VP -> sendele
# VP -> ateşle
# NP -> 4.375'den
# NP -> güruh
# NP -> 34.25$'den
# NP -> burger
# NP -> lakap
# NP -> $'lık
# NP -> %8.21
# NP -> rafine-petrol
# VP -> borç
# NP -> şık
# NP -> mikroskop
# NP -> paranın-çalışması
# NP -> meşruiyet
# NUM -> 400
# NP -> bankacı
# NP -> şüpheci
# VP -> kütüphane
# NP -> yerleşimcinin
# NP -> boyama
# VP -> onayla
# NP -> megawattlık
# NP -> mülteci
# NP -> lego
# NP -> çamaşır
# NP -> tehlikeli
# NP -> deccal
# NP -> katot
# NP -> müze
# NP -> hakimiyet
# NP -> grup'un
# NP -> gözardı
# VP -> merkez
# NP -> fan
# NP -> işlemci
# NP -> çayır
# NP -> `stay
# NP -> karakter
# NP -> kurma
# NP -> hasta
# NP -> uyaran
# NP -> veteriner
# VP -> düzenle
# NUM -> 1962
# NP -> tröst
# NP -> red
# NP -> litre
# NP -> çürü
# NP -> merhamet
# NP -> güreşçi
# NP -> sine
# NP -> ilerleyici
# NP -> .'dır
# VP -> geçerli
# NP -> anket
# NP -> 1970'de
# VP -> artır
# NP -> sermayedar
# NP -> tohum
# NP -> veto
# NP -> tik
# VP -> cihaz
# NP -> 9.62
# NP -> yayılım
# NP -> 1974-75'de
# NP -> şampuan
# NP -> tahliye
# VP -> kıyasla
# NP -> doyur
# NP -> finasman
# NP -> 130.13
# NUM -> 89
# VP -> titre
# NP -> infilakın
# NP -> koridor
# NP -> çizim
# NP -> komunist
# NP -> flaş
# VP -> gün
# VP -> salla
# NP -> arbs'in
# NP -> kamçı
# NP -> mühürle
# NP -> bakanlık
# NP -> demet
# VP -> ilgi
# VP -> in
# NP -> group
# NP -> kapitalizm
# NP -> 100-pay
# NUM -> 1960
# VP -> kabullen
# NP -> anti-kanser
# VP -> sıkıştır
# NP -> dağılma
# NP -> fişek
# NP -> kabartı
# NP -> tur
# NP -> netice
# NP -> beyin
# NP -> sorumsuzluk
# NP -> caydırıcı
# NP -> duayen
# NP -> z
# VP -> yakala
# NP -> suistimal
# NP -> çadır
# NP -> alarm
# NP -> etkileşim
# NP -> budak
# NP -> bütünleş
# NUM -> 66
# NP -> farz
# NP -> davranış
# NP -> içtihat
# NP -> beri
# NP -> faiz
# NP -> maliyet
# VP -> tanımla
# NUM -> 24
# NP -> döner
# NP -> vizon
# VP -> ipotek
# NP -> cümle
# NP -> herkes
# NP -> kalite
# VP -> etki
# NP -> farklılık
# NP -> etkinlik
# NP -> %40'ını
# NP -> neti
# NP -> stajyer
# NP -> dönemki
# NP -> istifa
# NP -> öncelik
# NP -> ahır
# NP -> veritaban
# NUM -> 11
# NP -> sebep:
# VP -> üzer
# VP -> ora
# NP -> yıkım
# NP -> sorumlu
# NP -> vade
# NP -> terk
# NP -> %11.1'ini
# NP -> 8:
# NP -> seks
# NP -> spekülasyon
# NP -> stop-ödeme
# NP -> kaplumbağa
# NP -> simülatör
# NP -> çığlık
# NP -> müzakelererin
# NP -> gayrimenkullerde
# NP -> bardak
# NP -> madenci
# VP -> sirkülasyon
# NP -> şirletler
# NUM -> 1979
# VP -> düzel
# NP -> multimedya
# NP -> erkek-kısır
# VP -> geç
# NP -> monolitlerin
# NP -> 3500
# NP -> dengesizlik
# NP -> utangaç
# NP -> mütevelli
# NP -> yakıt
# NP -> oil
# NP -> fırçala
# NP -> terzilik
# NP -> metanollu
# NP -> yuva
# NP -> öden
# NP -> muhalafeti
# NP -> şalo
# NP -> görgü
# NP -> sancak
# NP -> muadillerinden
# NP -> atık
# NP -> 1263.51
# NP -> çevreci
# NP -> operatif
# NP -> kural
# NP -> spektaküler
# NP -> olimpiyat
# VP -> panik
# NUM -> 6.5
# NP -> /4
# NP -> bowling
# VP -> oku
# VP -> takas
# VP -> yargıç
# NP -> müsrif
# VP -> yıllık
# NP -> 8,000
# NP -> kargaşa
# NP -> isyancı
# NP -> güreş
# VP -> ay
# NP -> yön
# NP -> toprak
# NP -> kasvet
# NP -> hakkımızdaki
# NP -> bilmiyorlar.
# NP -> bayıl
# NUM -> 1988
# NP -> sağ
# VP -> hatırla
# NP -> desen
# VP -> distribütör
# NP -> dezavantaj
# NP -> 2596.72
# NP -> tarafsız
# NP -> müzik
# NP -> tip
# NP -> deflatör
# NP -> çekim
# NP -> aciz
# NP -> sosyal
# NP -> opec
# NP -> alev
# VP -> atan
# NP -> mikroskobik
# NP -> çizelge
# NP -> puro
# NP -> stratosferik
# NP -> revizyon
# VP -> yapımcı
# NP -> ört
# VP -> kuvvet
# NUM -> 1987
# NP -> es
# NP -> yarışma
# NP -> %14.1
# NP -> 1.059.04
# VP -> şekil
# NP -> girişim
# NP -> mevki
# NP -> uyarı
# NP -> gençlik
# NP -> burs
# NP -> hard
# NP -> zafer
# VP -> ben
# NP -> kahraman
# NP -> canlandırma
# NP -> milyonlarca
# NP -> 51-nakit
# NP -> realizasyonları
# VP -> yağ
# NP -> bellek
# NP -> yor
# NP -> vesile
# NP -> göç
# NP -> depozito
# NP -> istihdam
# VP -> gösterge
# NP -> iyileştir
# VP -> aç
# VP -> duyur
# NP -> 13.4
# NUM -> 10.5
# NUM -> 23
# NP -> solo
# NP -> inşaat
# NP -> dondurma
# NP -> gayrimenkullerin
# NP -> kavga
# NP -> aracılık
# NP -> mahkum
# NP -> kavanoz
# NP -> emek-yönetim
# NP -> hidroelektrik
# VP -> süre
# NP -> alışveriş
# NP -> akraba
# VP -> etkile
# NP -> parçalan
# VP -> sök
# NP -> dayanışma
# VP -> bomba
# NP -> fizyoloji
# NP -> çubuk
# NP -> ölçek
# VP -> ertele
# NP -> implant
# NP -> burbon
# NP -> öğle
# NP -> bıçak
# NP -> kapitalist
# NP -> oğul
# NP -> spot
# NP -> ham
# NP -> küresel
# VP -> gel
# VP -> iddia
# NP -> dev
# VP -> teşhis
# NP -> diyabet
# NP -> %0,3
# VP -> şımar
# NP -> doldurma
# VP -> engelle
# NP -> vurul
# NP -> süpervizörleri
# NP -> gizem
# NP -> karmaşa
# NP -> suitinde
# NP -> devam
# NP -> 2149.3
# NP -> enstrüman
# NP -> spor
# NP -> dikte
# NP -> inat
# VP -> çağır
# NP -> fantezi
# VP -> ayrılık
# NP -> deniz
# VP -> yatırım
# NP -> 7.60
# NP -> sıkboğaz
# NUM -> 13/16
# VP -> husus
# NP -> gezi
# NP -> sınıfla
# NP -> özet
# NP -> yonga
# NP -> 'dür
# NP -> mobil
# NP -> 13.000
# NP -> profesör
# NP -> sinyal
# VP -> kuru
# NP -> patlama
# NP -> tomurcuk
# NP -> enkaz
# NP -> yardları
# NP -> nam
# NP -> kuaför
# VP -> amaç
# NP -> 3090
# NP -> piko
# NP -> edep
# NP -> ortalık
# NP -> kamu
# NP -> çölümsü
# NP -> bucak
# NP -> gider
# VP -> uyandır
# NP -> gel-gitlerden
# VP -> tahvil
# NP -> finiş
# NUM -> 2002
# NP -> harç
# NP -> inşa
# NP -> feragat
# NP -> niş
# NP -> eşitlikçiliği
# NP -> domuz
# NUM -> 18
# NP -> kapatma
# NP -> ​​yaptı
# NUM -> on
# NP -> başarısızlık
# NP -> kullanım
# NP -> tören
# NP -> avrupalı
# NP -> yeniyetme
# NP -> verme
# NP -> %26
# NP -> kuyu
# NP -> 455.63
# NP -> ipucu
# NP -> tanıma
# NP -> sırılsıklam
# NP -> banka-dolandırıcılık
# NP -> %6.4'ün
# NP -> şimşek
# NP -> metin
# NP -> reyting
# NP -> 9.5'di
# NP -> stadyum
# NP -> psikobiyoloji
# NP -> çalıntı
# NP -> imalat
# NP -> segman
# VP -> hazırla
# NP -> kasırga
# NP -> memur
# NP -> kapak
# NP -> antreman
# NP -> grafik
# NP -> propan
# NP -> karavan
# NP -> resepsiyon
# NP -> santimetre
# NP -> rekabet
# VP -> yuvarla
# NP -> içim
# NP -> franchiselarını
# NP -> türlü
# NP -> maden
# NP -> -110
# NP -> çarptır
# NP -> atak
# VP -> reform
# NP -> kromozom
# NP -> savunmasızlık
# NP -> soruşturmacı
# NP -> olacak
# NUM -> 32
# NP -> amonyum
# NP -> ölçüm
# NP -> diplomasi
# NP -> kaya
# NP -> %12'si
# NP -> facia
# NP -> yerinde
# NP -> bileşim
# NP -> çarpan
# NP -> maske
# NP -> mat
# NP -> doğa
# NP -> koro
# NP -> tesisat
# VP -> tüket
# NP -> tarama
# NP -> elektrolüminesans
# VP -> karşılaş
# VP -> vurgula
# NP -> kalıntı
# NP -> rafineri
# NP -> yen'lik
# NP -> üretkenlik
# NP -> rodeo
# NP -> demilitarize
# NP -> havalandırma
# VP -> numara
# NP -> akşam
# VP -> hazır
# NP -> yayınev
# NP -> saldırgan
# NP -> seremoni
# NP -> denizaşırı
# NP -> pısırık
# NP -> birikim
# NP -> peşinde
# NP -> seyir
# NP -> 14.560.000
# NP -> temin
# NP -> buzdağ
# NP -> aktarma
# NP -> vergilendirilebilir-eşdeğer
# NP -> gebelik
# NP -> centilmenlik
# NP -> açmaz
# NP -> espiyonaj
# VP -> tanım
# VP -> değiş
# NP -> komut
# NP -> tasavvur
# NP -> imparatorluk
# NP -> renk
# NP -> mega
# VP -> önce
# VP -> fiyat
# NP -> kıymet
# NP -> lig
# NP -> iyilik
# NP -> %5'i
# NP -> gürle
# NP -> verit
# NP -> antifriz
# NUM -> 8.9
# VP -> kültür
# NP -> %25'inin
# NP -> /2
# NP -> tasvir
# NP -> minimal
# NP -> çift-a'
# VP -> dikil
# NP -> şatafat
# NP -> tekstil
# NP -> fırtına
# VP -> çek
# NP -> engelleyici
# VP -> süpür
# VP -> şüphe
# NP -> işgal
# NP -> seyahat
# NP -> genişleme
# NP -> memnuniyet
# VP -> kullan
# NP -> fırın
# NP -> organ
# NP -> buldozer
# VP -> cay
# VP -> üye
# NP -> show
# NP -> stratejist
# NP -> duyduran
# NUM -> 1999
# NP -> tablo
# NP -> deney
# NP -> ayrılma
# NP -> 80,000
# VP -> fatura
# NP -> anı
# NP -> köpekbalık
# NP -> parsel
# NP -> şah
# NP -> kıdem
# NP -> saçmalık
# VP -> getir
# NP -> iletim
# NP -> mutluluk
# NP -> atıcı
# NP -> bisikletçi
# NP -> ettir
# VP -> hafifle
# VP -> görev
# NP -> 463.28
# NP -> gri
# NP -> huylu
# NP -> ova
# NP -> kum
# NP -> çekicilik
# NP -> halef
# NP -> rezerv
# NP -> çanak
# NP -> ustalık
# NP -> şifrele
# NP -> başlık
# NP -> muz
# NP -> kapasitör
# NP -> oşinografik
# NP -> sörfçü
# NP -> editoryal
# NP -> yedekle
# NP -> doğaçlama
# NP -> gönül
# NP -> lansman
# NP -> taklit
# NUM -> 9000
# NP -> kiralama
# VP -> sıfırla
# NP -> anlaşıl
# NP -> 1994'de
# NP -> çalgı
# NP -> iskontalarla
# NP -> kuzey
# NP -> bütçeciler
# NP -> sıçan
# VP -> hayalet
# NP -> zımni
# NP -> hortum
# NP -> yükümlülük
# NP -> elçi
# NP -> akın
# NP -> tahakkuk
# VP -> azal
# NP -> savunmacılarına
# NP -> çimento
# VP -> tedavül
# NP -> ressam
# NP -> pembe
# NP -> tatlılık
# NP -> kod
# NP -> fiyat-bilinçli
# VP -> serp
# NP -> 1507.37
# NUM -> 1992
# NP -> 4400
# VP -> cent
# NP -> ünite/birime
# NP -> açıklanan
# NP -> reasürans
# VP -> sosyalist
# NP -> romancı
# NP -> 1995'de
# NP -> isim
# NP -> pasifize
# NP -> damgala
# NP -> balina
# NP -> gezegen
# NP -> river
# NP -> kravat
# VP -> kat
# NP -> nakarat
# NP -> nisan
# NP -> düzeltme
# NP -> 1o
# NP -> pejmürde
# NP -> portre
# NP -> par
# NP -> ücret
# NP -> talihsizlik
# NP -> 8.35
# NP -> şalter
# NP -> diagnostik
# NP -> popüler
# NP -> kast
# VP -> dengele
# NP -> azalma
# NP -> öneri
# NP -> yandaş
# NP -> entrika
# NP -> toksin
# NP -> takasçı
# NP -> kemik
# NP -> çan
# NP -> biyolojik
# NP -> kurmay
# NP -> %0,9
# NP -> anonim
# NP -> satın
# NP -> saf
# ...
# NUM -> 10.3
# NUM -> 59
# NUM -> 130
# NUM -> 4.11
# NUM -> 50.59
# NUM -> 142.85
# NUM -> 1.49
# NUM -> 1961
# NUM -> 6050
# NUM -> ıv
# NUM -> 500.2
# NUM -> 130.76
# NUM -> 2.15
# NUM -> 730070
# NUM -> 9.2
# NUM -> 2683.2
# NUM -> 49000
# NUM -> 25.25
# NUM -> 4.27
# NUM -> 368.24
# NUM -> 184
# NUM -> 143.6
# NUM -> 4.31
# NUM -> 39300
# NUM -> 40.4
# NUM -> 36.6
# NUM -> 14580000
# NUM -> 8.375
# NUM -> 108.4
# NUM -> 11.6
# NUM -> 210
# NUM -> 11.4
# NUM -> 5.37
# NUM -> 20.6
# NUM -> 19.2
# NUM -> 53.9
# NUM -> 148
# NUM -> 30.1
# NUM -> 35.38
# NUM -> 376.36
# NUM -> 2.38
# NUM -> 28.6
# NUM -> 3.68
# NUM -> 40000
# NUM -> 2.87
# NUM -> 94425000
# NUM -> 11.0
# NUM -> 39.19
# NUM -> 691.09
# NUM -> 7.3
# NUM -> 168
# NUM -> 897.2
# NUM -> 0.03
# NUM -> 2.14
# NUM -> 170330000
# NUM -> 552302
# NUM -> 7.12
# NUM -> 986
# NUM -> 1956
# NUM -> 21.6
# NUM -> 295.7
# NUM -> 92.42
# NUM -> 111
# NUM -> 251.2
# NUM -> 1.8578
# NUM -> 11820000
# NUM -> 711.9
# NUM -> 11.8
# NUM -> 54.51
# NUM -> 373.8
# NUM -> 272.0
# NUM -> 47.46
# NUM -> 94.243
# NUM -> 765
# NUM -> 1.603
# NUM -> 2.57
# NUM -> 589
# NUM -> 2210
# NUM -> 487
# NUM -> 30\/32
# NUM -> 9.75
# NUM -> 18.69
# NUM -> 10.2
# NUM -> 29/32
# NUM -> 1.68
# NUM -> 1210.7
# NUM -> 307.2
# NUM -> 108.28
# NUM -> 141.65
# NUM -> 877.6
# NUM -> 63.52
# NUM -> 44.6
# NUM -> 368.15
# NUM -> 275000
# NUM -> 822
# NUM -> 5.04
# NUM -> 601.3
# NUM -> 7.4
# NUM -> 354000
# NUM -> 28.3
# NUM -> 1900
# NUM -> 166.9
# NUM -> 5.8125
# NUM -> 43.3
# NUM -> 145
# NUM -> 8.32
# NUM -> 92
# NUM -> 8.38
# NUM -> 27.0
# NUM -> 80000
# NUM -> 35587.85
# NUM -> 2.69
# NUM -> 407
# NUM -> 488
# NUM -> 914
# NUM -> 448
# NUM -> 101.98
# NUM -> 16.1
# NUM -> 1.54
# NUM -> 220
# NUM -> 925
# NUM -> 75.2
# NUM -> 191.1
# NUM -> 12283217
# NUM -> 8.62
# NUM -> 415
# NUM -> 0.45
# NUM -> 58.97
# NUM -> 99.14
# NUM -> 99.23
# NUM -> 185
# NUM -> 108625
# NUM -> 141.52
# NUM -> 0.53
# NUM -> 309381
# NUM -> 730
# NUM -> 44.125
# NUM -> 5088774
# NUM -> 433.5
# NUM -> 8.7
# NUM -> 2.21
# NUM -> 20.125
# NUM -> 257.8
# NUM -> 190
# NUM -> 5.94
# NUM -> 100.8
# NUM -> 423
# NUM -> 456.2
# NUM -> 176.7
# NUM -> 643.4
# NUM -> 97.85
# NUM -> 8.22
# NUM -> 117.94
# NUM -> 6.07
# NUM -> 4.75
# NUM -> 6.95
# NUM -> 195.19
# NUM -> 884
# NUM -> 7.81
# NUM -> 1.5885
# NUM -> 112
# NUM -> 21.4
# NUM -> 1.6145
# NUM -> 425000
# NUM -> 1701.7
# NUM -> 31000
# NUM -> 7.2
# NUM -> 626.3
# NUM -> 1920
# NUM -> 663
# NUM -> 780
# NUM -> 25.875
# NUM -> 747
# NUM -> 4.12
# NUM -> 0.44
# NUM -> 3481887
# NUM -> 283.2
# NUM -> 344.354
# NUM -> 499.4
# NUM -> 575000
# NUM -> 1610
# NUM -> 11.9
# NUM -> 2.73
# NUM -> 76.4
# NUM -> 4.9
# NUM -> 1070000
# NUM -> 9756
# NUM -> 25.78
# NUM -> 1.85
# NUM -> 13.02
# NUM -> 3.16
# NUM -> 18.7
# NUM -> 8590
# NUM -> 376000
# NUM -> 155.0
# NUM -> 0.39
# NUM -> 19395
# NUM -> 155650000
# NUM -> 12.9375
# NUM -> 13/32
# NUM -> 2600
# NUM -> 1.37
# NUM -> 14.95
# NUM -> 9.76
# NUM -> 784.5
# NUM -> 245.3
# NUM -> 0.23
# NUM -> 654.5
# NUM -> 41.2
# NUM -> 3426.33
# NUM -> 75.5
# NUM -> 3.55
# NUM -> 930
# NUM -> 673
# NUM -> 678
# NUM -> 177
# NUM -> 6.19
# NUM -> 33270
# NUM -> 9.3
# NUM -> 6500000
# NUM -> 25.8
# NUM -> 51
# NUM -> 785
# NUM -> 9.81
# NUM -> 540.9
# NUM -> 10.7
# NUM -> 36.125
# NUM -> 2.09
# NUM -> 2423.9
# NUM -> 313800
# NUM -> 108
# NUM -> 369000
# NUM -> 353
# NUM -> 192
# NUM -> 57000
# NUM -> 27.8
# NUM -> 452
# NUM -> 44400
# NUM -> 2.63
# NUM -> 194
# NUM -> 8.59
# NUM -> 21.98
# NUM -> 223.3
# NUM -> 14.11
# NUM -> 329.2
# NUM -> 78.64
# NUM -> 3.64
# NUM -> 13.0
# NUM -> 2007
# NUM -> 17.73
# NUM -> 1.2
# NUM -> 161
# NUM -> 39.31
# NUM -> 4.92
# NUM -> 390.5
# NUM -> 53
# NUM -> 2189.7
# NUM -> 2157656
# NUM -> 2600000
# NUM -> 42.25
# NUM -> 34230
# NUM -> 88
# NUM -> 761.38
# NUM -> 10.875
# NUM -> 08:01
# NUM -> 8.07
# NUM -> 26.23
# NUM -> 115
# NUM -> 2.66
# NUM -> 1150000
# NUM -> 12.06
# NUM -> 231
# NUM -> 119.88
# NUM -> 18.5
# NUM -> 52.75
# NUM -> 5.01
# NUM -> 382.9
# NUM -> 179.916
# NUM -> 26.81
# NUM -> 2.8
# NUM -> 10.4
# NUM -> 19.3
# NUM -> 39.68
# NUM -> 368.25
# NUM -> 0.6
# NUM -> 39.5
# NUM -> 515
# NUM -> 25.96
# NUM -> 176100000
# NUM -> 350.0
# NUM -> 35486.38
# NUM -> 103.0
# NUM -> 425
# NUM -> 680
# NUM -> 370.6
# NUM -> 786100
# NUM -> 28.7
# NUM -> 165
# NUM -> 210.2
# NUM -> 2023
# NUM -> 7.84
# NUM -> 31.2
# NUM -> 102.5
# NUM -> 2.79
# NUM -> 1.38
# NUM -> 250000
# NUM -> otuz
# NUM -> 750000
# NUM -> 1.45
# NUM -> 10.35
# NUM -> 461.2
# NUM -> 7.904
# NUM -> 215.48
# NUM -> 30.88
# NUM -> 21.25
# NUM -> 335.7
# NUM -> 17.92
# NUM -> 774000
# NUM -> 158
# NUM -> 19.51
# NUM -> 19.93
# NUM -> 114
# NUM -> 446.5
# NUM -> ııı
# NUM -> 2.61
# NUM -> 234
# NUM -> 22.3
# NUM -> 28.0
# NUM -> 117.2
# NUM -> 142.25
# NUM -> 155
# NUM -> 148.85
# NUM -> 153
# NUM -> 89.75
# NUM -> 1247.87
# NUM -> 130000
# NUM -> 87.37
# NUM -> 1.02
# NUM -> 6.94
# NUM -> 44877
# NUM -> 814000
# NUM -> 505
# NUM -> 38000
# NUM -> 9.78
# NUM -> 129.6
# NUM -> 6.8
# NUM -> 517500
# NUM -> yedinci
# NUM -> 16800000
# NUM -> 462.9
# NUM -> 3.54
# NUM -> 0.1
# NUM -> 4.22
# NUM -> 0.71
# NUM -> 25000
# NUM -> 3377.43
# NUM -> 8.81
# NUM -> 329600
# NUM -> 1.0
# NUM -> 1.8667
# NUM -> 6.31
# NUM -> 216.49
# NUM -> 129.38
# NUM -> 2.1
# NUM -> 497.1
# NUM -> 2387226
# NUM -> 904000
# NUM -> 402.7
# NUM -> 6.52
# NUM -> 17.375
# NUM -> 1.62
# NUM -> 195.4
# NUM -> 501.61
# NUM -> 83
# NUM -> 702.4
# NUM -> 18.0
# NUM -> 265.79
# NUM -> 13.32
# NUM -> 251.8
# NUM -> 7\/16
# NUM -> 12.9
# NUM -> 528.4
# NUM -> 14.85
# NUM -> 1435
# NUM -> 476.5
# NUM -> 7\/32
# NUM -> 428000
# NUM -> 0.35
# NUM -> 22.125
# NUM -> 11:54
# NUM -> 103
# NUM -> 1.73
# NUM -> 191.75
# NUM -> 320
# NUM -> 145.45
# NUM -> 22.8
# NUM -> 378.87
# NUM -> 26.1
# NUM -> 371.1
# NUM -> 1.4
# NUM -> 50.875
# NUM -> 87.1
# NUM -> 111.2
# NUM -> 22.6
# NUM -> 2117.1
# NUM -> 1.8485
# NUM -> 73
# NUM -> 180000
# NUM -> 4000
# NUM -> 370
# NUM -> 32.7
# NUM -> 410.5
# NUM -> 470.8
# NUM -> 8.05
# NUM -> 2.59
# NUM -> 291.6
# NUM -> 7.73
# NUM -> 36.13
# NUM -> 160
# NUM -> 56.9
# NUM -> 135.9
# NUM -> 91.21
# NUM -> 6727042
# NUM -> 42.7
# NUM -> 950
# NUM -> 30.6
# NUM -> 19.7
# NUM -> 10873
# NUM -> 128
# NUM -> 110
# NUM -> 2.75
# NUM -> 200000
# NUM -> 394.4
# NUM -> 5.9
# NUM -> 918.4
# NUM -> 12.345
# NUM -> 201.2
# NUM -> 5.32
# NUM -> 3.25
# NUM -> 299
# NUM -> 349
# NUM -> 1.01
# NUM -> 40.125
# NUM -> 1380000
# NUM -> 7.51
# NUM -> 256000
# NUM -> 2.68
# NUM -> 1400000
# NUM -> 4.49
# NUM -> 49.0
# NUM -> 58
# NUM -> 3.56
# NUM -> 4.03
# NUM -> 2.125
# NUM -> 200
# NUM -> 395000
# NUM -> 173.5
# NUM -> 2.33
# NUM -> 117
# NUM -> 91/2
# NUM -> 12000
# NUM -> 1.31
# NUM -> 527.39
# NUM -> 12500000
# NUM -> 34996.08
# NUM -> 125075
# NUM -> 2.36
# NUM -> 4.0
# NUM -> 12.05
# NUM -> 2.7
# NUM -> 105.2
# NUM -> 395700
# NUM -> 2100
# NUM -> 293.9
# NUM -> 2052.1
# NUM -> 8.03
# NUM -> 206
# NUM -> 21\/32
# NUM -> 0.06
# NUM -> 336
# NUM -> 2.34
# NUM -> 625.4
# NUM -> 127
# NUM -> 22.61
# NUM -> 15.5
# NUM -> 122.7
# NUM -> 348.2
# NUM -> 24.9
# NUM -> 28.375
# NUM -> 4695
# NUM -> 1035000
# NUM -> 60000
# NUM -> 62.7
# NUM -> 1.06
# NUM -> 24.3
# NUM -> 128.19
# NUM -> 2687.53
# NUM -> 1761.0
# NUM -> 403
# NUM -> 438845
# NUM -> 3.46
# NUM -> 2.9428
# NUM -> 141.7
# NUM -> 5.23
# NUM -> 525000
# NUM -> 452.76
# NUM -> 8.328
# NUM -> 0.51
# NUM -> 5.2
# NUM -> 881969
# NUM -> 734.8
# NUM -> 498
# NUM -> 1.08
# NUM -> 4.35
# NUM -> 78.625
# NUM -> 174.5
# NUM -> 99.385
# NUM -> 415.3
# NUM -> 496
# NUM -> 105.4
# NUM -> 268.6
# NUM -> 81.125
# NUM -> 3.26
# NUM -> 26.9
# NUM -> 1996
# NUM -> 14.44
# NUM -> 126630000
# NUM -> 4.32
# NUM -> 416
# NUM -> 422.1
# NUM -> 351.5
# NUM -> 848.7
# NUM -> 700.0
# NUM -> 13.05
# NUM -> 39
# NUM -> 368.5
# NUM -> 2080
# NUM -> 1.44
# NUM -> 44.3
# NUM -> 813
# NUM -> 502
# NUM -> 204
# NUM -> 394
# NUM -> 62.25
# NUM -> 334.5
# NUM -> 141.9
# NUM -> 12.4
# NUM -> 715.1
# NUM -> 9.8
# NUM -> 35544.87
# NUM -> 2.62
# NUM -> 1425035
# NUM -> 1.26
# NUM -> 12.375
# NUM -> 1214
# NUM -> 20.42
# NUM -> vıı
# NUM -> 2057750000
# NUM -> 4830
# NUM -> 208
# NUM -> 3.53
# NUM -> %
# NUM -> 43.5
# NUM -> 15.625
# NUM -> 613.7
# NUM -> 551
# NUM -> 4.7
# NUM -> 1.8415
# NUM -> 1700
# NUM -> 355
# NUM -> 213
# NUM -> 1.5805
# NUM -> 7.9
# NUM -> 15.6
# NUM -> 1.5795
# NUM -> 32.125
# NUM -> 366.85
# NUM -> 675400000
# NUM -> 6.6
# NUM -> 340.7
# NUM -> 34
# NUM -> 4.97
# NUM -> 0.94
# NUM -> 17:00
# NUM -> 268.98
# NUM -> 1.592
# NUM -> 1.55
# NUM -> 430.3
# NUM -> 518.7
# NUM -> 2.19
# NUM -> 54.875
# NUM -> 2.78
# NUM -> 1.5753
# NUM -> 2170
# NUM -> 8.52
# NUM -> 93.75
# NUM -> 224
# NUM -> 1.39
# NUM -> 380
# NUM -> 3.625
# NUM -> 7.52
# NUM -> 01:20
# NUM -> 247.6
# NUM -> 332.38
# NUM -> 1.5775
# NUM -> 1.81
# NUM -> 21.5
# NUM -> 1.16
# NUM -> 225000
# NUM -> 2015
# NUM -> 11.125
# NUM -> 679.5
# NUM -> 0.004
# NUM -> 8.19
# NUM -> 279.8
# NUM -> 1111
# NUM -> 1848000
# NUM -> 52.1
# NUM -> 1200
# NUM -> 3.48
# NUM -> 104
# NUM -> 33.3
# NUM -> 7.7
# NUM -> 8.56
# NUM -> 486.1
# NUM -> 33.375
# NUM -> 873.9
# NUM -> 16.25
# NUM -> 9.671
# NUM -> 588350000
# NUM -> 1.5
# NUM -> 5600
# NUM -> 466
# NUM -> 6.66
# NUM -> 724.4
# NUM -> 7.62
# NUM -> 25.0
# NUM -> 33
# NUM -> 1.9
# NUM -> 95.2
# NUM -> 26000
# NUM -> 580
# NUM -> 2.77
# NUM -> 64
# NUM -> 191.4
# NUM -> 07:13
# NUM -> 515.1
# NUM -> 3.84
# NUM -> 31.4
# NUM -> 2.45
# NUM -> 13.63
# NUM -> 15000
# NUM -> 0.11
# NUM -> 204.8
# NUM -> 1048500000
# NUM -> 650
# NUM -> 395374
# NUM -> 09:38
# NUM -> 194.0
# NUM -> 135860000
# NUM -> 141.45
# NUM -> 366.55
# NUM -> 3.2
# NUM -> 135.6
# NUM -> 73100
# NUM -> 1/32
# NUM -> 833.6
# NUM -> 110000
# NUM -> 89.6
# NUM -> 50.1
# NUM -> 65.53
# NUM -> 582
# NUM -> 1.69
# NUM -> 111.48
# NUM -> 18.6
# NUM -> 8930000
# NUM -> 2613.73
# NUM -> 3425.22
# NUM -> 300000
# NUM -> 135000
# NUM -> 522.3
# NUM -> 623
# NUM -> 0.8
# NUM -> 36.25
# NUM -> 23.65
# NUM -> 39.55
# NUM -> 4346
# NUM -> 37300
# NUM -> 435
# NUM -> 6.76
# NUM -> 9.87
# NUM -> 331.4
# NUM -> 4.199
# NUM -> 129.97
# NUM -> 4.6875
# NUM -> 175.2
# NUM -> 2.91
# NUM -> 2135.5
# NUM -> 42.455
# NUM -> 2.17
# NUM -> 71.36
# NUM -> 527
# NUM -> 6.84
# NUM -> 44.08
# NUM -> 5.42
# NUM -> 869
# NUM -> 5.1
# NUM -> 4.25
# NUM -> 0.37
# NUM -> 110625
# NUM -> 201
# NUM -> 52.5
# NUM -> 279.39
# NUM -> 278.7
# NUM -> 72.6
# NUM -> 1.59
# NUM -> 4.07
# NUM -> 35.28
# NUM -> 99.1875
# NUM -> 4.6
# NUM -> 3.95
# NUM -> 15.8
# NUM -> 2603.48
# NUM -> 248.3
# NUM -> 10.1
# NUM -> 9232
# NUM -> 2.375
# NUM -> 51.65
# NUM -> 0.36
# NUM -> 190.1
# NUM -> 1976
# NUM -> 43.34
# NUM -> 1.22
# NUM -> 20.375
# NUM -> 5.77
# NUM -> 38
# NUM -> 493
# NUM -> 1.255
# NUM -> 975.0
# NUM -> 1.15
# NUM -> 0.14
# NUM -> 1.83
# NUM -> 50000
# NUM -> 106
# NUM -> 13.15
# NUM -> 38.7
# NUM -> 252
# NUM -> 1.19
# NUM -> 478
# NUM -> 1.72
# NUM -> trilyon
# NUM -> 56
# NUM -> 110.4
# NUM -> 105.39
# NUM -> 57.5
# NUM -> 750
# NUM -> 4.66
# NUM -> 981.2
# NUM -> 249.5
# NUM -> 991
# NUM -> 42.9
# NUM -> 45000
# DET -> birçok
# DET -> her
# DET -> birkaç
# DET -> hiçbir
# ADV -> inatla
# ADV -> kilitlen
# ADV -> öylesine
# ADV -> aniden
# ADV -> şimdilik
# ADV -> özenle
# ADV -> sebepsizce
# ADV -> uğruna
# ADV -> ayrıca
# ADV -> yılla
# ADV -> ansızın
# ADV -> anında
# ADV -> üstünkörü
# ADV -> içinde
# ADV -> sessizce
# ADV -> sayıca
# ADV -> ortalamada
# ADV -> beraberinde
# ADV -> zekice
# ADV -> yukarıdan
# ADV -> ayakta
# ADV -> nihayet
# ADV -> kabaca
# ADV -> nereden
# ADV -> adına
# ADV -> nedeniyle
# ADV -> içtenlikle
# ADV -> muhakkak
# ADV -> bana
# ADV -> vasıtasıyla
# ADV -> günlüğüne
# ADV -> katiyen
# ADV -> yüzünden
# ADV -> yüzden
# ADV -> bıçakla
# ADV -> düpedüz
# ADV -> oradan
# ADV -> resmen
# ADV -> tembelce
# ADV -> bundan
# ADV -> nasılsa
# ADV -> saatlerce
# ADV -> ezbere
# ADV -> apaçık
# ADV -> ölümüne
# ADV -> tamamen
# ADV -> pal
# ADV -> bakarak
# ADV -> peki
# ADV -> dikkatle
# ADV -> pekala
# ADV -> tümüyle
# ADV -> esinlen
# ADV -> günde
# ADV -> çoğunlukla
# ADV -> kıkırda
# ADV -> düşüncesizce
# ADV -> kendince
# ADV -> fazlaca
# ADV -> tıpkı
# ADV -> kabilinden
# ADV -> nadiren
# ADV -> sonradan
# ADV -> memnuniyetle
# ADV -> neredeyse
# ADV -> açıkçası
# ADV -> haftaya
# PRON -> hep
# ADV -> bazen
# ADV -> yıllığına
# ADV -> hâlihazırda
# ADV -> böylece
# ADV -> seneye
# ADV -> belki
# ADV -> halihazırda
# ADV -> ille
# ADV -> böylesine
# ADV -> dikine
# ADV -> epey
# ADV -> kısaca
# ADV -> sertleş
# ADV -> geçenlerde
# ADV -> yakından
# ADV -> yukarıda
# ADV -> genelde
# ADV -> yanlışlıkla
# ADV -> yalnızca
# ADV -> şahsen
# ADV -> şimdiden
# ADV -> titizlikle
# ADV -> bize
# ADV -> elbette
# ADV -> doğrusu
# ADV -> sayesinde
# ADV -> acilen
# ADV -> nispeten
# ADV -> şiddetle
# ADV -> cömertçe
# ADV -> tekrardan
# ADV -> özellikle
# ADV -> asla
# ADV -> yolla
# ADV -> gerçi
# ADV -> sabahleyin
# ADV -> kurnazca
# ADV -> zamanında
# ADV -> kısmen
# ADV -> gitgide
# ADV -> rahatlıkla
# ADV -> ölesiye
# ADV -> ileride
# PP -> hem
# ADV -> sabahları
# ADV -> sırasıyla
# ADV -> iken
# ADV -> yerine
# ADV -> tamamıyla
# ADV -> delir
# ADV -> gerçekte
# ADV -> bayağı
# ADV -> dünyada
# ADV -> galiba
# ADV -> fazlasıyla
# ADV -> gayet
# ADV -> üzerine
# ADV -> aylarca
# ADV -> bakımdan
# ADV -> basitçe
# ADV -> dahası
# ADV -> gizlice
# ADV -> başkaca
# ADV -> aynen
# ADV -> sabaha
# ADV -> nereye
# ADV -> kopar
# ADV -> hükmen
# ADV -> nihayetinde
# ADV -> tahminen
# ADV -> boyuna
# ADV -> derinlemesine
# ADV -> üfle
# ADV -> yürekten
# ADV -> kayıtsızca
# ADV -> aracılığıyla
# ADV -> bunda
# ADV -> yakınlarda
# ADV -> haliyle
# ADV -> derhal
# ADV -> gittikçe
# ADV -> başlangıçta
# ADV -> görünmez
# ADV -> maalesef
# ADV -> detaylı
# ADV -> kısacası
# ADV -> yoluyla
# ADV -> basitleş
# ADV -> nitekim
# PP -> oysa
# ADV -> hafifçe
# ADV -> nezdinde
# ADV -> bizzat
# ADV -> aslen
# ADV -> geceleri
# ADV -> yeniden
# ADV -> oraya
# ADV -> üzerinde
# ADV -> baştan
# ADV -> hâlâ
# ADV -> birdenbire
# ADV -> haksızca
# ADV -> alenen
# ADV -> daha
# ADV -> saatinde
# ADV -> lütfen
# ADV -> sonuçta
# ADV -> zaten
# ADV -> esasen
# ADV -> tesadüfen
# ADV -> yağla
# ADV -> sadece
# ADV -> hayretle
# ADV -> kendiliğinden
# ADV -> böylelikle
# ADV -> yanaş
# ADV -> aralıkta
# ADV -> hızla
# ADV -> illa
# ADV -> sonunda
# ADV -> salt
# ADV -> yeterince
# ADV -> umumiyetle
# ADV -> aksine
# ADV -> öylece
# ADV -> sahiden
# ADV -> başlan
# ADV -> doğrul
# ADV -> öncelikle
# ADV -> eskiden
# ADV -> nerede
# ADV -> keşke
# ADV -> derinden
# ADV -> ardından
# ADV -> tersine
# ADV -> çabucak
# ADV -> sanki
# ADV -> giderek
# ADV -> pek
# ADV -> kasten
# ADV -> bilhassa
# ADV -> burada
# ADV -> birazcık
# ADV -> pahasına
# PP -> ancak
# ADV -> ondan
# ADV -> uyarınca
# ADV -> kesinlikle
# ADV -> zarfında
# ADV -> delikanlı
# ADV -> bakımından
# ADV -> münhasıran
# ADV -> muhtemelen
# ADV -> çoktan
# ADV -> orada
# ADV -> sürekli
# ADV -> sana
# ADV -> hesabına
# ADV -> birden
# ADV -> fiilen
# ADV -> zararına
# ADV -> yanında
# ADV -> genellikle
# ADV -> mutlaka
# ADV -> daima
# ADV -> ustalıkla
# ADV -> direkt
# ADV -> hemen
# ADV -> kaygısızca
# ADV -> çalkala
# ADV -> aslında
# ADV -> şimdilerde
# PP -> hatta
# ADV -> adeta
# ADV -> derhâl
# ADV -> halen
# ADV -> hala
# ADV -> kolaylıkla
# ADV -> çılgınca
# ADV -> iyice
# ADV -> yakında
# ADV -> süresince
# ADV -> çaresizce
# ADV -> yine
# ADV -> gerçekten
# ADV -> önceden
# ADV -> dolayısıyla
# ADV -> ilaveten
# ADV -> işte
# ADV -> ortaklaşa
# ADV -> mesela
# ADV -> henüz
# ADV -> tesadüfi
# ADV -> esnasında
# ADV -> külliyen
# ADV -> oldukça
# ADV -> bugünlerde
# ADV -> kendinden
# ADV -> yavaşça
# ADV -> etraflıca
# PP -> yanısıra
# PP -> nazaran
# PP -> dair
# PP -> takdirde
# PP -> ötürü
# PP -> istinaden
# PP -> evvel
# PP -> göre
# PP -> rağmen
# PP -> boyunca
# PP -> aşkın
# PP -> takiben
# PP -> ile
# PP -> karşın
# PP -> üzere
# PP -> dolayı
# PP -> yana
# PP -> diye
# PRON -> birbiri
# PRON -> sen
# PRON -> hepsi
# PRON -> diğeri
# PRON -> nere
# PRON -> kendi
# PRON -> siz
# PRON -> birbirleri
# PRON -> tümü
# PRON -> hiçbiri
# PP -> olsun
# PP -> ve
# PP -> örneğin
# PP -> gerekse
# PP -> yoksa
# PP -> ama
# PP -> neyse
# PP -> da
# PP -> dahi
# PP -> zira
# PP -> ister
# PP -> çünkü
# INTJ -> ya
# PP -> fakat
# PP -> yani
# PP -> vb
# PP -> ila
# PP -> şayet
# PP -> vs
# PP -> veya
# AUX -> değil
# AUX -> mi
# X -> %3.5
# X -> %7.875
# X -> %8.01
# X -> 21:00-22:30
# X -> %83
# X -> tefek
# X -> %7.986
# X -> %95
# X -> %8.2
# X -> derli
# X -> %17
# X -> 89-107
# X -> @
# X -> %11.3
# X -> %9.5
# X -> allak
# X -> %7.01
# X -> %7.88
# X -> %24
# X -> %6.90
# X -> 2-3
# X -> %9.4
# X -> 3-4
# X -> 1989-86
# X -> 20-21
# X -> %99
# X -> 1989-1
# X -> %61
# X -> %6.8
# X -> 13:30-18:00
# X -> %1.9
# X -> 1989-85
# X -> %9.39
# X -> _
# X -> %14
# X -> 4-5
# X -> %7.10
# X -> %3.4
# X -> %9.90
# X -> %8.61
# X -> %3.846
# X -> %7.53
# X -> 89-136
# X -> %1
# X -> %10.48
# X -> 1997-2000
# X -> 2-23
# X -> %2.9
# X -> 1962-63
# X -> %4.8
# X -> %25
# X -> %6.5
# X -> 1995-1999
# X -> %0.25
# X -> %18
# X -> %3.75
# X -> 1991-1996
# X -> %7.6
# X -> %7.52
# X -> %0.3
# X -> %5.2
# X -> %46
# X -> %10.03
# X -> 5-10
# X -> %7
# X -> %1.4
# X -> %6.4
# X -> %3.43
# X -> 800-900
# X -> %9.6
# X -> %3.9
# X -> %3.1
# X -> 231-191
# X -> %8
# X -> %60
# X -> %65
# X -> %7.92
# X -> %68
# X -> 14-16
# X -> %7.73
# X -> ışıl
# X -> %6
# X -> 22-23
# X -> %69
# X -> %19
# X -> %4.4
# X -> %85
# X -> %27.1
# X -> %3.3
# X -> %3.865
# X -> %44
# X -> 747-400
# X -> %6.15
# X -> %51.4
# X -> 1989-1987
# X -> %99.1875
# X -> %16
# X -> %7.55
# X -> 21-23
# X -> 89-52
# X -> %11
# X -> %2.7
# X -> %3.7
# X -> %9.19
# X -> %8.42
# X -> %0.2
# X -> %7.82
# X -> %5.4
# X -> dobra
# X -> %4
# X -> %8.9
# X -> %1.7
# X -> %2.45
# X -> %36
# X -> %9.617
# X -> %37
# X -> 2003-2005
# X -> 5-12
# X -> 20-23
# X -> %0.32
# X -> %0.5
# X -> tokuş
# X -> 1989-83
# X -> %5.3
# X -> bullak
# X -> 1982-85
# X -> %13
# X -> %7.71
# X -> %22
# X -> %80
# X -> 1989-84
# X -> %2
# X -> %12
# X -> %8.292
# X -> %51
# X -> %7.31
# X -> %7.227
# X -> 1991-1992
# X -> %4.7
# X -> %7.78
# X -> %7.75
# pp -> ki
# INTJ -> oh
# INTJ -> yaşasın
# INTJ -> hadi
# INTJ -> aman
# INTJ -> ah
# INTJ -> e
# INTJ -> haydi
# INTJ -> ha
# INTJ -> vay
# INTJ -> of
# INTJ -> eh

# %%
for line in lines.split("\n"):
    print(line)
# Out:
# ###### PAST TENSE ######
# ########################
# # Pronoun, Verb+past
# S -> PRO1 VPPAST1
# S -> PRO2 VPPAST2
# S -> PRO3 VPPAST3
#
# # NounPhrase, Verb+past
# S -> NP VPPAST1
# S -> NP VPPAST2
# S -> NP VPPAST3
#
# # PronounClause(Pronoun + NounPhrase), Verb+past
# S -> PRONOUNCLAUSE1 VPPAST1
# S -> PRONOUNCLAUSE2 VPPAST2
# S -> PRONOUNCLAUSE3 VPPAST3
#
# VPPAST1 -> VP PAST1
# VPPAST2 -> VP PAST2
# VPPAST3 -> VP PAST3
#
# ###### PRESENT TENSE ######
# ###########################
# # Pronoun, Verb+present
# S -> PRO1 VPPRE1
# S -> PRO2 VPPRE2
# S -> PRO3 VPPRE3
#
# # NounPhrase, Verb+present
# S -> NP VPPRE1
# S -> NP VPPRE2
# S -> NP VPPRE3
#
# # PronounClause(Pronoun + NounPhrase), Verb+present
# S -> PRONOUNCLAUSE1 VPPRE1
# S -> PRONOUNCLAUSE2 VPPRE2
# S -> PRONOUNCLAUSE3 VPPRE3
#
# VPPRE1 -> VP PRE1
# VPPRE2 -> VP PRE2
# VPPRE3 -> VP PRE3
#
# ###### FUTURE TENSE ######
# ##########################
# # Pronoun, Verb+future
# S -> PRO1 VPFUT1
# S -> PRO2 VPFUT2
# S -> PRO3 VPFUT3
#
# # NounPhrase, Verb+future
# S -> NP VPFUT1
# S -> NP VPFUT2
# S -> NP VPFUT3
#
# # PronounClause(Pronoun + NounPhrase), Verb+future
# S -> PRONOUNCLAUSE1 VPFUT1
# S -> PRONOUNCLAUSE2 VPFUT2
# S -> PRONOUNCLAUSE3 VPFUT3
#
# VPFUT1 -> VP FUT1
# VPFUT2 -> VP FUT2
# VPFUT3 -> VP FUT3
#
# ###### MISC ######
# ##################
# # Pronoun, NounPhrase+Suffix
# S -> PRO1 NP POSPRO1
# S -> PRO2 NP POSPRO2
# S -> PRO3 NP POSPRO3
#
# NP -> NP POSPRO1
# NP -> NP POSPRO2
# NP -> NP POSPRO3
#
# # Pronoun + NounPhrase
# PRONOUNCLAUSE1 -> PRO1 NP
# PRONOUNCLAUSE2 -> PRO2 NP
# PRONOUNCLAUSE3 -> PRO3 NP
#
# S -> NP VP PREPARTICLE
#
# NP -> ADJ NP
# NP -> ADJ NP PL
# NP -> ADJ SING NP
# PLNOUN -> NP PL
# SINGNP -> SING NP
# NP -> SING ADJ NP
# ADJCLAUSE -> ADJ NP
# NP -> NP PL
# NP -> NP NP
# NP -> NP PP
# ADJ -> ADJ ADJ
# VP -> ADV NP VP
# NPVP -> NP VP
# VP -> ADV VP
# VP -> QP VP
# QP -> Q NP
#
# QCLAUSE1 -> Q POSPROPL1
# QCLAUSE2 -> Q POSPROPL2
# QCLAUSE3 -> Q POSPROPL3
#
# Q -> mı
# Q -> mi
# Q -> ne
#
# PRO1 -> ben
# PRO2 -> sen
# PRO3 -> o
# PROPL1 -> biz
# PROPL2 -> siz
# PROPL3 -> onlar
# PAST3 -> ydi
# PAST3 -> tı
# PAST3 -> du
# PAST3 -> tu
# PAST3 -> ydı
# PAST3 -> dü
# PAST3 -> tü
# PAST3 -> ydu
# PAST3 -> dı
# PAST3 -> ydü
# PAST3 -> di
# PAST3 -> ti
# PAST3 -> medi
# PAST3 -> madı
# PRE1 -> iyor
# PRE1 -> ıyor
# PRE1 -> yor
# FUT1 -> eceğim
# PAST1 -> dım
# PAST1 -> dum
# PAST1 -> dim
# PAST1 -> tım
# PAST1 -> dük
# PAST1 -> dık
# PAST1 -> dik
# FUT3 -> yecek
# PAST3 -> emediler
# FUT3 -> ecektir
# FUT1 -> meyeceğiz
# FUT3 -> meyecek
# FUT3 -> mayacak
# PRE1 -> mıyorlar
# PRE1 -> miyor
# PAST3 -> tiler
# PAST3 -> dılar
# PAST3 -> rdı
# FUT3 -> meyecekler
# PRE2 -> maktadır
# PAST3 -> mişti
# PAST3 -> mıştı
# PRE2 -> mekte
# PAST2 -> din
# PAST1 -> iyordu
# PRE1 -> ıyorum
# PAST2 -> dunuz
# PRE1 -> yorlar
# PRE1 -> ıyorlar
# PRE1 -> ıyorsunPOSPRO1 -> m
# POSPRO1 -> üm
# POSPRO1 -> ım
# POSPRO1 -> yım
# POSPRO1 -> i
# POSPRO1 -> um
# POSPRO1 -> yim
# POSPRO1 -> yum
# POSPRO1 -> im
# POSPROPL1 -> yiz
# POSPROPL1 -> yüz
# POSPROPL1 -> ız
# POSPROPL1 -> üz
# POSPROPL1 -> yuz
# POSPROPL1 -> iz
# POSPROPL1 -> yız
# POSPROPL1 -> lım
# POSPROPL1 -> uz
# POSPROPL1 -> k
# POSPRO2 -> sin
# POSPRO2 -> s
# POSPRO2 -> ı
# POSPRO2 -> n
# POSPRO2 -> sun
# POSPRO2 -> sın
# POSPROPL2 -> yin
# POSPROPL2 -> ın
# POSPROPL2 -> nüz
# POSPROPL2 -> siniz
# POSPROPL2 -> niz
# POSPROPL2 -> sınız
# POSPROPL2 -> ı
# POSPROPL2 -> n
# POSPROPL2 -> nız
# POSPROPL2 -> sunuz
# POSPROPL2 -> nuz
# POSPRO3  -> ı
# POSPRO3  -> s
# POSPRO3  -> n
# POSPRONPL3  -> ler
# POSPRONPL3  -> r
# POSPRONPL3  -> lar
# POSPRONPL3  -> l
# POSPRONPL3  -> a
# NP -> 35-uluslu
# NP -> bakiye
# NP -> amerikalı
# NP -> broncs
# NP -> ikmal
# VP -> mahvet
# NP -> istirham
# VP -> yer
# NP -> yıkama
# NP -> üstün
# VP -> dosyala
# VP -> hafta
# NP -> raslantı
# NP -> link
# NP -> 508-puanlık
# NP -> ala
# NP -> pens
# NP -> defter
# NP -> muharebe
# NP -> kürek
# NP -> sonat
# NP -> dedikodu
# NP -> adliye
# NP -> hazırlık
# NUM -> 3.69
# NP -> teknik
# NP -> pompa
# VP -> seç
# NP -> karakteristik
# NP -> dük
# NP -> havaliman
# NP -> kasti
# NP -> anti
# NP -> topaz
# NP -> külfet
# NP -> masum
# VP -> bayi
# VP -> adım
# NP -> gelgit
# NP -> gümrükle
# NP -> evreleme
# NP -> tüvit
# NUM -> 1990
# NP -> söyledi.
# NP -> bonus
# NP -> dün
# NP -> dernek
# NP -> şişe
# NP -> belirtilen
# NP -> 197
# NP -> barınak
# VP -> ek
# NP -> 7.875,
# NP -> şaşkınlık
# NP -> nabız
# NP -> conta
# VP -> güç
# VP -> karar
# NP -> söylerimleyle
# NP -> ateş
# NP -> casusluk
# VP -> rakip
# NP -> kolajen
# NP -> selef
# NP -> parıltı
# VP -> sınır
# NP -> parola
# NP -> aksiyom
# NP -> açım
# NP -> terminal
# NP -> onkogenler
# NP -> kapitone
# VP -> hat
# NP -> kuruş
# NP -> hekim
# NP -> 821
# VP -> üstlen
# NP -> kârın
# NP -> doğum
# NP -> teslim
# NP -> somatostatin
# NP -> karyola
# NP -> uzatma
# NP -> yılbaş
# NP -> müteahhit
# NUM -> 1980
# VP -> zarar
# VP -> dil
# NP -> ideal
# NP -> 1890
# NP -> umar
# NP -> tercüman
# NP -> vaat
# NP -> mahsul
# NP -> filo
# NP -> yağmala
# VP -> destek
# NP -> güneş
# NP -> darma
# NP -> 455
# VP -> alt
# NP -> istila
# NP -> tantana
# NP -> kumaş
# NP -> ihtiva
# NP -> aslan
# NP -> başkaldır
# VP -> taşı
# VP -> kır
# NP -> b
# NP -> anlayış
# NP -> ağır
# NP -> süreçin
# NP -> katalog
# NP -> aleyh
# NP -> 123.5
# NP -> zorlama
# NP -> muğlaklık
# NP -> doktrin
# NP -> dizel
# NP -> lise
# NP -> oyalayıcı
# NP -> mermi
# NP -> bilet
# NP -> 'inc.,
# NP -> 49-uluslu
# NP -> türk
# NP -> yaşan
# VP -> sabit
# NP -> komisyoncu
# NP -> isteksiz
# NP -> oturum
# NP -> 2890
# NP -> gündüz
# NP -> 368
# NP -> radyasyon
# NP -> boykot
# NP -> rota
# NP -> ​​ayarlamak
# NP -> 414
# VP -> ilk
# NP -> kalorifer
# VP -> yol
# NP -> eşdeğerlik
# NP -> franchise
# NP -> kuzen
# NP -> aks
# NUM -> ikinci
# NP -> riyakarlık
# NP -> tecrit
# NP -> ayak
# NP -> makbuz
# NP -> hakaret
# NP -> ikonoklastik
# NP -> kayarak
# NP -> leh
# NP -> kesimhane
# NP -> vaha
# NP -> kılıç
# NP -> eldiven
# NP -> yönerge
# NP -> inç
# NP -> kazı
# NP -> eklenti
# NP -> boğmaca
# NP -> 23-5'lik
# NP -> değişim
# NP -> orman
# NP -> 2653.28
# NP -> teşviki
# NP -> asalet
# NP -> yanlışlık
# NP -> alay
# NP -> gözetle
# NP -> kovalamaca
# NP -> doğruluk
# VP -> öngör
# NUM -> 7.93
# NP -> ons'luk
# NP -> piyasısı
# NP -> uyuştur
# NP -> esinti
# VP -> yaka
# NP -> plastik
# NP -> var.
# NP -> orkestra
# NP -> kontra
# VP -> baba
# VP -> öde
# VP -> koca
# VP -> yüzleş
# NP -> çöp
# NP -> onarım
# NP -> ikame
# VP -> çarp
# NP -> kısas
# NP -> gözalt
# VP -> bil
# NP -> matine
# NP -> göl
# NP -> italyan
# NP -> babaerkil
# NP -> dargınlık
# VP -> kara
# NP -> çamur
# NP -> saygıdeğer
# VP -> doğ
# NP -> alıcılar'
# NP -> domine
# NP -> metal
# NP -> kırılgan
# NP -> akvaryum
# NP -> teveccüh
# NUM -> 43
# NP -> tekamül
# NP -> %70
# NP -> soylu
# VP -> rafine
# NP -> deforme
# NP -> lüks-araba
# NP -> km
# NP -> soğut
# NP -> nohut
# NP -> ingiliz
# VP -> incele
# NP -> dip
# NP -> 7.22
# VP -> şaşır
# NP -> gayrimenkuldeydi
# VP -> alıntı
# NP -> tat
# NP -> mobilya
# NP -> %10.3'ünü
# NP -> ayna
# NP -> inziva
# NP -> çalın
# NP -> salon
# NP -> sempati
# NUM -> 1959
# NP -> bilge
# NP -> kobay
# NP -> bebeklik
# NP -> bina
# NP -> 130.80
# NP -> köylü
# NP -> ince
# NP -> bacak
# VP -> kapat
# NP -> üstünlük
# VP -> sahte
# NP -> seramik
# NP -> jaguar
# NP -> applause
# NP -> diyabetik
# NP -> cin
# NP -> metafor
# NP -> patika
# NP -> kösteklen
# NP -> ifade
# NP -> çağırılan
# NP -> yoğunluk
# NP -> dost
# NP -> davetiye
# NP -> şablon
# NP -> davet
# NP -> fıkra
# NP -> 1190.43
# NP -> keman
# NP -> merdiven
# NP -> genç
# NP -> fabrika
# NP -> ispanyol
# NP -> sistem
# NP -> taze
# NP -> artçı
# NP -> alçı
# NP -> antibiyotik
# VP -> yük
# NP -> manipülatif
# NP -> mayala
# NP -> pohpohla
# NUM -> 7.89
# VP -> ekle
# VP -> göster
# NP -> hiç
# NP -> birik
# NP -> brokerları
# NP -> hüsran
# NP -> akrelik
# NP -> vezin
# NP -> gayrimenkuller
# NP -> sonra
# NP -> leke
# NP -> resesyon
# VP -> kelime
# NP -> basmakalıp
# VP -> gerile
# NP -> göz
# NP -> klinik
# NP -> panama
# NP -> avantacı
# NUM -> 13
# NP -> ekipman
# NUM -> 61
# NP -> izlenim
# NP -> bolluk
# NP -> %20'lik
# NP -> tasarlanmıştır.
# NP -> 120-günlük
# NP -> f
# NP -> ot
# NP -> türbin
# NP -> yassı
# NP -> prospektüs
# NP -> varyasyon
# NP -> anti-tröst
# NP -> antika
# VP -> sok
# NP -> dehşet
# NP -> analizci
# NP -> anahtar
# VP -> garantile
# NP -> özelleştirme
# NP -> burbonudur
# VP -> bağlı
# NP -> dayak
# NP -> kakao
# NP -> simsarlık
# NP -> yoksunluk
# NP -> bulaş
# NP -> gerçeklik
# NP -> 4440
# NP -> yıprat
# NP -> milliyetçi
# NP -> köşe
# NP -> öncül
# NP -> mercek
# NP -> ödeme
# NP -> platform
# NP -> fiyat/kazanç
# NP -> tahammül
# VP -> ilerle
# NP -> gayri
# NP -> dansçı
# NP -> eyalet
# NP -> 18.125
# NP -> alamet
# NP -> dudak
# VP -> sırala
# NP -> çimenlik
# VP -> oluş
# NP -> şimdiye
# VP -> mal
# NP -> 445.23
# NP -> 382
# NP -> protokol
# NP -> yaşam
# NP -> iyi.
# NP -> eziyet
# NP -> le
# NP -> diz
# VP -> aşama
# NP -> damga
# NP -> saygı
# NP -> un
# NP -> şömine
# NP -> feda
# NP -> rüşvet
# NP -> temas
# NP -> bağlam(lar)ında
# NP -> bağımsız
# NP -> odak
# NP -> moda
# NP -> alet
# NP -> gelen
# NP -> kumarhane
# NP -> antitröst
# NP -> vızıltı
# NP -> ,10:30-13:30
# NP -> tahmini
# NP -> teşvik
# NP -> hücum
# NP -> mercan
# NP -> ideolog
# NP -> implantasyon
# NP -> bunalım
# NP -> öğretmen
# NP -> devrimci
# NP -> oynaklık
# NP -> %6.25
# NP -> meraklı
# NP -> gözde
# NP -> iletken
# NP -> cila
# NP -> şerefiye
# NP -> deri
# NP -> gözdağ
# NP -> yumruk
# VP -> kastet
# NP -> elektrik
# NP -> benzerlik
# NP -> site
# NP -> ümit
# NP -> ekran
# NP -> beylik
# NP -> hayvan
# VP -> ön
# NP -> saye
# NP -> 3.çeyreğinde
# NP -> indeks
# NP -> füzyon
# NP -> lisanslama
# VP -> yoğun
# NP -> ambalaj
# VP -> yar
# NP -> örüntü
# NP -> müslüman
# NP -> kapama
# VP -> çağrı
# NP -> reklamverenlerle
# NP -> ehliyet
# NP -> malpraktis
# NP -> 2.659.22
# NP -> konserve
# NP -> işbirliğiden
# NP -> kârına
# NP -> alışkan
# NP -> dava
# NP -> olasılık
# NP -> broker-bayi
# NP -> adaylık
# VP -> diktatör
# NUM -> 47
# NP -> eksi
# NP -> taahhüt
# NP -> diyor.
# NP -> 130.73
# NP -> yumurta
# NP -> borsacı
# NP -> franchiselarınız
# NP -> balistik
# NP -> amortisman
# NP -> çoğalıyor.
# NP -> 130.36
# NP -> kopya
# NP -> tutanak
# NP -> aracı-bayi
# NP -> tank
# NP -> sanayici
# NP -> hareketsizlik
# NP -> 1975
# NP -> saçık
# NP -> makineli
# NP -> 1978
# NP -> lanet
# NP -> pasaport
# NP -> genel
# NP -> kurultay
# NP -> sigortalı
# NP -> (mpi)'dır
# VP -> birleş
# NP -> masaj
# NP -> erkek-verimli
# NP -> asıl
# NP -> havayol
# NP -> harici
# NP -> jumbos
# NUM -> 7.25
# NP -> kayalık
# NP -> abd
# NP -> %40'ından
# NP -> tedirgin
# NP -> yönetmenlik
# NP -> talip
# NP -> içerik
# NP -> yıldönüm
# NP -> 131.64'de
# VP -> değ
# NP -> kıpırtı
# NP -> gazetecilik
# NP -> hakim
# NP -> %52'sini
# NP -> 74.125
# NP -> perşembe
# VP -> genişlet
# NP -> ucube
# NP -> partner
# NP -> teknisyen
# NP -> 00.01
# VP -> patla
# VP -> kurul
# NP -> nakliye
# NUM -> 22
# NP -> itfaiyeci
# NP -> sağlama
# NP -> product
# NP -> teşvikinin
# NP -> müdafi
# VP -> yatış
# NP -> anlam
# NP -> birmingham
# NP -> yayılma
# VP -> süreç
# NP -> lokanta
# NP -> kısıntı
# NP -> türban
# NP -> ekspres
# NP -> ihraççıları
# NP -> bitim
# NP -> %70'inden
# NP -> verecek
# NP -> liyakat
# NP -> gözbebeğimiz
# VP -> sebep
# VP -> orta
# NP -> bataklık
# NP -> sertifikasyon
# VP -> iyimser
# VP -> emir
# NP -> konteyner
# NP -> hacmi-testi
# NP -> tahsil
# NP -> ayçiçek
# NP -> kardeş
# VP -> açık
# NP -> dank
# NP -> gecikme
# NP -> küpe
# NP -> itiraf
# NP -> pekiş
# NP -> hasır
# NP -> anti-damping
# NP -> kovboy
# NP -> aksilik
# NP -> boğa
# NP -> oda
# VP -> boğ
# NP -> kulüp
# NP -> makinelerininin
# NP -> alım-satıma
# NP -> katılan
# NP -> akis
# NP -> ilahiyatçı
# NP -> federasyon
# NP -> düzenleme
# NP -> hayal
# NP -> diğer
# VP -> performans
# VP -> gerileme
# NP -> atasöz
# NP -> manşet
# NP -> çelik
# NUM -> 48
# NP -> kürkçü
# NP -> ihmal
# NP -> ittifak
# NP -> duruşma
# NP -> hacim
# NP -> hurdalık
# NP -> aylık
# NP -> inkar
# NP -> rıza
# NP -> basınç
# NP -> müphem
# NP -> ironik
# VP -> miktar
# NP -> savcılık
# NP -> keçi
# NUM -> 2645.08
# NUM -> 54
# NP -> kozmetik
# NP -> icracı
# NP -> kargo
# NP -> moral
# NP -> kaygı
# NP -> ünite
# NP -> ayrımcılığı
# NP -> food
# NP -> kılıf
# NP -> monte
# NP -> mükellef
# NP -> yazılı
# VP -> konuş
# NP -> rehin
# VP -> komisyon
# NP -> mesai
# NP -> gıda
# NP -> 20-hisseli
# VP -> doğru
# NP -> maç
# NP -> fuar
# NP -> soğukluk
# VP -> yavaşla
# NP -> zorluk
# NP -> müracaat
# NP -> turizm
# NUM -> 1\/8
# NP -> peşinat
# NP -> imtiyaz
# NP -> eğer
# NP -> ant
# NP -> çip
# VP -> pazarla
# NP -> psikanaliz
# NP -> ball
# NP -> giyim
# NP -> anapara
# VP -> yetiştir
# NP -> çekiş
# NP -> işgücü
# NP -> lisanslamayla
# NP -> zihin
# NP -> belirti
# NP -> akor
# NP -> lübnanlı
# NP -> global
# NP -> depo
# NP -> denizci
# NP -> teamül
# NP -> maymun
# NP -> karpit
# NP -> 5.651
# NP -> darbe-kuvveti
# NP -> flört
# NP -> sukunet
# NP -> kepenk
# NP -> poz
# NP -> varis
# NP -> tek-a
# NP -> and
# VP -> yatak
# NP -> kışın
# NP -> rampa
# NP -> ayı
# NP -> sayfa
# NP -> kararname
# NP -> propogandayı
# NP -> ihracat
# NP -> 16:30
# NP -> buzdolaplarını
# NP -> rating
# VP -> sev
# NP -> özür
# NP -> söyleşi
# NP -> saldırma
# NP -> emperyal
# NP -> hurda
# NP -> psilyumu
# NP -> yeryüz
# NP -> 1960'da
# NP -> garip
# NP -> evrak
# NP -> biriktir
# NP -> lastik
# NP -> ananas
# NP -> eleştiri
# NP -> içindekiler
# NP -> lider
# NP -> ergenlik
# NP -> eğitmen
# NP -> acentelik
# NP -> başkanlık
# NP -> insanoğlu
# NP -> yurt
# VP -> uç
# NP -> alım-satımına
# NP -> %30
# NP -> dinlen
# VP -> al
# NP -> pachinko
# NP -> ihtimal
# NP -> toynak
# VP -> önemse
# NP -> yapılandırma
# NP -> hissedarlıklara
# NP -> egemenlik
# NP -> konsorsiyum
# NP -> dr.
# NP -> gittikça
# VP -> sonlan
# NP -> proaktif
# VP -> girişimcilik
# NP -> rahibe
# VP -> temizle
# NP -> sırt
# NP -> amir
# NP -> muhafaza
# NP -> dayanıklılık
# NP -> toy
# NP -> yanlılık
# NP -> işbirliği
# NP -> katılımcı
# VP -> kategori
# NP -> %15'ini
# NP -> imal
# NP -> sürüklen
# NP -> hücre
# NP -> arzet
# NP -> canlılık
# NP -> yelpaze
# NUM -> 6
# VP -> giy
# NP -> %51'ini
# NP -> öngören/savunan
# NP -> çıkarma
# NP -> are
# NP -> tahsilat
# NP -> 936
# NP -> 1730
# NP -> gezin
# VP -> yerleştir
# NP -> saygısız
# VP -> çılgınlık
# NP -> disiplin
# NP -> faz
# VP -> başkan
# NP -> ispat
# NP -> ciddi
# VP -> öte
# NP -> büyüklük
# NP -> tüzük
# NP -> üniversite
# NP -> ifa
# NP -> ithalat-ihracat
# NUM -> 1.6055
# VP -> top
# NP -> jogging
# VP -> kay
# NP -> müzayede
# NP -> esna
# NP -> kardiyovasküler
# NP -> blok
# NP -> çit
# NP -> volatilite
# NP -> suitindeki
# NP -> şahit
# NP -> tadil
# NP -> tartma
# NP -> oksit
# NP -> eylemci
# VP -> yanlış
# VP -> danış
# NP -> batak
# NP -> bilim
# NP -> nadas
# NUM -> 1997
# VP -> hoşlan
# NP -> itaat
# VP -> çiz
# NP -> konjonktür
# NP -> tüketim
# NP -> muhafazakar
# NP -> ortadirek
# VP -> görünüm
# NP -> yarışmacı
# VP -> yaklaş
# NP -> tuğla
# NP -> işlev
# NP -> bilgilen
# NP -> dolaşım
# NP -> ekmek
# NP -> bir-paya-300
# VP -> baskıla
# VP -> çiftçi
# NP -> delegasyon
# NP -> yurtdışında
# NP -> psilyum
# NP -> bekleme
# NP -> çete
# NP -> tecrübe
# NUM -> 1\/2
# NP -> depresyon
# NP -> pamuk
# NP -> misyon
# NP -> yapım
# VP -> ödül
# NP -> endüstri
# VP -> çevir
# NP -> debelen
# NP -> olgunluk
# NP -> tatilci
# NP -> itele
# NP -> kelebek
# VP -> özel
# NP -> opera
# NP -> yıkı
# VP -> başarı
# NP -> şaşkın
# NP -> dar
# NP -> votka
# NP -> grip
# VP -> düzen
# VP -> yöntem
# NP -> serbestleş
# NP -> armadillo
# NP -> cevher
# NP -> kral
# VP -> tırman
# NP -> dans
# NP -> konser
# VP -> öl
# NP -> ayrıldı?
# NP -> %12'lik
# NP -> uyarlama
# NP -> üstelik
# NP -> mücadele
# NP -> yurtdışı
# NP -> gazi
# NUM -> 2005
# VP -> uğraş
# NP -> 84
# NP -> özsermaye
# NP -> buğday
# NP -> evet
# NP -> kote
# NP -> oy
# VP -> pazarlan
# NP -> birçoğuyle
# NP -> tereyağ
# NP -> endeksle
# VP -> karmaşık
# NP -> etiket
# NP -> 2638.73
# NP -> boya
# NP -> aktris
# NP -> bozgun
# VP -> sayfala
# NP -> temel
# NP -> kârlar
# NP -> ​​otomobil
# NP -> tişört
# NP -> telekomünikasyon
# NP -> motor
# NP -> baskın
# NP -> 30-pay
# VP -> tetik
# NP -> kanım
# NP -> seleksiyon
# NP -> şizofreni
# NP -> broşür
# NP -> d'alene
# NP -> 470'den
# NP -> fiber
# NP -> hâlihazır
# NP -> dayat
# NP -> kuşatma
# NP -> 60-gün
# NP -> empoze
# NP -> ilham
# NP -> 378.07
# VP -> iş
# NP -> hırpala
# NP -> tamir
# NP -> dert
# NP -> 10.13
# NP -> klorin
# NP -> felsefik
# NP -> karnaval
# NP -> master
# NP -> mola
# NP -> deyiş
# NP -> pediyatrik
# NP -> boru
# NP -> ficus
# NP -> geçme
# NP -> akçe
# VP -> sürükle
# NP -> silikon
# NP -> mülayim
# NUM -> 1991
# NP -> siper
# NP -> intihar
# NP -> dikkat
# NP -> a.m
# NP -> özellik
# NP -> kâr
# VP -> çatla
# VP -> üretici
# NP -> beden
# NP -> kylix
# NP -> fransız
# NP -> törpü
# NP -> 10.98
# NP -> sonbahar
# NP -> kaçık
# VP -> kuşku
# NP -> 4.çeyrekteki
# NP -> büyücülük
# NP -> gayrimenkule
# NUM -> 4
# NP -> enflasyon
# NP -> kaplama
# NP -> aksama
# NP -> punt
# NP -> uzmanlaş
# VP -> uğrat
# NP -> rapor
# NP -> tuz
# NP -> ''dedi
# NP -> polemik
# NP -> hayret
# NP -> taktik
# NP -> podyum
# NP -> içerdekilerin
# NP -> yatıştır
# VP -> kapasite
# NP -> şövalye
# NP -> cevap
# NP -> c
# NP -> avantaj
# NP -> stopaj
# NUM -> 1977
# NP -> arayış
# NP -> var:
# VP -> kent
# NP -> klasik
# VP -> satıl
# NP -> 3m'in
# NP -> bezybol
# NP -> dogs
# VP -> nokta
# NUM -> 289
# NP -> alkışlama
# NP -> pekin
# NP -> gasp
# VP -> cins
# VP -> koşul
# NP -> üyelik
# NP -> 1739.3
# NP -> merci
# NP -> davalı
# NP -> eczane
# NP -> kıyı
# NP -> gösteri
# NP -> kuzeybatı
# VP -> kanıtla
# VP -> büyük
# NP -> pizza
# NP -> %7.20
# NP -> 132,8
# VP -> acı
# NP -> şema
# VP -> harca
# NP -> taksi
# NP -> kanat
# NP -> form
# NP -> ayin
# NUM -> üç
# NP -> blues
# NP -> gala
# NP -> bürokrasi
# NP -> kanal
# NP -> öğreneceğim.
# NP -> karşıt
# NUM -> 1972
# NUM -> 7.92
# NP -> topçu
# NP -> eşitsizlik
# NP -> retinoblastoma
# NP -> menfaat
# NP -> şükür
# NP -> inşaa
# VP -> teklif
# NP -> palamedes
# NP -> madalya
# NP -> kek
# NP -> otobüs
# NP -> zift
# NP -> aerobik
# NP -> yemek
# VP -> felaket
# NP -> fırsatçı
# VP -> yetkili
# NP -> eser
# NP -> ömür
# NP -> ayrıntılrı
# NP -> sarsıntı
# NP -> ambargo
# NP -> %8.17'lik
# VP -> dur
# NP -> saldırganları
# NP -> kornea
# NP -> erken
# NP -> %9.9'luk
# NP -> özkaynak
# NP -> dizginle
# NP -> 951
# VP -> normal
# NP -> krem
# NP -> dün`''
# NP -> dürüst
# NP -> yaşlan
# NP -> kurban
# NP -> albeni
# NP -> nevi
# NP -> hafif
# NP -> 100-paylık
# NP -> uğrak
# NP -> elitistleri
# NP -> çekilme
# NP -> bakımev
# NP -> %50
# NP -> 7/8'ye
# NP -> şikâyet
# NP -> asker
# NP -> cumhurbaşkan
# NP -> büyükbaba
# NP -> kanama
# NP -> puan
# VP -> çoğal
# NP -> süt
# NP -> sefalet
# NP -> kart
# VP -> asistan
# NP -> realite
# NP -> bağnaz
# NP -> kayak
# NP -> tarikat
# NP -> bide
# NP -> sakınca
# NP -> mil
# NP -> nişan
# NP -> rejim
# VP -> tedarikçi
# NUM -> 1.7
# NP -> talimat
# VP -> yaygınlaş
# NUM -> 27.5
# NP -> gsmh
# NP -> vasıta
# VP -> yara
# VP -> yık
# NP -> 0.0015
# NP -> 3/4'den
# NP -> sözleş
# NP -> itibar
# NP -> ruhsat
# NP -> öncü
# NP -> zig-zag
# NP -> dolgu
# NP -> çukur
# NP -> siyaset
# NP -> hububat
# NP -> işbaş
# NP -> tonlamam
# NP -> tezgah
# NP -> potansiyel
# NP -> ,devlet
# NP -> feminist
# VP -> eğ
# NP -> 186
# NP -> vuruş''
# NUM -> 300
# NP -> tarihçi
# VP -> kap
# VP -> abart
# NP -> 209.000'lik
# NP -> lirizm
# NP -> lokma
# VP -> otomobil
# NP -> hırs
# NP -> hizmetçi
# NP -> istatiksel
# NP -> alsatçılar
# NP -> artist
# NP -> lüks
# VP -> ebeveyn
# NP -> kupon
# NP -> kamp
# NP -> limited
# NP -> hobi
# NP -> sulh
# NP -> ediyor:
# NP -> minibüs
# NP -> alsatlarından
# NP -> eleştirmen
# NP -> köpek
# VP -> sözleşme
# NP -> charter
# NP -> troleybüs
# NP -> irrasyonel
# VP -> gözük
# VP -> müşavir
# NP -> kaygılan
# NP -> dekor
# VP -> um
# NP -> akademisyen
# NP -> perestroikanın
# NP -> ihsan
# VP -> ıskala
# NP -> demokrat
# NP -> durakla
# VP -> ulaş
# NP -> aktör
# NP -> %8-10
# NP -> şarkıcı
# NP -> sız
# NP -> solucan
# NP -> sevk
# NP -> ısı
# NP -> mükellefiyet
# NP -> hasar
# NP -> ceo
# NUM -> 170
# VP -> rekabetçi
# NP -> telif
# NP -> ortada
# NP -> komşu
# NP -> statü
# NP -> tescil
# NP -> koyun
# NP -> general
# NP -> heyecan
# NP -> yasama
# NP -> kabin
# NP -> açıklık
# VP -> bar
# NP -> cilveleş
# NP -> işletim
# NP -> gidişat
# NP -> 215.86
# NUM -> 40
# NP -> önder
# VP -> eleştir
# VP -> atlat
# VP -> değer
# NP -> kürsü
# VP -> tep
# VP -> halk
# NP -> gecelik
# VP -> zorun
# NP -> inch
# NP -> üreme
# NP -> sansasyon
# NP -> ıskonto
# NP -> roket
# VP -> frank
# NP -> jenerik
# NP -> fiş
# VP -> yaz
# NP -> takviye
# NP -> langırt
# NP -> şikayetçi
# NP -> aynısı
# NP -> kanaat
# NP -> saksı
# NP -> psikanalist
# NP -> fil
# NP -> di
# VP -> sürpriz
# NP -> 4348
# NP -> akım
# NP -> yüklenim
# NP -> 2.çeyrekte
# NP -> hemoroit
# NP -> dünya
# VP -> sefer
# NP -> çıkış
# VP -> düzey
# NP -> 19/32
# NP -> denek
# NP -> konsolidasyon
# VP -> sürdür
# NP -> kredi
# NP -> kalem
# VP -> zorunlu
# VP -> iste
# NP -> alım-satımcıların
# NP -> erkek
# NP -> sıkışık
# NP -> pist
# NP -> etkin
# NP -> solist
# NP -> petrol-hizmeti
# NP -> 11/2
# NP -> 4.çeyrekte
# NP -> mezarlık
# NP -> tahta
# NP -> genelle
# VP -> ülke
# NP -> sürerlik
# NP -> stok
# NP -> yazıl
# NP -> mikro
# VP -> öğren
# NP -> pazartesi
# NP -> 5.86
# NP -> birleşik
# NP -> delta
# NP -> lazer
# NP -> başkaldırı
# NP -> eşik
# NP -> %8'inden
# NP -> fotoğrafçı
# NP -> 1950
# NP -> sabah
# NP -> handikap
# NP -> kriptografisi
# NP -> vazo
# NP -> edilmememesi
# NP -> bilgilendirme
# NP -> mesaj
# NP -> tedarik
# NP -> tane
# NP -> 215.35'de
# NP -> nbc
# NP -> rehber
# NP -> elmas
# NP -> bilek
# NP -> taşikardi
# NP -> deprem
# NP -> şöhret
# VP -> karşıla
# NP -> dram
# NP -> eğim
# NP -> jour
# NP -> entelektüel
# NP -> icra
# NP -> fizik
# NP -> sedir
# NP -> itimatname
# VP -> betimle
# VP -> kayyum
# NUM -> 4.3
# VP -> gez
# VP -> yorumcu
# NP -> süspansiyon
# NP -> fasulye
# NP -> karartı
# NP -> fast-food
# NP -> ağustos
# NP -> dikim
# NP -> yenilikçi
# VP -> hatıra
# NP -> okuyucu
# NP -> konik
# NP -> brifing
# NP -> marka
# VP -> hükmet
# NP -> öğrenci
# NP -> iyidir.
# VP -> bölün
# NP -> pasta
# NP -> sicilya
# VP -> uyarla
# NP -> kraliçe
# NUM -> 1906
# NP -> buz
# NP -> günlük
# NP -> alternatif
# NP -> mini-bileşen
# NP -> mülakat
# VP -> sakla
# NP -> 1/4-1/2
# VP -> öfke
# NP -> sokak
# NP -> mimar
# NP -> teleferik
# NP -> aleyhtar
# NP -> yumuşama
# VP -> seviye
# NP -> paladyum
# NP -> avcı
# NP -> rehine
# VP -> eğilim
# NP -> nane
# VP -> segment
# VP -> kaz
# VP -> yönlendir
# NP -> edepsiz
# NP -> altı-maçlık
# NP -> üç-a
# NP -> şekilde.
# NP -> ustabaş
# NP -> reseptör
# NP -> tazminat
# VP -> dolu
# NP -> dosya
# NP -> yemin
# NP -> pazarlık
# NP -> soya
# VP -> yararlan
# NP -> pound
# NP -> kooperatif
# NUM -> 1.75
# NP -> megabillion
# NP -> balta
# NP -> milyoner
# NP -> meyve
# NP -> jigolo
# NP -> 131.34'de
# NUM -> 85
# NP -> eşya
# NP -> skandal
# NP -> suç
# NP -> gözetmen
# VP -> kur
# NP -> idam
# NP -> teknoloji
# NUM -> 2643.65
# NP -> v.
# NP -> bileşen
# NP -> %3.6'sını
# NP -> tv
# NP -> düşman
# NP -> rönesans
# VP -> rekor
# NP -> protestocu
# NP -> korumacılık
# NP -> teklifçileri
# NP -> materyal
# VP -> haber
# NP -> montaj
# NP -> buzdolabı
# NP -> elektro
# NP -> komutan
# NP -> bayrak
# NP -> %2.52'lik
# NP -> katılmadı.
# NP -> dramatize
# VP -> ata
# NP -> soyad
# NP -> ilga
# NP -> nahoş
# NP -> kıvılcım
# VP -> devret
# NP -> genişmeme
# NP -> oluşturdu.
# NP -> ödün
# NP -> prodüktör
# VP -> gerçek
# VP -> faktör
# NP -> tatminkar
# VP -> gerçekleş
# VP -> dahil
# NP -> 7580
# NP -> bulak
# NP -> %7.8
# VP -> çözül
# NP -> sap
# NP -> tirat
# NP -> revaç
# NP -> saygısızlık
# NP -> çizgi
# NP -> faydalanma
# NP -> leasing
# NP -> buyout
# NP -> ilave
# NUM -> 81
# NP -> abartma
# NP -> 3363949
# NP -> jonron
# NP -> nüfus-kontrolü
# NP -> sendika
# NP -> idare
# NP -> amca
# NP -> ozon
# NP -> parmaklık
# NP -> donanma
# NUM -> 4.8
# NP -> hareket
# NP -> demirbaş
# NP -> açıklama
# NP -> yolculuk
# NP -> safra
# NP -> ehil
# NP -> rüya
# NP -> rezillik
# NP -> amiral
# NP -> makara
# VP -> sür
# NP -> güçlük
# NP -> tela
# VP -> ucuz
# NP -> karat
# NP -> aygıt
# NP -> vitrin
# VP -> kaçır
# NUM -> 500
# NP -> dolay
# NP -> düşünme
# NP -> ziyaret
# NP -> farmasötik
# NP -> yumuşaklık
# NP -> detay
# NP -> sürücü
# NP -> 1141
# NP -> uyku
# NP -> bütünlük
# NP -> masa
# NP -> tedariğine
# NP -> meşguldu
# NP -> fast-food'un
# NP -> ithal
# VP -> şok
# VP -> dinle
# NP -> %15
# NP -> birleşim
# NP -> fiyat-seviyesi
# NP -> protesto
# NP -> fin
# NP -> vali
# NP -> kepek
# VP -> hal
# NP -> yozlaşma
# NP -> %6'nın
# NP -> defa
# NP -> takipçi
# NP -> efor
# NP -> standart
# NP -> 129.90
# NP -> aşk
# VP -> içeri
# NUM -> 1986
# NP -> karın
# NP -> karşılaştırma
# NP -> destekleme
# NP -> yen'den
# NP -> bank
# NP -> eczacı
# NUM -> 107
# NP -> tüp
# NP -> oyuncu
# NP -> single-b-2
# NP -> tatmin
# NP -> mısır
# VP -> sık
# VP -> maaş
# NP -> yengeç
# NP -> yükseltil
# NUM -> 6.4
# NP -> piyango
# VP -> kurtar
# NP -> talih
# VP -> opsiyon
# VP -> cevapla
# VP -> öldür
# NUM -> 95
# NP -> etek
# NP -> devre
# NP -> trajedi
# NP -> iğne
# NP -> halükarda
# NP -> kaolin
# NP -> belirsizlik
# VP -> alan
# NP -> icat
# NP -> villa
# NP -> boşan
# NP -> tümsek
# NP -> dek
# NP -> konut
# NP -> çürüt
# NP -> öksürük
# NP -> ten
# NP -> lisans
# NP -> vuruşçusunun
# NP -> ulaştırma
# NP -> abone
# NP -> bürokrat
# VP -> yayın
# NP -> küme
# NP -> alım-satımlarda
# NUM -> 3\/4
# NP -> kafes
# NP -> olumsuz
# NP -> tadilat
# NUM -> 1.05
# NP -> alevlen
# NP -> ünlü
# NP -> ortodoks
# NP -> tüyo
# NP -> bakkal
# NP -> kızgın
# NP -> inanç
# NP -> otomatik-kotasyon
# NP -> tahkikat
# NP -> garaj
# NP -> çöplük
# NP -> karşılık
# NP -> acınası
# NP -> megabit
# NP -> tıpın
# NP -> kadı
# NP -> mesele
# NP -> deyim
# VP -> güzel
# NP -> tehvili
# VP -> sars
# NP -> kuşak
# NP -> ab
# VP -> çeşit
# NP -> istikrar
# VP -> çalış
# VP -> hak
# NP -> leş
# NP -> karışım
# NP -> yasak
# NP -> yurtdışına
# NP -> düşürül
# VP -> katolik
# NP -> söğüş
# NP -> halı
# NP -> çeşitlilik
# NP -> vaka
# VP -> araştır
# NP -> etme
# NP -> otantik
# NP -> ipuc
# NP -> içme
# NP -> damlalık
# VP -> canlan
# NP -> omuz
# NP -> rastlantı
# NP -> ün
# NP -> maraton
# NP -> spiker
# VP -> ağırlık
# VP -> döndür
# NP -> imge
# NP -> mikroişlemci
# NP -> kartpostal
# NP -> kader
# NP -> ödememe
# NP -> yapımcılık
# NP -> macun
# NP -> görüntü
# VP -> şükret
# NP -> şamdan
# NP -> tanrı
# NP -> 1772.6
# VP -> bağla
# NP -> atıştırmalık
# NP -> zırh
# NP -> yönlü
# NP -> demir
# NP -> %23'ünü
# NP -> işbirliğ
# NP -> %4.5'lik
# NP -> şaka
# NP -> afet
# VP -> sallan
# NP -> fıstık
# NP -> 4.çeyrek
# NP -> kahve
# NP -> kartel
# VP -> destekle
# NP -> fiyatlandırma
# NP -> stagflasyon
# NP -> barış
# NP -> pico
# NP -> misafir
# VP -> vur
# NP -> çatışma
# VP -> sınıf
# NP -> teşebbüs
# VP -> hız
# NP -> ıslah
# VP -> imalatçı
# NP -> sovyet
# VP -> prens
# NP -> denetim
# VP -> düş
# NP -> heyelan
# NP -> ​​meslektaşlarına
# NP -> lira
# VP -> kurumsal
# NP -> antiviral
# NP -> yürüten
# NP -> 1.980
# NP -> çok
# NP -> vari
# NP -> uluslararasılaşma
# NP -> enstitü
# NP -> sakatla
# VP -> makine
# NP -> ilgili
# NP -> mikrop
# NP -> nesnellik
# NP -> final
# NP -> futbol
# NP -> hâla
# VP -> banyo
# NP -> kiracı
# NP -> terim
# VP -> doldur
# NP -> rahat
# VP -> takın
# NP -> yıldız
# NP -> 2660
# NP -> 212.5
# NP -> boyun
# NP -> folkun
# NP -> şebeke
# VP -> fon
# NP -> doktor
# NP -> balık
# NP -> vurucu
# NP -> advancer
# NP -> bourbon
# NP -> tökezle
# NP -> heyet
# NP -> baklagil
# VP -> bozul
# NP -> per
# NP -> fare
# VP -> sorgula
# VP -> ihtiyaç
# NUM -> 35
# NP -> piyasa
# VP -> dök
# NP -> ret
# VP -> biç
# VP -> masraf
# VP -> adam
# NP -> tekrar
# NP -> danışma
# NP -> tanker
# VP -> yapı
# VP -> katıl
# VP -> cumhuriyetçi
# NP -> teklik
# NP -> vadesiz
# NP -> bilgin
# NP -> yetişkin
# NP -> tar
# NP -> çemenotu
# NP -> mega-hisse
# NP -> bilişim
# NP -> hesap
# NP -> idareci
# NP -> devralım
# NP -> resmi
# NP -> stabilize
# NP -> süreliğine
# NP -> hasatı
# NP -> patinaj
# NP -> tan
# NP -> istasyon
# NP -> anlama
# VP -> azalt
# NP -> sepet
# NP -> plaka
# VP -> suçla
# NP -> ayıkla
# NP -> bilanço
# NP -> posta
# VP -> bas
# VP -> atış
# NP -> kaçakçı
# NP -> cuma
# NP -> gayret
# VP -> yenileş
# NP -> jilet
# NP -> sözlük
# NP -> sever
# NP -> kabile
# NP -> açgözlülük
# NP -> aylaklık
# NP -> 662
# VP -> din
# NP -> toplanan
# VP -> ayrım
# NP -> pezo
# NP -> parti
# NP -> eleman
# NP -> torun
# NP -> dizüstü
# NP -> 7.96
# NP -> edinim
# NUM -> 14
# NP -> motosiklet
# NP -> marksist
# NP -> dalgakıran
# NP -> ocak
# NP -> mütabakat
# NP -> bülten
# NP -> sevgi
# NP -> evlilik
# NP -> şasi
# NP -> 458.32'e
# NP -> fraksiyonel
# NP -> biyoteknoloji
# NP -> ödenme
# NP -> manastır
# NP -> irtibat
# NP -> finansçıları
# NP -> talep
# NP -> makul
# NP -> eş
# NP -> araştırma
# NP -> franchising
# NP -> gol
# NP -> somun
# NP -> teşkilat
# NP -> \
# NP -> tercih
# NP -> suikast
# NP -> şov
# NP -> şehire
# NP -> lok
# VP -> gözlemle
# NP -> 216.74'de
# NP -> hukuk
# NP -> arsa
# NP -> duvar
# NP -> 1.125$
# NP -> rahatsızlık
# NP -> ihraç
# NP -> testere
# NP -> dedektör
# NP -> hafriyat
# VP -> karala
# NP -> peş
# NP -> ,viroqua
# NP -> çanta
# NP -> klip
# VP -> tamam
# NP -> beta
# NP -> dayanak
# NP -> söylem
# NP -> kuş
# NP -> randevu
# VP -> ilişki
# NP -> kumla
# NP -> 88.100.000
# NP -> tasarım
# NP -> manşon
# NP -> kamyon
# NP -> volatiliteden
# NP -> 1,100
# NP -> cumartesi
# VP -> kaydet
# NP -> 65-gün
# NP -> bugün
# NP -> koruyuculuk
# VP -> inan
# VP -> yarar
# NP -> hindistanlı
# NP -> sıvılaş
# NP -> teminatçıya
# NUM -> 42
# VP -> uyan
# NP -> doksan
# NP -> mahkeme
# VP -> üret
# VP -> kuruluş
# NP -> teselli
# VP -> olabilir
# NP -> doğu
# NP -> başarızlığına
# NP -> finansman
# NP -> yanlış?
# NP -> temerrütünü
# NP -> terör
# NP -> bulantı
# NP -> şemsiye
# NP -> turna
# NP -> iade
# NP -> dispaşörleri
# NP -> perakendecilik
# NP -> takıl
# NP -> vakit
# NP -> 1930
# NP -> d
# NP -> şampanya
# NP -> pekiştir
# NP -> 3/4'de
# VP -> dolar
# NP -> aktivite
# NP -> favori
# NP -> nesil
# NUM -> dört
# NP -> kriter
# NP -> mentor
# NP -> arena
# NP -> dei
# NP -> kaydadeğer
# VP -> sendikalaş
# NP -> el
# NP -> gerekçe
# NP -> ayrımcılığın
# NP -> baskıncı
# NP -> deneme
# NP -> şeker
# VP -> ad
# NP -> fenomen
# VP -> tut
# NP -> çarşamba
# NP -> izahname
# VP -> küçük
# NP -> istatistik
# VP -> vazgeç
# NP -> duty-free
# NP -> yükselti
# NP -> dadır
# NP -> rütbe
# NP -> nebze
# NP -> mutabakat
# NP -> sağlık
# VP -> beklenti
# NP -> ülser
# NUM -> 57
# NP -> kasa
# VP -> bakan
# NUM -> 3/8
# VP -> danışman
# NP -> trilyonluk
# NP -> pabuç
# NP -> pastırma
# NP -> kompozit
# NP -> nörolog
# NP -> müdahale
# NP -> $'
# NP -> konkordato
# NP -> kazanç
# NUM -> 5/8
# NP -> %42
# VP -> yayıl
# NP -> yabancılaş
# NP -> servet
# NP -> düşünce
# NP -> kolon
# NP -> özgecilik
# NP -> 3.çeyrek
# NP -> bencillik
# NUM -> 24.4
# NP -> ''erkek
# NP -> 6.45
# VP -> kapa
# VP -> kaçın
# NP -> cıa
# VP -> gerilla
# NP -> spekülatör
# NP -> tarz
# NP -> argüman
# NP -> verdi.
# VP -> ters
# NP -> intikam
# NP -> göğüs
# VP -> girişimci
# VP -> hizmet
# NP -> hoşbeş
# NP -> geri
# NP -> dedektif
# VP -> kalk
# NP -> üniforma
# NP -> kanadalı
# NP -> patron
# NP -> sıra)
# VP -> dol
# VP -> ortaklık
# VP -> baskı
# NP -> uyuşmazlık
# NP -> delesyon
# VP -> eğit
# NP -> star
# NP -> arama
# VP -> aşağıla
# NP -> ruh
# NP -> şubat
# NP -> dostluk
# NP -> bulmaca
# NP -> çay
# NP -> trafik
# NP -> boy
# NP -> işçi
# NP -> ekip
# NP -> erteleme
# VP -> kına
# VP -> kapla
# NP -> bilmiş
# NP -> zor.
# NP -> baron
# NP -> kıyas
# NP -> video
# VP -> parçala
# VP -> canlandır
# NP -> resif
# NP -> tokuşlarını
# VP -> darbe
# NP -> coşku
# NP -> sağduyu
# NP -> gin
# NP -> data
# NP -> merkeziyetçilik
# NP -> devriye
# NP -> fotoğraf
# NP -> koşum
# NP -> kolestrol
# NP -> kaldırım
# NP -> çare
# NP -> yenilgi
# VP -> bay
# NP -> dinozor
# VP -> ol
# VP -> toparla
# NP -> %100
# NP -> dükkan
# NP -> ivme
# NP -> dolarlık
# VP -> bulundur
# NP -> pusula
# NP -> süpermarket
# NP -> 1.012
# NP -> 7.10
# NP -> gemi
# NP -> bakiş
# VP -> azınlık
# NP -> dölle
# NP -> tarım
# NP -> yanıt
# NP -> mektup
# NP -> ilköğretim
# VP -> uzaklaştır
# NP -> koruyucu
# VP -> çekici
# NP -> cüret
# VP -> yüksek
# VP -> parça
# NP -> tren
# NP -> sihir
# NP -> faaliyet
# NUM -> 700
# VP -> çöz
# NP -> depolama
# NP -> hâline
# NP -> müessese
# NP -> taş
# NP -> nerdeyse
# NP -> liste
# NP -> uluslararasılaştırılmasında
# NP -> nesile
# NP -> %0.6'lık
# NP -> kimyager
# NP -> amut
# VP -> güçlen
# NP -> yaratıcılık
# VP -> avukat
# NP -> post
# NP -> volatilitesine
# NP -> 7.875,%
# NP -> kesinti
# NP -> disket
# NP -> döşeme
# NP -> sirenleri
# VP -> düşük
# NP -> savuştur
# NP -> 1,120-806
# NP -> çaba
# NP -> tasdik
# VP -> endişe
# NP -> odeon
# NP -> rezervasyon
# NP -> miting
# NP -> müsteşar
# NP -> mark
# NP -> affet
# NP -> 70.000
# NP -> polis
# NP -> kabine
# NP -> (iki
# NP -> burası
# NP -> yayma
# NP -> şarkı
# NP -> sindir
# NP -> müfettiş
# NP -> kelepirci
# NP -> asansör
# NP -> mühendislik
# NP -> alım-satımda
# NP -> koleksiyon
# NP -> buhar
# VP -> heyecanlan
# NP -> %60'ına
# VP -> otur
# NP -> mentalite
# NP -> haciz
# NP -> sohbet
# NP -> arzu
# NP -> kule
# NP -> iman
# NP -> saat
# NP -> havale
# NP -> pazar
# NP -> daralt
# NP -> %42'sini
# NP -> işyer
# NP -> ima
# NUM -> 459.93
# NP -> promosyon
# NP -> tahribat
# NP -> içki
# NP -> samimiyet
# NP -> sürüm
# NP -> biracılık
# NP -> ban
# NP -> teyit
# NP -> zeka
# NP -> %8.03
# NP -> çerçeve
# NP -> ikraz
# NP -> dördün
# VP -> fiyatlandır
# NP -> şiketleri
# NP -> çevre
# NP -> 1845
# NP -> ıhlamur
# NP -> 3.çeyrekte
# VP -> pozisyon
# NP -> cinnet
# NP -> ilkokul
# NP -> mizah
# NP -> mikro-elektronik
# NP -> projeksiyon
# NP -> keyif
# VP -> zirve
# NP -> kurt
# NP -> uçak-elektronik
# NP -> pc
# NP -> çatlak
# NP -> intex
# NP -> eğitim
# NP -> brokerler
# NP -> 1191.86'de
# NP -> çevrecilik
# NP -> metrik
# NP -> ördek
# NUM -> 2662.91
# VP -> endeks
# NP -> sahne
# NP -> tecavüz
# VP -> ölç
# NP -> 1891
# NP -> feet
# NP -> galibiyet
# NP -> mermer
# NP -> sondajcı
# VP -> bitir
# NP -> had
# NP -> sadaka
# NP -> koçu
# NP -> yaşlı
# NP -> değerlendiyor
# NP -> kalpli
# NP -> sütyen
# NP -> 08:30
# VP -> yetki
# VP -> ilgilen
# NP -> korku
# NP -> alım-satımı
# NP -> kayış
# NP -> prenatal
# NP -> unsur
# NP -> suitlere
# NP -> uzay-bilim
# NP -> telaş
# NP -> termal
# NP -> kırışık
# NP -> dönemeç
# NP -> etiğini
# VP -> dağıtıcı
# NP -> terhis
# NP -> yogi
# NP -> işleme
# NP -> emeklilik
# NP -> portföy
# NP -> yalancı
# NUM -> 69
# NP -> bey
# VP -> konum
# NP -> sayaç
# NP -> mantıksızlık
# VP -> beyaz
# NP -> kese
# VP -> tasarla
# NP -> %70'ini
# NP -> dinamik
# NP -> tanıtım
# NP -> revize
# NP -> açma
# NP -> ferroelektrik
# NP -> öğütücü
# NP -> temsil
# VP -> siyah
# NP -> nesir
# NP -> volatile
# NP -> garantör
# NP -> 1074
# VP -> anlaş
# NP -> iplik
# NP -> kova
# NP -> 44796
# VP -> hissedar
# VP -> yanıl
# NP -> başkent
# NP -> muayene
# VP -> gör
# NP -> laboratuar
# NP -> %10'luk
# NP -> verimsizlik
# NP -> platin
# NP -> diyet
# NP -> kimya
# NP -> katılım
# NP -> esas
# NP -> deklarasyon
# NP -> sos
# NP -> borçlanma
# NP -> ihtiyat
# VP -> mantık
# NP -> parite
# NP -> sosyete
# NP -> zayıflık
# NP -> kambiyo
# VP -> bük
# VP -> borçlan
# NP -> tokat
# NP -> am
# NP -> hamilelik
# NP -> müzisyen
# NP -> tespit
# NP -> hikmet
# NP -> takdir
# NP -> açıkça
# NP -> iktidar
# NP -> efsane
# NP -> soygun
# NP -> kota
# NP -> megabayt
# NP -> teğmen
# VP -> üre
# VP -> az
# NP -> gücü
# VP -> faydalan
# NP -> doğrultu
# NP -> kontrat
# NP -> başka
# NP -> keselen
# NP -> 215.42
# NP -> .'dur
# VP -> şüpheli
# NP -> düzenbaz
# NP -> kovan
# NP -> franchise'larına
# VP -> tekrarla
# NP -> ölçekli
# NP -> tango
# NP -> cinsiyet
# NP -> c-yields
# NP -> numune
# NP -> 27.125$'a
# NP -> kıyamet
# NUM -> 1/2
# NP -> cephanelik
# NP -> manzara
# NP -> paddleball
# NP -> geyiriği
# NP -> son
# NP -> ter
# NP -> ayrılış
# NP -> kırıcı
# NP -> ayrıcalık
# NP -> pürüz
# NP -> lanet-torpido
# NP -> tema
# NUM -> altı
# NP -> 543.5
# NP -> konsensusunun
# NP -> sevinç
# NP -> mayın
# NP -> ameliyat
# NP -> kurnazlık
# VP -> ons
# NUM -> 1989
# NP -> sanatçı
# NP -> listening
# NP -> stimülatörle
# NP -> broker
# NP -> bitki
# VP -> bulgu
# NP -> koç
# NP -> toplam
# VP -> kaynak
# NP -> triphosphorous
# NP -> kez
# NP -> tanıklık
# NP -> tüy
# NP -> kampüs
# VP -> dönem
# NP -> takolarının
# NP -> sabitleş
# NP -> dürtü
# NP -> düzine
# VP -> umut
# VP -> geçmiş
# NP -> sendikasyon
# VP -> paketle
# NP -> abonman
# NP -> seneti
# NP -> katip
# VP -> yeni
# NP -> saygınlık
# VP -> yönetici
# VP -> gergin
# VP -> durgunlaş
# NP -> restorasyon
# NP -> verimlilik
# NP -> yürütme
# VP -> yok
# NP -> boşaltı
# NP -> teçhizat
# NP -> rövanş
# NP -> kabus
# NP -> beysbol
# NP -> benzersiz
# NP -> titanyum
# VP -> engel
# NP -> 1993'de
# NP -> ödenek
# NP -> muhafazakarlık
# NP -> alıcı
# NP -> kristal
# NP -> görünüyor.
# NP -> 1205.01
# VP -> çatırda
# VP -> hüküm
# VP -> paylaş
# VP -> üst
# NP -> konumsal
# NP -> polip
# NP -> deneyimsizlik
# NP -> beş-yıllık
# VP -> banka
# NP -> likit
# NP -> kadeh
# NP -> tabanca
# NP -> kapı
# NP -> mahalle
# NP -> stres
# NP -> tekli
# NP -> newport
# VP -> tak
# NP -> komite
# NP -> sprey
# NP -> temmuz
# NP -> gövde
# NP -> makro-ekonomik
# VP -> raporla
# NP -> anlaşmazlık
# NP -> güvensizlik
# NP -> sunucu
# NP -> filistinli
# NP -> nakit
# NP -> açan
# VP -> beceri
# VP -> sağlam
# NP -> işlem
# NP -> hariç
# NP -> kaçakçılık
# NP -> ayakkabı
# NP -> vize
# NP -> %50'sine
# NP -> glukozu
# NP -> silme
# NP -> kik
# VP -> aciliyet
# NP -> edeme
# NP -> pil
# NP -> saçma
# NP -> idealizm
# NP -> kolej
# NP -> konsunda
# NP -> teşkil
# NP -> 2161.9
# NUM -> 90
# NUM -> 1/4
# NP -> sermaye-kazanç
# NP -> stokunun
# VP -> birleştir
# NP -> kömür
# NP -> avukatlık
# NP -> konsept
# NP -> umur
# VP -> bak
# NP -> kapanış
# VP -> sarsıl
# NP -> 30-hisse
# VP -> yayımcı
# VP -> dik
# NP -> tutma
# NP -> elektronik
# NP -> kârlarının
# NP -> hayat
# NUM -> 3.23
# VP -> onar
# NP -> tersane
# NP -> 7.05
# NP -> cerrah
# NP -> koyucu
# NP -> dizi
# NP -> ekonomist
# VP -> taraftar
# VP -> evril
# VP -> don
# NP -> röportaj
# VP -> külçe
# VP -> art
# NP -> hepatit
# NP -> taşıyıcı
# NP -> masör
# NP -> kanunlaş
# NP -> kamyonet
# VP -> yazar
# NP -> otomotiv-emisyon
# NP -> yahudi
# NP -> nüsha
# NP -> noel
# VP -> yoğunlaş
# NP -> zam
# NUM -> 5\/8
# NUM -> 2009
# NP -> arıza
# NP -> yaran
# NP -> bayan
# NP -> kolektif
# NP -> gümrük
# NP -> taşımacılık
# NP -> %9
# NP -> şantaj
# NP -> vizyon
# NP -> artırım
# VP -> hisset
# VP -> sınırla
# VP -> ara
# NP -> saray
# NP -> glasnost
# VP -> şüphelen
# NP -> banliyö
# NP -> yemlik
# NP -> asimetrik
# NP -> papaz
# NP -> zaaf
# NUM -> 1994
# NP -> barometre
# NP -> vagon
# NP -> başvuru
# VP -> istek
# NUM -> 4/32
# NP -> sözel
# NP -> gayrimenkul
# NP -> biçimlendir
# NP -> atmosfer
# NP -> libre
# NP -> vinç
# NP -> mülk
# NP -> besi
# NP -> 2569.72
# NP -> seyirci
# NP -> yavru
# NP -> kılavuz
# NP -> anavatan
# NP -> kitap
# NP -> doku
# NP -> dolar-yen
# VP -> tepki
# NP -> tayfun
# NP -> maya
# NP -> liberalleş
# NP -> toplama
# NP -> çekirdek
# NP -> reji
# NP -> kaş
# VP -> git
# VP -> savaş
# NP -> arter
# NP -> aracı
# NP -> enfekte
# NP -> istifade
# NP -> 183.467
# NP -> teori
# NP -> çıkma
# VP -> uyum
# NP -> çeyrek
# NP -> %29
# NP -> konsantre
# NP -> 754'den
# VP -> vergi
# NP -> $'dan
# NP -> makiyetlerine
# NP -> diyoruz.
# NP -> alman
# NP -> değişik
# VP -> sorumluluk
# NP -> sosyolog
# NP -> federal
# NP -> oto
# VP -> belirle
# NP -> grev
# NP -> tasarı
# NP -> krema
# NP -> tali
# NP -> ortala
# VP -> aş
# NUM -> 7/8
# NP -> transplanttan
# NP -> kalega
# NP -> finanse
# NP -> disk
# NP -> onur
# NP -> ders
# NP -> verici
# NP -> kariyer
# NP -> emeklilik-
# NP -> filtre
# NP -> asyalı
# NP -> uyuşturucu
# NP -> japonyalı
# NP -> eşitlikçilik
# NP -> tezgahüstü
# NP -> referans
# NP -> guguk
# NP -> fonlamak
# NP -> şimdi
# NP -> şifre
# NP -> monetarist
# NP -> 454.86
# NP -> kirlilik
# VP -> benze
# NP -> dul
# NP -> temiz
# NP -> nakiti
# NP -> supraventriküler
# NP -> hapis
# NUM -> 8.65
# NP -> bursiyer
# NP -> kuyumcu
# NP -> gürültü
# NP -> ağaç
# NP -> sütun
# NP -> bağnazlık
# NP -> gezinti
# NP -> 98523
# NP -> kostüm
# NP -> patlak
# NP -> fakir
# VP -> taban
# VP -> kapsa
# NP -> vakıf
# NP -> cilve
# NP -> şarlatan
# VP -> tutum
# VP -> yığ
# NP -> dağ
# NP -> radar-tehdit
# NP -> nefes
# NP -> yen
# NP -> motif
# VP -> savun
# NP -> temyiz
# NP -> tenor
# NP -> faks
# NP -> simsar
# NP -> lisansladı
# NP -> 1947
# NUM -> 1/8
# NP -> norm
# NP -> yenileme
# NP -> bildirge
# NP -> ateşkes
# NP -> politikacı
# NP -> mahal
# VP -> yayınla
# NP -> korsan
# NP -> demeç
# VP -> tamamla
# NP -> ayrış
# NP -> paket
# NP -> somon
# NP -> turkuaz
# NP -> dönüm
# NP -> yükselme
# NUM -> 15
# NP -> çinli
# NP -> mezun
# VP -> bat
# NP -> iş-yönetim
# NP -> tanık
# NP -> 1199.32
# NP -> avaz
# NP -> kutup
# VP -> istisna
# NP -> kış
# NP -> programcılık
# NP -> ceset
# NP -> yıldırım
# NP -> sermaye
# VP -> kaybol
# NP -> 1975'de
# VP -> politika
# NP -> bağımlılık
# NP -> iletişim
# NP -> piskopos
# VP -> geliş
# NP -> malik
# NP -> motive
# VP -> planla
# NP -> dilekçe
# NP -> sapan
# NP -> bakma
# NP -> diet
# NP -> delin
# NP -> tiryaki
# NP -> kimse
# NP -> 213.97
# NP -> eksiklik
# NP -> damıtıcı
# NP -> kliring
# NP -> 219.19'de
# NUM -> 9
# VP -> emin
# NP -> acenta
# VP -> aktif
# NP -> balon
# NP -> islam
# NP -> mt
# NP -> aldat
# VP -> çıkar
# NP -> 6.kez
# NP -> revak
# NP -> sonuçla
# NP -> çıktı.
# NP -> karşı-devrimci
# VP -> uzunluk
# VP -> kaç
# NP -> cinayet
# NP -> alış-veriş
# NUM -> 12.5
# VP -> onay
# NUM -> 2200
# NP -> piyano
# VP -> araştırmacı
# VP -> kurtul
# NP -> espri
# NP -> ayaklanma
# NP -> 694
# NP -> 35670
# VP -> dön
# NP -> itfa
# NP -> indikatör
# NUM -> 465
# NP -> güncelle
# NP -> p53
# NP -> basit
# NP -> köprü
# VP -> hikaye
# NP -> sertifika
# NP -> baloncu
# NP -> figür
# NP -> hardal
# NP -> ajan
# NP -> varak
# VP -> tüken
# VP -> kışkırt
# NP -> bordro
# NP -> epileptik
# NP -> bağcık
# NP -> kışkırtma
# NP -> single-b
# NP -> manken
# NP -> hissi
# NP -> tel
# VP -> satı
# NP -> yoldaş
# NP -> tahmis
# NP -> diril
# NP -> bayii
# NP -> 130.46
# NP -> tahrip
# NP -> ana
# NP -> postala
# NP -> ünite/birim
# NP -> tasarımcı
# NP -> tekabül
# NP -> batarya
# NP -> fener
# NP -> %10.4
# NP -> lejyon
# VP -> ilet
# NP -> salınım
# NP -> yürürlük
# NP -> ikram
# NP -> kıyafet
# NP -> edebiyat
# VP -> profesyonel
# NP -> neon
# NP -> optik
# NP -> tenis
# NP -> sevkiyat
# VP -> karşı
# NP -> haşere
# NP -> yönelim
# NP -> sızıntı
# NUM -> 240
# VP -> sektör
# NP -> algı
# NP -> çarpı
# NP -> marina
# NP -> tahıl
# VP -> önlem
# VP -> artış
# NP -> nüfuz
# NP -> döngü
# NP -> klor
# NP -> örtü
# NP -> üstat
# NP -> kaldıraç
# NP -> reorganizasyon
# NP -> bahar
# NP -> ünvan
# VP -> önemsen
# NP -> kopuk
# NP -> nezaket
# NP -> lezzet
# NP -> 1974'deydi
# NP -> 1.222
# NP -> azaltım
# NP -> kitapçı
# VP -> başar
# NP -> 40.6
# NP -> hiddet
# NP -> aflatoksin
# NP -> uzmanlık
# NP -> yüksek.
# NP -> hareketlen
# VP -> kaynaklan
# NP -> referandum
# NP -> isabet
# NP -> egzersiz
# NP -> nakliyeci
# NP -> harcama
# VP -> yat
# VP -> aksa
# NP -> ilişkilerinde:
# VP -> dönüş
# NP -> mahsülü
# VP -> bono
# NP -> sabun
# NP -> telafi
# NP -> belirsizdir.
# VP -> böl
# VP -> söz
# NP -> tümor
# NP -> kafeterya
# NP -> traktör
# NP -> ekarte
# VP -> zayıfla
# NP -> kağıt
# NP -> lojistik
# VP -> oyna
# NP -> damızlık
# NP -> kabiliyet
# NP -> bildiri
# NP -> eylem
# NP -> fırlatma
# NP -> telgraf
# NP -> som
# NP -> gözlemci
# VP -> düşür
# NP -> limoni
# NP -> memurluk
# NP -> muhasebe
# NP -> çingene
# NP -> bilinç
# NP -> teneke
# NP -> denetçi
# NP -> masaüstü
# NP -> bezelye
# NP -> 2018
# NP -> arbede
# NP -> konuşmacı
# NUM -> 572
# VP -> sor
# NP -> transitde
# NP -> ithalatçı
# NP -> iptal
# NP -> gözlük
# VP -> net
# VP -> öğe
# NP -> mühimmat
# VP -> sıçra
# NUM -> 12.75
# NP -> 1990-model
# NP -> tutucu
# VP -> işletmeci
# NP -> bağırsak
# NP -> özürlü
# NP -> kaygılı
# NP -> %7.90
# NP -> atari
# NP -> isveçli
# NP -> nakavt
# NP -> yalan
# VP -> yasakla
# VP -> yumuşa
# NP -> %2'dir
# NP -> fast-track
# NP -> gölge
# NP -> kaset
# NP -> çökme
# NP -> ustabaşısı
# NP -> karne
# NP -> parlamento
# NP -> %2'lik
# NP -> seçki
# NP -> kürk
# NP -> yazarlık
# NP -> kadro
# NP -> iz
# NP -> konyak
# NP -> meditasyon
# VP -> değiştir
# NUM -> ı
# NP -> yapılanma
# VP -> davran
# NP -> doğurganlık
# VP -> sendele
# VP -> ateşle
# NP -> 4.375'den
# NP -> güruh
# NP -> 34.25$'den
# NP -> burger
# NP -> lakap
# NP -> $'lık
# NP -> %8.21
# NP -> rafine-petrol
# VP -> borç
# NP -> şık
# NP -> mikroskop
# NP -> paranın-çalışması
# NP -> meşruiyet
# NUM -> 400
# NP -> bankacı
# NP -> şüpheci
# VP -> kütüphane
# NP -> yerleşimcinin
# NP -> boyama
# VP -> onayla
# NP -> megawattlık
# NP -> mülteci
# NP -> lego
# NP -> çamaşır
# NP -> tehlikeli
# NP -> deccal
# NP -> katot
# NP -> müze
# NP -> hakimiyet
# NP -> grup'un
# NP -> gözardı
# VP -> merkez
# NP -> fan
# NP -> işlemci
# NP -> çayır
# NP -> `stay
# NP -> karakter
# NP -> kurma
# NP -> hasta
# NP -> uyaran
# NP -> veteriner
# VP -> düzenle
# NUM -> 1962
# NP -> tröst
# NP -> red
# NP -> litre
# NP -> çürü
# NP -> merhamet
# NP -> güreşçi
# NP -> sine
# NP -> ilerleyici
# NP -> .'dır
# VP -> geçerli
# NP -> anket
# NP -> 1970'de
# VP -> artır
# NP -> sermayedar
# NP -> tohum
# NP -> veto
# NP -> tik
# VP -> cihaz
# NP -> 9.62
# NP -> yayılım
# NP -> 1974-75'de
# NP -> şampuan
# NP -> tahliye
# VP -> kıyasla
# NP -> doyur
# NP -> finasman
# NP -> 130.13
# NUM -> 89
# VP -> titre
# NP -> infilakın
# NP -> koridor
# NP -> çizim
# NP -> komunist
# NP -> flaş
# VP -> gün
# VP -> salla
# NP -> arbs'in
# NP -> kamçı
# NP -> mühürle
# NP -> bakanlık
# NP -> demet
# VP -> ilgi
# VP -> in
# NP -> group
# NP -> kapitalizm
# NP -> 100-pay
# NUM -> 1960
# VP -> kabullen
# NP -> anti-kanser
# VP -> sıkıştır
# NP -> dağılma
# NP -> fişek
# NP -> kabartı
# NP -> tur
# NP -> netice
# NP -> beyin
# NP -> sorumsuzluk
# NP -> caydırıcı
# NP -> duayen
# NP -> z
# VP -> yakala
# NP -> suistimal
# NP -> çadır
# NP -> alarm
# NP -> etkileşim
# NP -> budak
# NP -> bütünleş
# NUM -> 66
# NP -> farz
# NP -> davranış
# NP -> içtihat
# NP -> beri
# NP -> faiz
# NP -> maliyet
# VP -> tanımla
# NUM -> 24
# NP -> döner
# NP -> vizon
# VP -> ipotek
# NP -> cümle
# NP -> herkes
# NP -> kalite
# VP -> etki
# NP -> farklılık
# NP -> etkinlik
# NP -> %40'ını
# NP -> neti
# NP -> stajyer
# NP -> dönemki
# NP -> istifa
# NP -> öncelik
# NP -> ahır
# NP -> veritaban
# NUM -> 11
# NP -> sebep:
# VP -> üzer
# VP -> ora
# NP -> yıkım
# NP -> sorumlu
# NP -> vade
# NP -> terk
# NP -> %11.1'ini
# NP -> 8:
# NP -> seks
# NP -> spekülasyon
# NP -> stop-ödeme
# NP -> kaplumbağa
# NP -> simülatör
# NP -> çığlık
# NP -> müzakelererin
# NP -> gayrimenkullerde
# NP -> bardak
# NP -> madenci
# VP -> sirkülasyon
# NP -> şirletler
# NUM -> 1979
# VP -> düzel
# NP -> multimedya
# NP -> erkek-kısır
# VP -> geç
# NP -> monolitlerin
# NP -> 3500
# NP -> dengesizlik
# NP -> utangaç
# NP -> mütevelli
# NP -> yakıt
# NP -> oil
# NP -> fırçala
# NP -> terzilik
# NP -> metanollu
# NP -> yuva
# NP -> öden
# NP -> muhalafeti
# NP -> şalo
# NP -> görgü
# NP -> sancak
# NP -> muadillerinden
# NP -> atık
# NP -> 1263.51
# NP -> çevreci
# NP -> operatif
# NP -> kural
# NP -> spektaküler
# NP -> olimpiyat
# VP -> panik
# NUM -> 6.5
# NP -> /4
# NP -> bowling
# VP -> oku
# VP -> takas
# VP -> yargıç
# NP -> müsrif
# VP -> yıllık
# NP -> 8,000
# NP -> kargaşa
# NP -> isyancı
# NP -> güreş
# VP -> ay
# NP -> yön
# NP -> toprak
# NP -> kasvet
# NP -> hakkımızdaki
# NP -> bilmiyorlar.
# NP -> bayıl
# NUM -> 1988
# NP -> sağ
# VP -> hatırla
# NP -> desen
# VP -> distribütör
# NP -> dezavantaj
# NP -> 2596.72
# NP -> tarafsız
# NP -> müzik
# NP -> tip
# NP -> deflatör
# NP -> çekim
# NP -> aciz
# NP -> sosyal
# NP -> opec
# NP -> alev
# VP -> atan
# NP -> mikroskobik
# NP -> çizelge
# NP -> puro
# NP -> stratosferik
# NP -> revizyon
# VP -> yapımcı
# NP -> ört
# VP -> kuvvet
# NUM -> 1987
# NP -> es
# NP -> yarışma
# NP -> %14.1
# NP -> 1.059.04
# VP -> şekil
# NP -> girişim
# NP -> mevki
# NP -> uyarı
# NP -> gençlik
# NP -> burs
# NP -> hard
# NP -> zafer
# VP -> ben
# NP -> kahraman
# NP -> canlandırma
# NP -> milyonlarca
# NP -> 51-nakit
# NP -> realizasyonları
# VP -> yağ
# NP -> bellek
# NP -> yor
# NP -> vesile
# NP -> göç
# NP -> depozito
# NP -> istihdam
# VP -> gösterge
# NP -> iyileştir
# VP -> aç
# VP -> duyur
# NP -> 13.4
# NUM -> 10.5
# NUM -> 23
# NP -> solo
# NP -> inşaat
# NP -> dondurma
# NP -> gayrimenkullerin
# NP -> kavga
# NP -> aracılık
# NP -> mahkum
# NP -> kavanoz
# NP -> emek-yönetim
# NP -> hidroelektrik
# VP -> süre
# NP -> alışveriş
# NP -> akraba
# VP -> etkile
# NP -> parçalan
# VP -> sök
# NP -> dayanışma
# VP -> bomba
# NP -> fizyoloji
# NP -> çubuk
# NP -> ölçek
# VP -> ertele
# NP -> implant
# NP -> burbon
# NP -> öğle
# NP -> bıçak
# NP -> kapitalist
# NP -> oğul
# NP -> spot
# NP -> ham
# NP -> küresel
# VP -> gel
# VP -> iddia
# NP -> dev
# VP -> teşhis
# NP -> diyabet
# NP -> %0,3
# VP -> şımar
# NP -> doldurma
# VP -> engelle
# NP -> vurul
# NP -> süpervizörleri
# NP -> gizem
# NP -> karmaşa
# NP -> suitinde
# NP -> devam
# NP -> 2149.3
# NP -> enstrüman
# NP -> spor
# NP -> dikte
# NP -> inat
# VP -> çağır
# NP -> fantezi
# VP -> ayrılık
# NP -> deniz
# VP -> yatırım
# NP -> 7.60
# NP -> sıkboğaz
# NUM -> 13/16
# VP -> husus
# NP -> gezi
# NP -> sınıfla
# NP -> özet
# NP -> yonga
# NP -> 'dür
# NP -> mobil
# NP -> 13.000
# NP -> profesör
# NP -> sinyal
# VP -> kuru
# NP -> patlama
# NP -> tomurcuk
# NP -> enkaz
# NP -> yardları
# NP -> nam
# NP -> kuaför
# VP -> amaç
# NP -> 3090
# NP -> piko
# NP -> edep
# NP -> ortalık
# NP -> kamu
# NP -> çölümsü
# NP -> bucak
# NP -> gider
# VP -> uyandır
# NP -> gel-gitlerden
# VP -> tahvil
# NP -> finiş
# NUM -> 2002
# NP -> harç
# NP -> inşa
# NP -> feragat
# NP -> niş
# NP -> eşitlikçiliği
# NP -> domuz
# NUM -> 18
# NP -> kapatma
# NP -> ​​yaptı
# NUM -> on
# NP -> başarısızlık
# NP -> kullanım
# NP -> tören
# NP -> avrupalı
# NP -> yeniyetme
# NP -> verme
# NP -> %26
# NP -> kuyu
# NP -> 455.63
# NP -> ipucu
# NP -> tanıma
# NP -> sırılsıklam
# NP -> banka-dolandırıcılık
# NP -> %6.4'ün
# NP -> şimşek
# NP -> metin
# NP -> reyting
# NP -> 9.5'di
# NP -> stadyum
# NP -> psikobiyoloji
# NP -> çalıntı
# NP -> imalat
# NP -> segman
# VP -> hazırla
# NP -> kasırga
# NP -> memur
# NP -> kapak
# NP -> antreman
# NP -> grafik
# NP -> propan
# NP -> karavan
# NP -> resepsiyon
# NP -> santimetre
# NP -> rekabet
# VP -> yuvarla
# NP -> içim
# NP -> franchiselarını
# NP -> türlü
# NP -> maden
# NP -> -110
# NP -> çarptır
# NP -> atak
# VP -> reform
# NP -> kromozom
# NP -> savunmasızlık
# NP -> soruşturmacı
# NP -> olacak
# NUM -> 32
# NP -> amonyum
# NP -> ölçüm
# NP -> diplomasi
# NP -> kaya
# NP -> %12'si
# NP -> facia
# NP -> yerinde
# NP -> bileşim
# NP -> çarpan
# NP -> maske
# NP -> mat
# NP -> doğa
# NP -> koro
# NP -> tesisat
# VP -> tüket
# NP -> tarama
# NP -> elektrolüminesans
# VP -> karşılaş
# VP -> vurgula
# NP -> kalıntı
# NP -> rafineri
# NP -> yen'lik
# NP -> üretkenlik
# NP -> rodeo
# NP -> demilitarize
# NP -> havalandırma
# VP -> numara
# NP -> akşam
# VP -> hazır
# NP -> yayınev
# NP -> saldırgan
# NP -> seremoni
# NP -> denizaşırı
# NP -> pısırık
# NP -> birikim
# NP -> peşinde
# NP -> seyir
# NP -> 14.560.000
# NP -> temin
# NP -> buzdağ
# NP -> aktarma
# NP -> vergilendirilebilir-eşdeğer
# NP -> gebelik
# NP -> centilmenlik
# NP -> açmaz
# NP -> espiyonaj
# VP -> tanım
# VP -> değiş
# NP -> komut
# NP -> tasavvur
# NP -> imparatorluk
# NP -> renk
# NP -> mega
# VP -> önce
# VP -> fiyat
# NP -> kıymet
# NP -> lig
# NP -> iyilik
# NP -> %5'i
# NP -> gürle
# NP -> verit
# NP -> antifriz
# NUM -> 8.9
# VP -> kültür
# NP -> %25'inin
# NP -> /2
# NP -> tasvir
# NP -> minimal
# NP -> çift-a'
# VP -> dikil
# NP -> şatafat
# NP -> tekstil
# NP -> fırtına
# VP -> çek
# NP -> engelleyici
# VP -> süpür
# VP -> şüphe
# NP -> işgal
# NP -> seyahat
# NP -> genişleme
# NP -> memnuniyet
# VP -> kullan
# NP -> fırın
# NP -> organ
# NP -> buldozer
# VP -> cay
# VP -> üye
# NP -> show
# NP -> stratejist
# NP -> duyduran
# NUM -> 1999
# NP -> tablo
# NP -> deney
# NP -> ayrılma
# NP -> 80,000
# VP -> fatura
# NP -> anı
# NP -> köpekbalık
# NP -> parsel
# NP -> şah
# NP -> kıdem
# NP -> saçmalık
# VP -> getir
# NP -> iletim
# NP -> mutluluk
# NP -> atıcı
# NP -> bisikletçi
# NP -> ettir
# VP -> hafifle
# VP -> görev
# NP -> 463.28
# NP -> gri
# NP -> huylu
# NP -> ova
# NP -> kum
# NP -> çekicilik
# NP -> halef
# NP -> rezerv
# NP -> çanak
# NP -> ustalık
# NP -> şifrele
# NP -> başlık
# NP -> muz
# NP -> kapasitör
# NP -> oşinografik
# NP -> sörfçü
# NP -> editoryal
# NP -> yedekle
# NP -> doğaçlama
# NP -> gönül
# NP -> lansman
# NP -> taklit
# NUM -> 9000
# NP -> kiralama
# VP -> sıfırla
# NP -> anlaşıl
# NP -> 1994'de
# NP -> çalgı
# NP -> iskontalarla
# NP -> kuzey
# NP -> bütçeciler
# NP -> sıçan
# VP -> hayalet
# NP -> zımni
# NP -> hortum
# NP -> yükümlülük
# NP -> elçi
# NP -> akın
# NP -> tahakkuk
# VP -> azal
# NP -> savunmacılarına
# NP -> çimento
# VP -> tedavül
# NP -> ressam
# NP -> pembe
# NP -> tatlılık
# NP -> kod
# NP -> fiyat-bilinçli
# VP -> serp
# NP -> 1507.37
# NUM -> 1992
# NP -> 4400
# VP -> cent
# NP -> ünite/birime
# NP -> açıklanan
# NP -> reasürans
# VP -> sosyalist
# NP -> romancı
# NP -> 1995'de
# NP -> isim
# NP -> pasifize
# NP -> damgala
# NP -> balina
# NP -> gezegen
# NP -> river
# NP -> kravat
# VP -> kat
# NP -> nakarat
# NP -> nisan
# NP -> düzeltme
# NP -> 1o
# NP -> pejmürde
# NP -> portre
# NP -> par
# NP -> ücret
# NP -> talihsizlik
# NP -> 8.35
# NP -> şalter
# NP -> diagnostik
# NP -> popüler
# NP -> kast
# VP -> dengele
# NP -> azalma
# NP -> öneri
# NP -> yandaş
# NP -> entrika
# NP -> toksin
# NP -> takasçı
# NP -> kemik
# NP -> çan
# NP -> biyolojik
# NP -> kurmay
# NP -> %0,9
# NP -> anonim
# NP -> satın
# NP -> saf
# ...
# NUM -> 10.3
# NUM -> 59
# NUM -> 130
# NUM -> 4.11
# NUM -> 50.59
# NUM -> 142.85
# NUM -> 1.49
# NUM -> 1961
# NUM -> 6050
# NUM -> ıv
# NUM -> 500.2
# NUM -> 130.76
# NUM -> 2.15
# NUM -> 730070
# NUM -> 9.2
# NUM -> 2683.2
# NUM -> 49000
# NUM -> 25.25
# NUM -> 4.27
# NUM -> 368.24
# NUM -> 184
# NUM -> 143.6
# NUM -> 4.31
# NUM -> 39300
# NUM -> 40.4
# NUM -> 36.6
# NUM -> 14580000
# NUM -> 8.375
# NUM -> 108.4
# NUM -> 11.6
# NUM -> 210
# NUM -> 11.4
# NUM -> 5.37
# NUM -> 20.6
# NUM -> 19.2
# NUM -> 53.9
# NUM -> 148
# NUM -> 30.1
# NUM -> 35.38
# NUM -> 376.36
# NUM -> 2.38
# NUM -> 28.6
# NUM -> 3.68
# NUM -> 40000
# NUM -> 2.87
# NUM -> 94425000
# NUM -> 11.0
# NUM -> 39.19
# NUM -> 691.09
# NUM -> 7.3
# NUM -> 168
# NUM -> 897.2
# NUM -> 0.03
# NUM -> 2.14
# NUM -> 170330000
# NUM -> 552302
# NUM -> 7.12
# NUM -> 986
# NUM -> 1956
# NUM -> 21.6
# NUM -> 295.7
# NUM -> 92.42
# NUM -> 111
# NUM -> 251.2
# NUM -> 1.8578
# NUM -> 11820000
# NUM -> 711.9
# NUM -> 11.8
# NUM -> 54.51
# NUM -> 373.8
# NUM -> 272.0
# NUM -> 47.46
# NUM -> 94.243
# NUM -> 765
# NUM -> 1.603
# NUM -> 2.57
# NUM -> 589
# NUM -> 2210
# NUM -> 487
# NUM -> 30\/32
# NUM -> 9.75
# NUM -> 18.69
# NUM -> 10.2
# NUM -> 29/32
# NUM -> 1.68
# NUM -> 1210.7
# NUM -> 307.2
# NUM -> 108.28
# NUM -> 141.65
# NUM -> 877.6
# NUM -> 63.52
# NUM -> 44.6
# NUM -> 368.15
# NUM -> 275000
# NUM -> 822
# NUM -> 5.04
# NUM -> 601.3
# NUM -> 7.4
# NUM -> 354000
# NUM -> 28.3
# NUM -> 1900
# NUM -> 166.9
# NUM -> 5.8125
# NUM -> 43.3
# NUM -> 145
# NUM -> 8.32
# NUM -> 92
# NUM -> 8.38
# NUM -> 27.0
# NUM -> 80000
# NUM -> 35587.85
# NUM -> 2.69
# NUM -> 407
# NUM -> 488
# NUM -> 914
# NUM -> 448
# NUM -> 101.98
# NUM -> 16.1
# NUM -> 1.54
# NUM -> 220
# NUM -> 925
# NUM -> 75.2
# NUM -> 191.1
# NUM -> 12283217
# NUM -> 8.62
# NUM -> 415
# NUM -> 0.45
# NUM -> 58.97
# NUM -> 99.14
# NUM -> 99.23
# NUM -> 185
# NUM -> 108625
# NUM -> 141.52
# NUM -> 0.53
# NUM -> 309381
# NUM -> 730
# NUM -> 44.125
# NUM -> 5088774
# NUM -> 433.5
# NUM -> 8.7
# NUM -> 2.21
# NUM -> 20.125
# NUM -> 257.8
# NUM -> 190
# NUM -> 5.94
# NUM -> 100.8
# NUM -> 423
# NUM -> 456.2
# NUM -> 176.7
# NUM -> 643.4
# NUM -> 97.85
# NUM -> 8.22
# NUM -> 117.94
# NUM -> 6.07
# NUM -> 4.75
# NUM -> 6.95
# NUM -> 195.19
# NUM -> 884
# NUM -> 7.81
# NUM -> 1.5885
# NUM -> 112
# NUM -> 21.4
# NUM -> 1.6145
# NUM -> 425000
# NUM -> 1701.7
# NUM -> 31000
# NUM -> 7.2
# NUM -> 626.3
# NUM -> 1920
# NUM -> 663
# NUM -> 780
# NUM -> 25.875
# NUM -> 747
# NUM -> 4.12
# NUM -> 0.44
# NUM -> 3481887
# NUM -> 283.2
# NUM -> 344.354
# NUM -> 499.4
# NUM -> 575000
# NUM -> 1610
# NUM -> 11.9
# NUM -> 2.73
# NUM -> 76.4
# NUM -> 4.9
# NUM -> 1070000
# NUM -> 9756
# NUM -> 25.78
# NUM -> 1.85
# NUM -> 13.02
# NUM -> 3.16
# NUM -> 18.7
# NUM -> 8590
# NUM -> 376000
# NUM -> 155.0
# NUM -> 0.39
# NUM -> 19395
# NUM -> 155650000
# NUM -> 12.9375
# NUM -> 13/32
# NUM -> 2600
# NUM -> 1.37
# NUM -> 14.95
# NUM -> 9.76
# NUM -> 784.5
# NUM -> 245.3
# NUM -> 0.23
# NUM -> 654.5
# NUM -> 41.2
# NUM -> 3426.33
# NUM -> 75.5
# NUM -> 3.55
# NUM -> 930
# NUM -> 673
# NUM -> 678
# NUM -> 177
# NUM -> 6.19
# NUM -> 33270
# NUM -> 9.3
# NUM -> 6500000
# NUM -> 25.8
# NUM -> 51
# NUM -> 785
# NUM -> 9.81
# NUM -> 540.9
# NUM -> 10.7
# NUM -> 36.125
# NUM -> 2.09
# NUM -> 2423.9
# NUM -> 313800
# NUM -> 108
# NUM -> 369000
# NUM -> 353
# NUM -> 192
# NUM -> 57000
# NUM -> 27.8
# NUM -> 452
# NUM -> 44400
# NUM -> 2.63
# NUM -> 194
# NUM -> 8.59
# NUM -> 21.98
# NUM -> 223.3
# NUM -> 14.11
# NUM -> 329.2
# NUM -> 78.64
# NUM -> 3.64
# NUM -> 13.0
# NUM -> 2007
# NUM -> 17.73
# NUM -> 1.2
# NUM -> 161
# NUM -> 39.31
# NUM -> 4.92
# NUM -> 390.5
# NUM -> 53
# NUM -> 2189.7
# NUM -> 2157656
# NUM -> 2600000
# NUM -> 42.25
# NUM -> 34230
# NUM -> 88
# NUM -> 761.38
# NUM -> 10.875
# NUM -> 08:01
# NUM -> 8.07
# NUM -> 26.23
# NUM -> 115
# NUM -> 2.66
# NUM -> 1150000
# NUM -> 12.06
# NUM -> 231
# NUM -> 119.88
# NUM -> 18.5
# NUM -> 52.75
# NUM -> 5.01
# NUM -> 382.9
# NUM -> 179.916
# NUM -> 26.81
# NUM -> 2.8
# NUM -> 10.4
# NUM -> 19.3
# NUM -> 39.68
# NUM -> 368.25
# NUM -> 0.6
# NUM -> 39.5
# NUM -> 515
# NUM -> 25.96
# NUM -> 176100000
# NUM -> 350.0
# NUM -> 35486.38
# NUM -> 103.0
# NUM -> 425
# NUM -> 680
# NUM -> 370.6
# NUM -> 786100
# NUM -> 28.7
# NUM -> 165
# NUM -> 210.2
# NUM -> 2023
# NUM -> 7.84
# NUM -> 31.2
# NUM -> 102.5
# NUM -> 2.79
# NUM -> 1.38
# NUM -> 250000
# NUM -> otuz
# NUM -> 750000
# NUM -> 1.45
# NUM -> 10.35
# NUM -> 461.2
# NUM -> 7.904
# NUM -> 215.48
# NUM -> 30.88
# NUM -> 21.25
# NUM -> 335.7
# NUM -> 17.92
# NUM -> 774000
# NUM -> 158
# NUM -> 19.51
# NUM -> 19.93
# NUM -> 114
# NUM -> 446.5
# NUM -> ııı
# NUM -> 2.61
# NUM -> 234
# NUM -> 22.3
# NUM -> 28.0
# NUM -> 117.2
# NUM -> 142.25
# NUM -> 155
# NUM -> 148.85
# NUM -> 153
# NUM -> 89.75
# NUM -> 1247.87
# NUM -> 130000
# NUM -> 87.37
# NUM -> 1.02
# NUM -> 6.94
# NUM -> 44877
# NUM -> 814000
# NUM -> 505
# NUM -> 38000
# NUM -> 9.78
# NUM -> 129.6
# NUM -> 6.8
# NUM -> 517500
# NUM -> yedinci
# NUM -> 16800000
# NUM -> 462.9
# NUM -> 3.54
# NUM -> 0.1
# NUM -> 4.22
# NUM -> 0.71
# NUM -> 25000
# NUM -> 3377.43
# NUM -> 8.81
# NUM -> 329600
# NUM -> 1.0
# NUM -> 1.8667
# NUM -> 6.31
# NUM -> 216.49
# NUM -> 129.38
# NUM -> 2.1
# NUM -> 497.1
# NUM -> 2387226
# NUM -> 904000
# NUM -> 402.7
# NUM -> 6.52
# NUM -> 17.375
# NUM -> 1.62
# NUM -> 195.4
# NUM -> 501.61
# NUM -> 83
# NUM -> 702.4
# NUM -> 18.0
# NUM -> 265.79
# NUM -> 13.32
# NUM -> 251.8
# NUM -> 7\/16
# NUM -> 12.9
# NUM -> 528.4
# NUM -> 14.85
# NUM -> 1435
# NUM -> 476.5
# NUM -> 7\/32
# NUM -> 428000
# NUM -> 0.35
# NUM -> 22.125
# NUM -> 11:54
# NUM -> 103
# NUM -> 1.73
# NUM -> 191.75
# NUM -> 320
# NUM -> 145.45
# NUM -> 22.8
# NUM -> 378.87
# NUM -> 26.1
# NUM -> 371.1
# NUM -> 1.4
# NUM -> 50.875
# NUM -> 87.1
# NUM -> 111.2
# NUM -> 22.6
# NUM -> 2117.1
# NUM -> 1.8485
# NUM -> 73
# NUM -> 180000
# NUM -> 4000
# NUM -> 370
# NUM -> 32.7
# NUM -> 410.5
# NUM -> 470.8
# NUM -> 8.05
# NUM -> 2.59
# NUM -> 291.6
# NUM -> 7.73
# NUM -> 36.13
# NUM -> 160
# NUM -> 56.9
# NUM -> 135.9
# NUM -> 91.21
# NUM -> 6727042
# NUM -> 42.7
# NUM -> 950
# NUM -> 30.6
# NUM -> 19.7
# NUM -> 10873
# NUM -> 128
# NUM -> 110
# NUM -> 2.75
# NUM -> 200000
# NUM -> 394.4
# NUM -> 5.9
# NUM -> 918.4
# NUM -> 12.345
# NUM -> 201.2
# NUM -> 5.32
# NUM -> 3.25
# NUM -> 299
# NUM -> 349
# NUM -> 1.01
# NUM -> 40.125
# NUM -> 1380000
# NUM -> 7.51
# NUM -> 256000
# NUM -> 2.68
# NUM -> 1400000
# NUM -> 4.49
# NUM -> 49.0
# NUM -> 58
# NUM -> 3.56
# NUM -> 4.03
# NUM -> 2.125
# NUM -> 200
# NUM -> 395000
# NUM -> 173.5
# NUM -> 2.33
# NUM -> 117
# NUM -> 91/2
# NUM -> 12000
# NUM -> 1.31
# NUM -> 527.39
# NUM -> 12500000
# NUM -> 34996.08
# NUM -> 125075
# NUM -> 2.36
# NUM -> 4.0
# NUM -> 12.05
# NUM -> 2.7
# NUM -> 105.2
# NUM -> 395700
# NUM -> 2100
# NUM -> 293.9
# NUM -> 2052.1
# NUM -> 8.03
# NUM -> 206
# NUM -> 21\/32
# NUM -> 0.06
# NUM -> 336
# NUM -> 2.34
# NUM -> 625.4
# NUM -> 127
# NUM -> 22.61
# NUM -> 15.5
# NUM -> 122.7
# NUM -> 348.2
# NUM -> 24.9
# NUM -> 28.375
# NUM -> 4695
# NUM -> 1035000
# NUM -> 60000
# NUM -> 62.7
# NUM -> 1.06
# NUM -> 24.3
# NUM -> 128.19
# NUM -> 2687.53
# NUM -> 1761.0
# NUM -> 403
# NUM -> 438845
# NUM -> 3.46
# NUM -> 2.9428
# NUM -> 141.7
# NUM -> 5.23
# NUM -> 525000
# NUM -> 452.76
# NUM -> 8.328
# NUM -> 0.51
# NUM -> 5.2
# NUM -> 881969
# NUM -> 734.8
# NUM -> 498
# NUM -> 1.08
# NUM -> 4.35
# NUM -> 78.625
# NUM -> 174.5
# NUM -> 99.385
# NUM -> 415.3
# NUM -> 496
# NUM -> 105.4
# NUM -> 268.6
# NUM -> 81.125
# NUM -> 3.26
# NUM -> 26.9
# NUM -> 1996
# NUM -> 14.44
# NUM -> 126630000
# NUM -> 4.32
# NUM -> 416
# NUM -> 422.1
# NUM -> 351.5
# NUM -> 848.7
# NUM -> 700.0
# NUM -> 13.05
# NUM -> 39
# NUM -> 368.5
# NUM -> 2080
# NUM -> 1.44
# NUM -> 44.3
# NUM -> 813
# NUM -> 502
# NUM -> 204
# NUM -> 394
# NUM -> 62.25
# NUM -> 334.5
# NUM -> 141.9
# NUM -> 12.4
# NUM -> 715.1
# NUM -> 9.8
# NUM -> 35544.87
# NUM -> 2.62
# NUM -> 1425035
# NUM -> 1.26
# NUM -> 12.375
# NUM -> 1214
# NUM -> 20.42
# NUM -> vıı
# NUM -> 2057750000
# NUM -> 4830
# NUM -> 208
# NUM -> 3.53
# NUM -> %
# NUM -> 43.5
# NUM -> 15.625
# NUM -> 613.7
# NUM -> 551
# NUM -> 4.7
# NUM -> 1.8415
# NUM -> 1700
# NUM -> 355
# NUM -> 213
# NUM -> 1.5805
# NUM -> 7.9
# NUM -> 15.6
# NUM -> 1.5795
# NUM -> 32.125
# NUM -> 366.85
# NUM -> 675400000
# NUM -> 6.6
# NUM -> 340.7
# NUM -> 34
# NUM -> 4.97
# NUM -> 0.94
# NUM -> 17:00
# NUM -> 268.98
# NUM -> 1.592
# NUM -> 1.55
# NUM -> 430.3
# NUM -> 518.7
# NUM -> 2.19
# NUM -> 54.875
# NUM -> 2.78
# NUM -> 1.5753
# NUM -> 2170
# NUM -> 8.52
# NUM -> 93.75
# NUM -> 224
# NUM -> 1.39
# NUM -> 380
# NUM -> 3.625
# NUM -> 7.52
# NUM -> 01:20
# NUM -> 247.6
# NUM -> 332.38
# NUM -> 1.5775
# NUM -> 1.81
# NUM -> 21.5
# NUM -> 1.16
# NUM -> 225000
# NUM -> 2015
# NUM -> 11.125
# NUM -> 679.5
# NUM -> 0.004
# NUM -> 8.19
# NUM -> 279.8
# NUM -> 1111
# NUM -> 1848000
# NUM -> 52.1
# NUM -> 1200
# NUM -> 3.48
# NUM -> 104
# NUM -> 33.3
# NUM -> 7.7
# NUM -> 8.56
# NUM -> 486.1
# NUM -> 33.375
# NUM -> 873.9
# NUM -> 16.25
# NUM -> 9.671
# NUM -> 588350000
# NUM -> 1.5
# NUM -> 5600
# NUM -> 466
# NUM -> 6.66
# NUM -> 724.4
# NUM -> 7.62
# NUM -> 25.0
# NUM -> 33
# NUM -> 1.9
# NUM -> 95.2
# NUM -> 26000
# NUM -> 580
# NUM -> 2.77
# NUM -> 64
# NUM -> 191.4
# NUM -> 07:13
# NUM -> 515.1
# NUM -> 3.84
# NUM -> 31.4
# NUM -> 2.45
# NUM -> 13.63
# NUM -> 15000
# NUM -> 0.11
# NUM -> 204.8
# NUM -> 1048500000
# NUM -> 650
# NUM -> 395374
# NUM -> 09:38
# NUM -> 194.0
# NUM -> 135860000
# NUM -> 141.45
# NUM -> 366.55
# NUM -> 3.2
# NUM -> 135.6
# NUM -> 73100
# NUM -> 1/32
# NUM -> 833.6
# NUM -> 110000
# NUM -> 89.6
# NUM -> 50.1
# NUM -> 65.53
# NUM -> 582
# NUM -> 1.69
# NUM -> 111.48
# NUM -> 18.6
# NUM -> 8930000
# NUM -> 2613.73
# NUM -> 3425.22
# NUM -> 300000
# NUM -> 135000
# NUM -> 522.3
# NUM -> 623
# NUM -> 0.8
# NUM -> 36.25
# NUM -> 23.65
# NUM -> 39.55
# NUM -> 4346
# NUM -> 37300
# NUM -> 435
# NUM -> 6.76
# NUM -> 9.87
# NUM -> 331.4
# NUM -> 4.199
# NUM -> 129.97
# NUM -> 4.6875
# NUM -> 175.2
# NUM -> 2.91
# NUM -> 2135.5
# NUM -> 42.455
# NUM -> 2.17
# NUM -> 71.36
# NUM -> 527
# NUM -> 6.84
# NUM -> 44.08
# NUM -> 5.42
# NUM -> 869
# NUM -> 5.1
# NUM -> 4.25
# NUM -> 0.37
# NUM -> 110625
# NUM -> 201
# NUM -> 52.5
# NUM -> 279.39
# NUM -> 278.7
# NUM -> 72.6
# NUM -> 1.59
# NUM -> 4.07
# NUM -> 35.28
# NUM -> 99.1875
# NUM -> 4.6
# NUM -> 3.95
# NUM -> 15.8
# NUM -> 2603.48
# NUM -> 248.3
# NUM -> 10.1
# NUM -> 9232
# NUM -> 2.375
# NUM -> 51.65
# NUM -> 0.36
# NUM -> 190.1
# NUM -> 1976
# NUM -> 43.34
# NUM -> 1.22
# NUM -> 20.375
# NUM -> 5.77
# NUM -> 38
# NUM -> 493
# NUM -> 1.255
# NUM -> 975.0
# NUM -> 1.15
# NUM -> 0.14
# NUM -> 1.83
# NUM -> 50000
# NUM -> 106
# NUM -> 13.15
# NUM -> 38.7
# NUM -> 252
# NUM -> 1.19
# NUM -> 478
# NUM -> 1.72
# NUM -> trilyon
# NUM -> 56
# NUM -> 110.4
# NUM -> 105.39
# NUM -> 57.5
# NUM -> 750
# NUM -> 4.66
# NUM -> 981.2
# NUM -> 249.5
# NUM -> 991
# NUM -> 42.9
# NUM -> 45000
# DET -> birçok
# DET -> her
# DET -> birkaç
# DET -> hiçbir
# ADV -> inatla
# ADV -> kilitlen
# ADV -> öylesine
# ADV -> aniden
# ADV -> şimdilik
# ADV -> özenle
# ADV -> sebepsizce
# ADV -> uğruna
# ADV -> ayrıca
# ADV -> yılla
# ADV -> ansızın
# ADV -> anında
# ADV -> üstünkörü
# ADV -> içinde
# ADV -> sessizce
# ADV -> sayıca
# ADV -> ortalamada
# ADV -> beraberinde
# ADV -> zekice
# ADV -> yukarıdan
# ADV -> ayakta
# ADV -> nihayet
# ADV -> kabaca
# ADV -> nereden
# ADV -> adına
# ADV -> nedeniyle
# ADV -> içtenlikle
# ADV -> muhakkak
# ADV -> bana
# ADV -> vasıtasıyla
# ADV -> günlüğüne
# ADV -> katiyen
# ADV -> yüzünden
# ADV -> yüzden
# ADV -> bıçakla
# ADV -> düpedüz
# ADV -> oradan
# ADV -> resmen
# ADV -> tembelce
# ADV -> bundan
# ADV -> nasılsa
# ADV -> saatlerce
# ADV -> ezbere
# ADV -> apaçık
# ADV -> ölümüne
# ADV -> tamamen
# ADV -> pal
# ADV -> bakarak
# ADV -> peki
# ADV -> dikkatle
# ADV -> pekala
# ADV -> tümüyle
# ADV -> esinlen
# ADV -> günde
# ADV -> çoğunlukla
# ADV -> kıkırda
# ADV -> düşüncesizce
# ADV -> kendince
# ADV -> fazlaca
# ADV -> tıpkı
# ADV -> kabilinden
# ADV -> nadiren
# ADV -> sonradan
# ADV -> memnuniyetle
# ADV -> neredeyse
# ADV -> açıkçası
# ADV -> haftaya
# PRON -> hep
# ADV -> bazen
# ADV -> yıllığına
# ADV -> hâlihazırda
# ADV -> böylece
# ADV -> seneye
# ADV -> belki
# ADV -> halihazırda
# ADV -> ille
# ADV -> böylesine
# ADV -> dikine
# ADV -> epey
# ADV -> kısaca
# ADV -> sertleş
# ADV -> geçenlerde
# ADV -> yakından
# ADV -> yukarıda
# ADV -> genelde
# ADV -> yanlışlıkla
# ADV -> yalnızca
# ADV -> şahsen
# ADV -> şimdiden
# ADV -> titizlikle
# ADV -> bize
# ADV -> elbette
# ADV -> doğrusu
# ADV -> sayesinde
# ADV -> acilen
# ADV -> nispeten
# ADV -> şiddetle
# ADV -> cömertçe
# ADV -> tekrardan
# ADV -> özellikle
# ADV -> asla
# ADV -> yolla
# ADV -> gerçi
# ADV -> sabahleyin
# ADV -> kurnazca
# ADV -> zamanında
# ADV -> kısmen
# ADV -> gitgide
# ADV -> rahatlıkla
# ADV -> ölesiye
# ADV -> ileride
# PP -> hem
# ADV -> sabahları
# ADV -> sırasıyla
# ADV -> iken
# ADV -> yerine
# ADV -> tamamıyla
# ADV -> delir
# ADV -> gerçekte
# ADV -> bayağı
# ADV -> dünyada
# ADV -> galiba
# ADV -> fazlasıyla
# ADV -> gayet
# ADV -> üzerine
# ADV -> aylarca
# ADV -> bakımdan
# ADV -> basitçe
# ADV -> dahası
# ADV -> gizlice
# ADV -> başkaca
# ADV -> aynen
# ADV -> sabaha
# ADV -> nereye
# ADV -> kopar
# ADV -> hükmen
# ADV -> nihayetinde
# ADV -> tahminen
# ADV -> boyuna
# ADV -> derinlemesine
# ADV -> üfle
# ADV -> yürekten
# ADV -> kayıtsızca
# ADV -> aracılığıyla
# ADV -> bunda
# ADV -> yakınlarda
# ADV -> haliyle
# ADV -> derhal
# ADV -> gittikçe
# ADV -> başlangıçta
# ADV -> görünmez
# ADV -> maalesef
# ADV -> detaylı
# ADV -> kısacası
# ADV -> yoluyla
# ADV -> basitleş
# ADV -> nitekim
# PP -> oysa
# ADV -> hafifçe
# ADV -> nezdinde
# ADV -> bizzat
# ADV -> aslen
# ADV -> geceleri
# ADV -> yeniden
# ADV -> oraya
# ADV -> üzerinde
# ADV -> baştan
# ADV -> hâlâ
# ADV -> birdenbire
# ADV -> haksızca
# ADV -> alenen
# ADV -> daha
# ADV -> saatinde
# ADV -> lütfen
# ADV -> sonuçta
# ADV -> zaten
# ADV -> esasen
# ADV -> tesadüfen
# ADV -> yağla
# ADV -> sadece
# ADV -> hayretle
# ADV -> kendiliğinden
# ADV -> böylelikle
# ADV -> yanaş
# ADV -> aralıkta
# ADV -> hızla
# ADV -> illa
# ADV -> sonunda
# ADV -> salt
# ADV -> yeterince
# ADV -> umumiyetle
# ADV -> aksine
# ADV -> öylece
# ADV -> sahiden
# ADV -> başlan
# ADV -> doğrul
# ADV -> öncelikle
# ADV -> eskiden
# ADV -> nerede
# ADV -> keşke
# ADV -> derinden
# ADV -> ardından
# ADV -> tersine
# ADV -> çabucak
# ADV -> sanki
# ADV -> giderek
# ADV -> pek
# ADV -> kasten
# ADV -> bilhassa
# ADV -> burada
# ADV -> birazcık
# ADV -> pahasına
# PP -> ancak
# ADV -> ondan
# ADV -> uyarınca
# ADV -> kesinlikle
# ADV -> zarfında
# ADV -> delikanlı
# ADV -> bakımından
# ADV -> münhasıran
# ADV -> muhtemelen
# ADV -> çoktan
# ADV -> orada
# ADV -> sürekli
# ADV -> sana
# ADV -> hesabına
# ADV -> birden
# ADV -> fiilen
# ADV -> zararına
# ADV -> yanında
# ADV -> genellikle
# ADV -> mutlaka
# ADV -> daima
# ADV -> ustalıkla
# ADV -> direkt
# ADV -> hemen
# ADV -> kaygısızca
# ADV -> çalkala
# ADV -> aslında
# ADV -> şimdilerde
# PP -> hatta
# ADV -> adeta
# ADV -> derhâl
# ADV -> halen
# ADV -> hala
# ADV -> kolaylıkla
# ADV -> çılgınca
# ADV -> iyice
# ADV -> yakında
# ADV -> süresince
# ADV -> çaresizce
# ADV -> yine
# ADV -> gerçekten
# ADV -> önceden
# ADV -> dolayısıyla
# ADV -> ilaveten
# ADV -> işte
# ADV -> ortaklaşa
# ADV -> mesela
# ADV -> henüz
# ADV -> tesadüfi
# ADV -> esnasında
# ADV -> külliyen
# ADV -> oldukça
# ADV -> bugünlerde
# ADV -> kendinden
# ADV -> yavaşça
# ADV -> etraflıca
# PP -> yanısıra
# PP -> nazaran
# PP -> dair
# PP -> takdirde
# PP -> ötürü
# PP -> istinaden
# PP -> evvel
# PP -> göre
# PP -> rağmen
# PP -> boyunca
# PP -> aşkın
# PP -> takiben
# PP -> ile
# PP -> karşın
# PP -> üzere
# PP -> dolayı
# PP -> yana
# PP -> diye
# PRON -> birbiri
# PRON -> sen
# PRON -> hepsi
# PRON -> diğeri
# PRON -> nere
# PRON -> kendi
# PRON -> siz
# PRON -> birbirleri
# PRON -> tümü
# PRON -> hiçbiri
# PP -> olsun
# PP -> ve
# PP -> örneğin
# PP -> gerekse
# PP -> yoksa
# PP -> ama
# PP -> neyse
# PP -> da
# PP -> dahi
# PP -> zira
# PP -> ister
# PP -> çünkü
# INTJ -> ya
# PP -> fakat
# PP -> yani
# PP -> vb
# PP -> ila
# PP -> şayet
# PP -> vs
# PP -> veya
# AUX -> değil
# AUX -> mi
# X -> %3.5
# X -> %7.875
# X -> %8.01
# X -> 21:00-22:30
# X -> %83
# X -> tefek
# X -> %7.986
# X -> %95
# X -> %8.2
# X -> derli
# X -> %17
# X -> 89-107
# X -> @
# X -> %11.3
# X -> %9.5
# X -> allak
# X -> %7.01
# X -> %7.88
# X -> %24
# X -> %6.90
# X -> 2-3
# X -> %9.4
# X -> 3-4
# X -> 1989-86
# X -> 20-21
# X -> %99
# X -> 1989-1
# X -> %61
# X -> %6.8
# X -> 13:30-18:00
# X -> %1.9
# X -> 1989-85
# X -> %9.39
# X -> _
# X -> %14
# X -> 4-5
# X -> %7.10
# X -> %3.4
# X -> %9.90
# X -> %8.61
# X -> %3.846
# X -> %7.53
# X -> 89-136
# X -> %1
# X -> %10.48
# X -> 1997-2000
# X -> 2-23
# X -> %2.9
# X -> 1962-63
# X -> %4.8
# X -> %25
# X -> %6.5
# X -> 1995-1999
# X -> %0.25
# X -> %18
# X -> %3.75
# X -> 1991-1996
# X -> %7.6
# X -> %7.52
# X -> %0.3
# X -> %5.2
# X -> %46
# X -> %10.03
# X -> 5-10
# X -> %7
# X -> %1.4
# X -> %6.4
# X -> %3.43
# X -> 800-900
# X -> %9.6
# X -> %3.9
# X -> %3.1
# X -> 231-191
# X -> %8
# X -> %60
# X -> %65
# X -> %7.92
# X -> %68
# X -> 14-16
# X -> %7.73
# X -> ışıl
# X -> %6
# X -> 22-23
# X -> %69
# X -> %19
# X -> %4.4
# X -> %85
# X -> %27.1
# X -> %3.3
# X -> %3.865
# X -> %44
# X -> 747-400
# X -> %6.15
# X -> %51.4
# X -> 1989-1987
# X -> %99.1875
# X -> %16
# X -> %7.55
# X -> 21-23
# X -> 89-52
# X -> %11
# X -> %2.7
# X -> %3.7
# X -> %9.19
# X -> %8.42
# X -> %0.2
# X -> %7.82
# X -> %5.4
# X -> dobra
# X -> %4
# X -> %8.9
# X -> %1.7
# X -> %2.45
# X -> %36
# X -> %9.617
# X -> %37
# X -> 2003-2005
# X -> 5-12
# X -> 20-23
# X -> %0.32
# X -> %0.5
# X -> tokuş
# X -> 1989-83
# X -> %5.3
# X -> bullak
# X -> 1982-85
# X -> %13
# X -> %7.71
# X -> %22
# X -> %80
# X -> 1989-84
# X -> %2
# X -> %12
# X -> %8.292
# X -> %51
# X -> %7.31
# X -> %7.227
# X -> 1991-1992
# X -> %4.7
# X -> %7.78
# X -> %7.75
# pp -> ki
# INTJ -> oh
# INTJ -> yaşasın
# INTJ -> hadi
# INTJ -> aman
# INTJ -> ah
# INTJ -> e
# INTJ -> haydi
# INTJ -> ha
# INTJ -> vay
# INTJ -> of
# INTJ -> eh

# %%
grammar_all = []
for line in lines.split("\n"):
    if "#" in line or len(line) < 1: continue
    grammar_all.append(line)
    
grammar_all = "\n".join(grammar_all)
print(grammar_all)
# Out:
# S -> PRO1 VPPAST1
# S -> PRO2 VPPAST2
# S -> PRO3 VPPAST3
# S -> NP VPPAST1
# S -> NP VPPAST2
# S -> NP VPPAST3
# S -> PRONOUNCLAUSE1 VPPAST1
# S -> PRONOUNCLAUSE2 VPPAST2
# S -> PRONOUNCLAUSE3 VPPAST3
# VPPAST1 -> VP PAST1
# VPPAST2 -> VP PAST2
# VPPAST3 -> VP PAST3
# S -> PRO1 VPPRE1
# S -> PRO2 VPPRE2
# S -> PRO3 VPPRE3
# S -> NP VPPRE1
# S -> NP VPPRE2
# S -> NP VPPRE3
# S -> PRONOUNCLAUSE1 VPPRE1
# S -> PRONOUNCLAUSE2 VPPRE2
# S -> PRONOUNCLAUSE3 VPPRE3
# VPPRE1 -> VP PRE1
# VPPRE2 -> VP PRE2
# VPPRE3 -> VP PRE3
# S -> PRO1 VPFUT1
# S -> PRO2 VPFUT2
# S -> PRO3 VPFUT3
# S -> NP VPFUT1
# S -> NP VPFUT2
# S -> NP VPFUT3
# S -> PRONOUNCLAUSE1 VPFUT1
# S -> PRONOUNCLAUSE2 VPFUT2
# S -> PRONOUNCLAUSE3 VPFUT3
# VPFUT1 -> VP FUT1
# VPFUT2 -> VP FUT2
# VPFUT3 -> VP FUT3
# S -> PRO1 NP POSPRO1
# S -> PRO2 NP POSPRO2
# S -> PRO3 NP POSPRO3
# NP -> NP POSPRO1
# NP -> NP POSPRO2
# NP -> NP POSPRO3
# PRONOUNCLAUSE1 -> PRO1 NP
# PRONOUNCLAUSE2 -> PRO2 NP
# PRONOUNCLAUSE3 -> PRO3 NP
# S -> NP VP PREPARTICLE
# NP -> ADJ NP
# NP -> ADJ NP PL
# NP -> ADJ SING NP
# PLNOUN -> NP PL
# SINGNP -> SING NP
# NP -> SING ADJ NP
# ADJCLAUSE -> ADJ NP
# NP -> NP PL
# NP -> NP NP
# NP -> NP PP
# ADJ -> ADJ ADJ
# VP -> ADV NP VP
# NPVP -> NP VP
# VP -> ADV VP
# VP -> QP VP
# QP -> Q NP
# QCLAUSE1 -> Q POSPROPL1
# QCLAUSE2 -> Q POSPROPL2
# QCLAUSE3 -> Q POSPROPL3
# Q -> mı
# Q -> mi
# Q -> ne
# PRO1 -> ben
# PRO2 -> sen
# PRO3 -> o
# PROPL1 -> biz
# PROPL2 -> siz
# PROPL3 -> onlar
# PAST3 -> ydi
# PAST3 -> tı
# PAST3 -> du
# PAST3 -> tu
# PAST3 -> ydı
# PAST3 -> dü
# PAST3 -> tü
# PAST3 -> ydu
# PAST3 -> dı
# PAST3 -> ydü
# PAST3 -> di
# PAST3 -> ti
# PAST3 -> medi
# PAST3 -> madı
# PRE1 -> iyor
# PRE1 -> ıyor
# PRE1 -> yor
# FUT1 -> eceğim
# PAST1 -> dım
# PAST1 -> dum
# PAST1 -> dim
# PAST1 -> tım
# PAST1 -> dük
# PAST1 -> dık
# PAST1 -> dik
# FUT3 -> yecek
# PAST3 -> emediler
# FUT3 -> ecektir
# FUT1 -> meyeceğiz
# FUT3 -> meyecek
# FUT3 -> mayacak
# PRE1 -> mıyorlar
# PRE1 -> miyor
# PAST3 -> tiler
# PAST3 -> dılar
# PAST3 -> rdı
# FUT3 -> meyecekler
# PRE2 -> maktadır
# PAST3 -> mişti
# PAST3 -> mıştı
# PRE2 -> mekte
# PAST2 -> din
# PAST1 -> iyordu
# PRE1 -> ıyorum
# PAST2 -> dunuz
# PRE1 -> yorlar
# PRE1 -> ıyorlar
# PRE1 -> ıyorsunPOSPRO1 -> m
# POSPRO1 -> üm
# POSPRO1 -> ım
# POSPRO1 -> yım
# POSPRO1 -> i
# POSPRO1 -> um
# POSPRO1 -> yim
# POSPRO1 -> yum
# POSPRO1 -> im
# POSPROPL1 -> yiz
# POSPROPL1 -> yüz
# POSPROPL1 -> ız
# POSPROPL1 -> üz
# POSPROPL1 -> yuz
# POSPROPL1 -> iz
# POSPROPL1 -> yız
# POSPROPL1 -> lım
# POSPROPL1 -> uz
# POSPROPL1 -> k
# POSPRO2 -> sin
# POSPRO2 -> s
# POSPRO2 -> ı
# POSPRO2 -> n
# POSPRO2 -> sun
# POSPRO2 -> sın
# POSPROPL2 -> yin
# POSPROPL2 -> ın
# POSPROPL2 -> nüz
# POSPROPL2 -> siniz
# POSPROPL2 -> niz
# POSPROPL2 -> sınız
# POSPROPL2 -> ı
# POSPROPL2 -> n
# POSPROPL2 -> nız
# POSPROPL2 -> sunuz
# POSPROPL2 -> nuz
# POSPRO3  -> ı
# POSPRO3  -> s
# POSPRO3  -> n
# POSPRONPL3  -> ler
# POSPRONPL3  -> r
# POSPRONPL3  -> lar
# POSPRONPL3  -> l
# POSPRONPL3  -> a
# NP -> 35-uluslu
# NP -> bakiye
# NP -> amerikalı
# NP -> broncs
# NP -> ikmal
# VP -> mahvet
# NP -> istirham
# VP -> yer
# NP -> yıkama
# NP -> üstün
# VP -> dosyala
# VP -> hafta
# NP -> raslantı
# NP -> link
# NP -> 508-puanlık
# NP -> ala
# NP -> pens
# NP -> defter
# NP -> muharebe
# NP -> kürek
# NP -> sonat
# NP -> dedikodu
# NP -> adliye
# NP -> hazırlık
# NUM -> 3.69
# NP -> teknik
# NP -> pompa
# VP -> seç
# NP -> karakteristik
# NP -> dük
# NP -> havaliman
# NP -> kasti
# NP -> anti
# NP -> topaz
# NP -> külfet
# NP -> masum
# VP -> bayi
# VP -> adım
# NP -> gelgit
# NP -> gümrükle
# NP -> evreleme
# NP -> tüvit
# NUM -> 1990
# NP -> söyledi.
# NP -> bonus
# NP -> dün
# NP -> dernek
# NP -> şişe
# NP -> belirtilen
# NP -> 197
# NP -> barınak
# VP -> ek
# NP -> 7.875,
# NP -> şaşkınlık
# NP -> nabız
# NP -> conta
# VP -> güç
# VP -> karar
# NP -> söylerimleyle
# NP -> ateş
# NP -> casusluk
# VP -> rakip
# NP -> kolajen
# NP -> selef
# NP -> parıltı
# VP -> sınır
# NP -> parola
# NP -> aksiyom
# NP -> açım
# NP -> terminal
# NP -> onkogenler
# NP -> kapitone
# VP -> hat
# NP -> kuruş
# NP -> hekim
# NP -> 821
# VP -> üstlen
# NP -> kârın
# NP -> doğum
# NP -> teslim
# NP -> somatostatin
# NP -> karyola
# NP -> uzatma
# NP -> yılbaş
# NP -> müteahhit
# NUM -> 1980
# VP -> zarar
# VP -> dil
# NP -> ideal
# NP -> 1890
# NP -> umar
# NP -> tercüman
# NP -> vaat
# NP -> mahsul
# NP -> filo
# NP -> yağmala
# VP -> destek
# NP -> güneş
# NP -> darma
# NP -> 455
# VP -> alt
# NP -> istila
# NP -> tantana
# NP -> kumaş
# NP -> ihtiva
# NP -> aslan
# NP -> başkaldır
# VP -> taşı
# VP -> kır
# NP -> b
# NP -> anlayış
# NP -> ağır
# NP -> süreçin
# NP -> katalog
# NP -> aleyh
# NP -> 123.5
# NP -> zorlama
# NP -> muğlaklık
# NP -> doktrin
# NP -> dizel
# NP -> lise
# NP -> oyalayıcı
# NP -> mermi
# NP -> bilet
# NP -> 'inc.,
# NP -> 49-uluslu
# NP -> türk
# NP -> yaşan
# VP -> sabit
# NP -> komisyoncu
# NP -> isteksiz
# NP -> oturum
# NP -> 2890
# NP -> gündüz
# NP -> 368
# NP -> radyasyon
# NP -> boykot
# NP -> rota
# NP -> ​​ayarlamak
# NP -> 414
# VP -> ilk
# NP -> kalorifer
# VP -> yol
# NP -> eşdeğerlik
# NP -> franchise
# NP -> kuzen
# NP -> aks
# NUM -> ikinci
# NP -> riyakarlık
# NP -> tecrit
# NP -> ayak
# NP -> makbuz
# NP -> hakaret
# NP -> ikonoklastik
# NP -> kayarak
# NP -> leh
# NP -> kesimhane
# NP -> vaha
# NP -> kılıç
# NP -> eldiven
# NP -> yönerge
# NP -> inç
# NP -> kazı
# NP -> eklenti
# NP -> boğmaca
# NP -> 23-5'lik
# NP -> değişim
# NP -> orman
# NP -> 2653.28
# NP -> teşviki
# NP -> asalet
# NP -> yanlışlık
# NP -> alay
# NP -> gözetle
# NP -> kovalamaca
# NP -> doğruluk
# VP -> öngör
# NUM -> 7.93
# NP -> ons'luk
# NP -> piyasısı
# NP -> uyuştur
# NP -> esinti
# VP -> yaka
# NP -> plastik
# NP -> var.
# NP -> orkestra
# NP -> kontra
# VP -> baba
# VP -> öde
# VP -> koca
# VP -> yüzleş
# NP -> çöp
# NP -> onarım
# NP -> ikame
# VP -> çarp
# NP -> kısas
# NP -> gözalt
# VP -> bil
# NP -> matine
# NP -> göl
# NP -> italyan
# NP -> babaerkil
# NP -> dargınlık
# VP -> kara
# NP -> çamur
# NP -> saygıdeğer
# VP -> doğ
# NP -> alıcılar'
# NP -> domine
# NP -> metal
# NP -> kırılgan
# NP -> akvaryum
# NP -> teveccüh
# NUM -> 43
# NP -> tekamül
# NP -> %70
# NP -> soylu
# VP -> rafine
# NP -> deforme
# NP -> lüks-araba
# NP -> km
# NP -> soğut
# NP -> nohut
# NP -> ingiliz
# VP -> incele
# NP -> dip
# NP -> 7.22
# VP -> şaşır
# NP -> gayrimenkuldeydi
# VP -> alıntı
# NP -> tat
# NP -> mobilya
# NP -> %10.3'ünü
# NP -> ayna
# NP -> inziva
# NP -> çalın
# NP -> salon
# NP -> sempati
# NUM -> 1959
# NP -> bilge
# NP -> kobay
# NP -> bebeklik
# NP -> bina
# NP -> 130.80
# NP -> köylü
# NP -> ince
# NP -> bacak
# VP -> kapat
# NP -> üstünlük
# VP -> sahte
# NP -> seramik
# NP -> jaguar
# NP -> applause
# NP -> diyabetik
# NP -> cin
# NP -> metafor
# NP -> patika
# NP -> kösteklen
# NP -> ifade
# NP -> çağırılan
# NP -> yoğunluk
# NP -> dost
# NP -> davetiye
# NP -> şablon
# NP -> davet
# NP -> fıkra
# NP -> 1190.43
# NP -> keman
# NP -> merdiven
# NP -> genç
# NP -> fabrika
# NP -> ispanyol
# NP -> sistem
# NP -> taze
# NP -> artçı
# NP -> alçı
# NP -> antibiyotik
# VP -> yük
# NP -> manipülatif
# NP -> mayala
# NP -> pohpohla
# NUM -> 7.89
# VP -> ekle
# VP -> göster
# NP -> hiç
# NP -> birik
# NP -> brokerları
# NP -> hüsran
# NP -> akrelik
# NP -> vezin
# NP -> gayrimenkuller
# NP -> sonra
# NP -> leke
# NP -> resesyon
# VP -> kelime
# NP -> basmakalıp
# VP -> gerile
# NP -> göz
# NP -> klinik
# NP -> panama
# NP -> avantacı
# NUM -> 13
# NP -> ekipman
# NUM -> 61
# NP -> izlenim
# NP -> bolluk
# NP -> %20'lik
# NP -> tasarlanmıştır.
# NP -> 120-günlük
# NP -> f
# NP -> ot
# NP -> türbin
# NP -> yassı
# NP -> prospektüs
# NP -> varyasyon
# NP -> anti-tröst
# NP -> antika
# VP -> sok
# NP -> dehşet
# NP -> analizci
# NP -> anahtar
# VP -> garantile
# NP -> özelleştirme
# NP -> burbonudur
# VP -> bağlı
# NP -> dayak
# NP -> kakao
# NP -> simsarlık
# NP -> yoksunluk
# NP -> bulaş
# NP -> gerçeklik
# NP -> 4440
# NP -> yıprat
# NP -> milliyetçi
# NP -> köşe
# NP -> öncül
# NP -> mercek
# NP -> ödeme
# NP -> platform
# NP -> fiyat/kazanç
# NP -> tahammül
# VP -> ilerle
# NP -> gayri
# NP -> dansçı
# NP -> eyalet
# NP -> 18.125
# NP -> alamet
# NP -> dudak
# VP -> sırala
# NP -> çimenlik
# VP -> oluş
# NP -> şimdiye
# VP -> mal
# NP -> 445.23
# NP -> 382
# NP -> protokol
# NP -> yaşam
# NP -> iyi.
# NP -> eziyet
# NP -> le
# NP -> diz
# VP -> aşama
# NP -> damga
# NP -> saygı
# NP -> un
# NP -> şömine
# NP -> feda
# NP -> rüşvet
# NP -> temas
# NP -> bağlam(lar)ında
# NP -> bağımsız
# NP -> odak
# NP -> moda
# NP -> alet
# NP -> gelen
# NP -> kumarhane
# NP -> antitröst
# NP -> vızıltı
# NP -> ,10:30-13:30
# NP -> tahmini
# NP -> teşvik
# NP -> hücum
# NP -> mercan
# NP -> ideolog
# NP -> implantasyon
# NP -> bunalım
# NP -> öğretmen
# NP -> devrimci
# NP -> oynaklık
# NP -> %6.25
# NP -> meraklı
# NP -> gözde
# NP -> iletken
# NP -> cila
# NP -> şerefiye
# NP -> deri
# NP -> gözdağ
# NP -> yumruk
# VP -> kastet
# NP -> elektrik
# NP -> benzerlik
# NP -> site
# NP -> ümit
# NP -> ekran
# NP -> beylik
# NP -> hayvan
# VP -> ön
# NP -> saye
# NP -> 3.çeyreğinde
# NP -> indeks
# NP -> füzyon
# NP -> lisanslama
# VP -> yoğun
# NP -> ambalaj
# VP -> yar
# NP -> örüntü
# NP -> müslüman
# NP -> kapama
# VP -> çağrı
# NP -> reklamverenlerle
# NP -> ehliyet
# NP -> malpraktis
# NP -> 2.659.22
# NP -> konserve
# NP -> işbirliğiden
# NP -> kârına
# NP -> alışkan
# NP -> dava
# NP -> olasılık
# NP -> broker-bayi
# NP -> adaylık
# VP -> diktatör
# NUM -> 47
# NP -> eksi
# NP -> taahhüt
# NP -> diyor.
# NP -> 130.73
# NP -> yumurta
# NP -> borsacı
# NP -> franchiselarınız
# NP -> balistik
# NP -> amortisman
# NP -> çoğalıyor.
# NP -> 130.36
# NP -> kopya
# NP -> tutanak
# NP -> aracı-bayi
# NP -> tank
# NP -> sanayici
# NP -> hareketsizlik
# NP -> 1975
# NP -> saçık
# NP -> makineli
# NP -> 1978
# NP -> lanet
# NP -> pasaport
# NP -> genel
# NP -> kurultay
# NP -> sigortalı
# NP -> (mpi)'dır
# VP -> birleş
# NP -> masaj
# NP -> erkek-verimli
# NP -> asıl
# NP -> havayol
# NP -> harici
# NP -> jumbos
# NUM -> 7.25
# NP -> kayalık
# NP -> abd
# NP -> %40'ından
# NP -> tedirgin
# NP -> yönetmenlik
# NP -> talip
# NP -> içerik
# NP -> yıldönüm
# NP -> 131.64'de
# VP -> değ
# NP -> kıpırtı
# NP -> gazetecilik
# NP -> hakim
# NP -> %52'sini
# NP -> 74.125
# NP -> perşembe
# VP -> genişlet
# NP -> ucube
# NP -> partner
# NP -> teknisyen
# NP -> 00.01
# VP -> patla
# VP -> kurul
# NP -> nakliye
# NUM -> 22
# NP -> itfaiyeci
# NP -> sağlama
# NP -> product
# NP -> teşvikinin
# NP -> müdafi
# VP -> yatış
# NP -> anlam
# NP -> birmingham
# NP -> yayılma
# VP -> süreç
# NP -> lokanta
# NP -> kısıntı
# NP -> türban
# NP -> ekspres
# NP -> ihraççıları
# NP -> bitim
# NP -> %70'inden
# NP -> verecek
# NP -> liyakat
# NP -> gözbebeğimiz
# VP -> sebep
# VP -> orta
# NP -> bataklık
# NP -> sertifikasyon
# VP -> iyimser
# VP -> emir
# NP -> konteyner
# NP -> hacmi-testi
# NP -> tahsil
# NP -> ayçiçek
# NP -> kardeş
# VP -> açık
# NP -> dank
# NP -> gecikme
# NP -> küpe
# NP -> itiraf
# NP -> pekiş
# NP -> hasır
# NP -> anti-damping
# NP -> kovboy
# NP -> aksilik
# NP -> boğa
# NP -> oda
# VP -> boğ
# NP -> kulüp
# NP -> makinelerininin
# NP -> alım-satıma
# NP -> katılan
# NP -> akis
# NP -> ilahiyatçı
# NP -> federasyon
# NP -> düzenleme
# NP -> hayal
# NP -> diğer
# VP -> performans
# VP -> gerileme
# NP -> atasöz
# NP -> manşet
# NP -> çelik
# NUM -> 48
# NP -> kürkçü
# NP -> ihmal
# NP -> ittifak
# NP -> duruşma
# NP -> hacim
# NP -> hurdalık
# NP -> aylık
# NP -> inkar
# NP -> rıza
# NP -> basınç
# NP -> müphem
# NP -> ironik
# VP -> miktar
# NP -> savcılık
# NP -> keçi
# NUM -> 2645.08
# NUM -> 54
# NP -> kozmetik
# NP -> icracı
# NP -> kargo
# NP -> moral
# NP -> kaygı
# NP -> ünite
# NP -> ayrımcılığı
# NP -> food
# NP -> kılıf
# NP -> monte
# NP -> mükellef
# NP -> yazılı
# VP -> konuş
# NP -> rehin
# VP -> komisyon
# NP -> mesai
# NP -> gıda
# NP -> 20-hisseli
# VP -> doğru
# NP -> maç
# NP -> fuar
# NP -> soğukluk
# VP -> yavaşla
# NP -> zorluk
# NP -> müracaat
# NP -> turizm
# NUM -> 1\/8
# NP -> peşinat
# NP -> imtiyaz
# NP -> eğer
# NP -> ant
# NP -> çip
# VP -> pazarla
# NP -> psikanaliz
# NP -> ball
# NP -> giyim
# NP -> anapara
# VP -> yetiştir
# NP -> çekiş
# NP -> işgücü
# NP -> lisanslamayla
# NP -> zihin
# NP -> belirti
# NP -> akor
# NP -> lübnanlı
# NP -> global
# NP -> depo
# NP -> denizci
# NP -> teamül
# NP -> maymun
# NP -> karpit
# NP -> 5.651
# NP -> darbe-kuvveti
# NP -> flört
# NP -> sukunet
# NP -> kepenk
# NP -> poz
# NP -> varis
# NP -> tek-a
# NP -> and
# VP -> yatak
# NP -> kışın
# NP -> rampa
# NP -> ayı
# NP -> sayfa
# NP -> kararname
# NP -> propogandayı
# NP -> ihracat
# NP -> 16:30
# NP -> buzdolaplarını
# NP -> rating
# VP -> sev
# NP -> özür
# NP -> söyleşi
# NP -> saldırma
# NP -> emperyal
# NP -> hurda
# NP -> psilyumu
# NP -> yeryüz
# NP -> 1960'da
# NP -> garip
# NP -> evrak
# NP -> biriktir
# NP -> lastik
# NP -> ananas
# NP -> eleştiri
# NP -> içindekiler
# NP -> lider
# NP -> ergenlik
# NP -> eğitmen
# NP -> acentelik
# NP -> başkanlık
# NP -> insanoğlu
# NP -> yurt
# VP -> uç
# NP -> alım-satımına
# NP -> %30
# NP -> dinlen
# VP -> al
# NP -> pachinko
# NP -> ihtimal
# NP -> toynak
# VP -> önemse
# NP -> yapılandırma
# NP -> hissedarlıklara
# NP -> egemenlik
# NP -> konsorsiyum
# NP -> dr.
# NP -> gittikça
# VP -> sonlan
# NP -> proaktif
# VP -> girişimcilik
# NP -> rahibe
# VP -> temizle
# NP -> sırt
# NP -> amir
# NP -> muhafaza
# NP -> dayanıklılık
# NP -> toy
# NP -> yanlılık
# NP -> işbirliği
# NP -> katılımcı
# VP -> kategori
# NP -> %15'ini
# NP -> imal
# NP -> sürüklen
# NP -> hücre
# NP -> arzet
# NP -> canlılık
# NP -> yelpaze
# NUM -> 6
# VP -> giy
# NP -> %51'ini
# NP -> öngören/savunan
# NP -> çıkarma
# NP -> are
# NP -> tahsilat
# NP -> 936
# NP -> 1730
# NP -> gezin
# VP -> yerleştir
# NP -> saygısız
# VP -> çılgınlık
# NP -> disiplin
# NP -> faz
# VP -> başkan
# NP -> ispat
# NP -> ciddi
# VP -> öte
# NP -> büyüklük
# NP -> tüzük
# NP -> üniversite
# NP -> ifa
# NP -> ithalat-ihracat
# NUM -> 1.6055
# VP -> top
# NP -> jogging
# VP -> kay
# NP -> müzayede
# NP -> esna
# NP -> kardiyovasküler
# NP -> blok
# NP -> çit
# NP -> volatilite
# NP -> suitindeki
# NP -> şahit
# NP -> tadil
# NP -> tartma
# NP -> oksit
# NP -> eylemci
# VP -> yanlış
# VP -> danış
# NP -> batak
# NP -> bilim
# NP -> nadas
# NUM -> 1997
# VP -> hoşlan
# NP -> itaat
# VP -> çiz
# NP -> konjonktür
# NP -> tüketim
# NP -> muhafazakar
# NP -> ortadirek
# VP -> görünüm
# NP -> yarışmacı
# VP -> yaklaş
# NP -> tuğla
# NP -> işlev
# NP -> bilgilen
# NP -> dolaşım
# NP -> ekmek
# NP -> bir-paya-300
# VP -> baskıla
# VP -> çiftçi
# NP -> delegasyon
# NP -> yurtdışında
# NP -> psilyum
# NP -> bekleme
# NP -> çete
# NP -> tecrübe
# NUM -> 1\/2
# NP -> depresyon
# NP -> pamuk
# NP -> misyon
# NP -> yapım
# VP -> ödül
# NP -> endüstri
# VP -> çevir
# NP -> debelen
# NP -> olgunluk
# NP -> tatilci
# NP -> itele
# NP -> kelebek
# VP -> özel
# NP -> opera
# NP -> yıkı
# VP -> başarı
# NP -> şaşkın
# NP -> dar
# NP -> votka
# NP -> grip
# VP -> düzen
# VP -> yöntem
# NP -> serbestleş
# NP -> armadillo
# NP -> cevher
# NP -> kral
# VP -> tırman
# NP -> dans
# NP -> konser
# VP -> öl
# NP -> ayrıldı?
# NP -> %12'lik
# NP -> uyarlama
# NP -> üstelik
# NP -> mücadele
# NP -> yurtdışı
# NP -> gazi
# NUM -> 2005
# VP -> uğraş
# NP -> 84
# NP -> özsermaye
# NP -> buğday
# NP -> evet
# NP -> kote
# NP -> oy
# VP -> pazarlan
# NP -> birçoğuyle
# NP -> tereyağ
# NP -> endeksle
# VP -> karmaşık
# NP -> etiket
# NP -> 2638.73
# NP -> boya
# NP -> aktris
# NP -> bozgun
# VP -> sayfala
# NP -> temel
# NP -> kârlar
# NP -> ​​otomobil
# NP -> tişört
# NP -> telekomünikasyon
# NP -> motor
# NP -> baskın
# NP -> 30-pay
# VP -> tetik
# NP -> kanım
# NP -> seleksiyon
# NP -> şizofreni
# NP -> broşür
# NP -> d'alene
# NP -> 470'den
# NP -> fiber
# NP -> hâlihazır
# NP -> dayat
# NP -> kuşatma
# NP -> 60-gün
# NP -> empoze
# NP -> ilham
# NP -> 378.07
# VP -> iş
# NP -> hırpala
# NP -> tamir
# NP -> dert
# NP -> 10.13
# NP -> klorin
# NP -> felsefik
# NP -> karnaval
# NP -> master
# NP -> mola
# NP -> deyiş
# NP -> pediyatrik
# NP -> boru
# NP -> ficus
# NP -> geçme
# NP -> akçe
# VP -> sürükle
# NP -> silikon
# NP -> mülayim
# NUM -> 1991
# NP -> siper
# NP -> intihar
# NP -> dikkat
# NP -> a.m
# NP -> özellik
# NP -> kâr
# VP -> çatla
# VP -> üretici
# NP -> beden
# NP -> kylix
# NP -> fransız
# NP -> törpü
# NP -> 10.98
# NP -> sonbahar
# NP -> kaçık
# VP -> kuşku
# NP -> 4.çeyrekteki
# NP -> büyücülük
# NP -> gayrimenkule
# NUM -> 4
# NP -> enflasyon
# NP -> kaplama
# NP -> aksama
# NP -> punt
# NP -> uzmanlaş
# VP -> uğrat
# NP -> rapor
# NP -> tuz
# NP -> ''dedi
# NP -> polemik
# NP -> hayret
# NP -> taktik
# NP -> podyum
# NP -> içerdekilerin
# NP -> yatıştır
# VP -> kapasite
# NP -> şövalye
# NP -> cevap
# NP -> c
# NP -> avantaj
# NP -> stopaj
# NUM -> 1977
# NP -> arayış
# NP -> var:
# VP -> kent
# NP -> klasik
# VP -> satıl
# NP -> 3m'in
# NP -> bezybol
# NP -> dogs
# VP -> nokta
# NUM -> 289
# NP -> alkışlama
# NP -> pekin
# NP -> gasp
# VP -> cins
# VP -> koşul
# NP -> üyelik
# NP -> 1739.3
# NP -> merci
# NP -> davalı
# NP -> eczane
# NP -> kıyı
# NP -> gösteri
# NP -> kuzeybatı
# VP -> kanıtla
# VP -> büyük
# NP -> pizza
# NP -> %7.20
# NP -> 132,8
# VP -> acı
# NP -> şema
# VP -> harca
# NP -> taksi
# NP -> kanat
# NP -> form
# NP -> ayin
# NUM -> üç
# NP -> blues
# NP -> gala
# NP -> bürokrasi
# NP -> kanal
# NP -> öğreneceğim.
# NP -> karşıt
# NUM -> 1972
# NUM -> 7.92
# NP -> topçu
# NP -> eşitsizlik
# NP -> retinoblastoma
# NP -> menfaat
# NP -> şükür
# NP -> inşaa
# VP -> teklif
# NP -> palamedes
# NP -> madalya
# NP -> kek
# NP -> otobüs
# NP -> zift
# NP -> aerobik
# NP -> yemek
# VP -> felaket
# NP -> fırsatçı
# VP -> yetkili
# NP -> eser
# NP -> ömür
# NP -> ayrıntılrı
# NP -> sarsıntı
# NP -> ambargo
# NP -> %8.17'lik
# VP -> dur
# NP -> saldırganları
# NP -> kornea
# NP -> erken
# NP -> %9.9'luk
# NP -> özkaynak
# NP -> dizginle
# NP -> 951
# VP -> normal
# NP -> krem
# NP -> dün`''
# NP -> dürüst
# NP -> yaşlan
# NP -> kurban
# NP -> albeni
# NP -> nevi
# NP -> hafif
# NP -> 100-paylık
# NP -> uğrak
# NP -> elitistleri
# NP -> çekilme
# NP -> bakımev
# NP -> %50
# NP -> 7/8'ye
# NP -> şikâyet
# NP -> asker
# NP -> cumhurbaşkan
# NP -> büyükbaba
# NP -> kanama
# NP -> puan
# VP -> çoğal
# NP -> süt
# NP -> sefalet
# NP -> kart
# VP -> asistan
# NP -> realite
# NP -> bağnaz
# NP -> kayak
# NP -> tarikat
# NP -> bide
# NP -> sakınca
# NP -> mil
# NP -> nişan
# NP -> rejim
# VP -> tedarikçi
# NUM -> 1.7
# NP -> talimat
# VP -> yaygınlaş
# NUM -> 27.5
# NP -> gsmh
# NP -> vasıta
# VP -> yara
# VP -> yık
# NP -> 0.0015
# NP -> 3/4'den
# NP -> sözleş
# NP -> itibar
# NP -> ruhsat
# NP -> öncü
# NP -> zig-zag
# NP -> dolgu
# NP -> çukur
# NP -> siyaset
# NP -> hububat
# NP -> işbaş
# NP -> tonlamam
# NP -> tezgah
# NP -> potansiyel
# NP -> ,devlet
# NP -> feminist
# VP -> eğ
# NP -> 186
# NP -> vuruş''
# NUM -> 300
# NP -> tarihçi
# VP -> kap
# VP -> abart
# NP -> 209.000'lik
# NP -> lirizm
# NP -> lokma
# VP -> otomobil
# NP -> hırs
# NP -> hizmetçi
# NP -> istatiksel
# NP -> alsatçılar
# NP -> artist
# NP -> lüks
# VP -> ebeveyn
# NP -> kupon
# NP -> kamp
# NP -> limited
# NP -> hobi
# NP -> sulh
# NP -> ediyor:
# NP -> minibüs
# NP -> alsatlarından
# NP -> eleştirmen
# NP -> köpek
# VP -> sözleşme
# NP -> charter
# NP -> troleybüs
# NP -> irrasyonel
# VP -> gözük
# VP -> müşavir
# NP -> kaygılan
# NP -> dekor
# VP -> um
# NP -> akademisyen
# NP -> perestroikanın
# NP -> ihsan
# VP -> ıskala
# NP -> demokrat
# NP -> durakla
# VP -> ulaş
# NP -> aktör
# NP -> %8-10
# NP -> şarkıcı
# NP -> sız
# NP -> solucan
# NP -> sevk
# NP -> ısı
# NP -> mükellefiyet
# NP -> hasar
# NP -> ceo
# NUM -> 170
# VP -> rekabetçi
# NP -> telif
# NP -> ortada
# NP -> komşu
# NP -> statü
# NP -> tescil
# NP -> koyun
# NP -> general
# NP -> heyecan
# NP -> yasama
# NP -> kabin
# NP -> açıklık
# VP -> bar
# NP -> cilveleş
# NP -> işletim
# NP -> gidişat
# NP -> 215.86
# NUM -> 40
# NP -> önder
# VP -> eleştir
# VP -> atlat
# VP -> değer
# NP -> kürsü
# VP -> tep
# VP -> halk
# NP -> gecelik
# VP -> zorun
# NP -> inch
# NP -> üreme
# NP -> sansasyon
# NP -> ıskonto
# NP -> roket
# VP -> frank
# NP -> jenerik
# NP -> fiş
# VP -> yaz
# NP -> takviye
# NP -> langırt
# NP -> şikayetçi
# NP -> aynısı
# NP -> kanaat
# NP -> saksı
# NP -> psikanalist
# NP -> fil
# NP -> di
# VP -> sürpriz
# NP -> 4348
# NP -> akım
# NP -> yüklenim
# NP -> 2.çeyrekte
# NP -> hemoroit
# NP -> dünya
# VP -> sefer
# NP -> çıkış
# VP -> düzey
# NP -> 19/32
# NP -> denek
# NP -> konsolidasyon
# VP -> sürdür
# NP -> kredi
# NP -> kalem
# VP -> zorunlu
# VP -> iste
# NP -> alım-satımcıların
# NP -> erkek
# NP -> sıkışık
# NP -> pist
# NP -> etkin
# NP -> solist
# NP -> petrol-hizmeti
# NP -> 11/2
# NP -> 4.çeyrekte
# NP -> mezarlık
# NP -> tahta
# NP -> genelle
# VP -> ülke
# NP -> sürerlik
# NP -> stok
# NP -> yazıl
# NP -> mikro
# VP -> öğren
# NP -> pazartesi
# NP -> 5.86
# NP -> birleşik
# NP -> delta
# NP -> lazer
# NP -> başkaldırı
# NP -> eşik
# NP -> %8'inden
# NP -> fotoğrafçı
# NP -> 1950
# NP -> sabah
# NP -> handikap
# NP -> kriptografisi
# NP -> vazo
# NP -> edilmememesi
# NP -> bilgilendirme
# NP -> mesaj
# NP -> tedarik
# NP -> tane
# NP -> 215.35'de
# NP -> nbc
# NP -> rehber
# NP -> elmas
# NP -> bilek
# NP -> taşikardi
# NP -> deprem
# NP -> şöhret
# VP -> karşıla
# NP -> dram
# NP -> eğim
# NP -> jour
# NP -> entelektüel
# NP -> icra
# NP -> fizik
# NP -> sedir
# NP -> itimatname
# VP -> betimle
# VP -> kayyum
# NUM -> 4.3
# VP -> gez
# VP -> yorumcu
# NP -> süspansiyon
# NP -> fasulye
# NP -> karartı
# NP -> fast-food
# NP -> ağustos
# NP -> dikim
# NP -> yenilikçi
# VP -> hatıra
# NP -> okuyucu
# NP -> konik
# NP -> brifing
# NP -> marka
# VP -> hükmet
# NP -> öğrenci
# NP -> iyidir.
# VP -> bölün
# NP -> pasta
# NP -> sicilya
# VP -> uyarla
# NP -> kraliçe
# NUM -> 1906
# NP -> buz
# NP -> günlük
# NP -> alternatif
# NP -> mini-bileşen
# NP -> mülakat
# VP -> sakla
# NP -> 1/4-1/2
# VP -> öfke
# NP -> sokak
# NP -> mimar
# NP -> teleferik
# NP -> aleyhtar
# NP -> yumuşama
# VP -> seviye
# NP -> paladyum
# NP -> avcı
# NP -> rehine
# VP -> eğilim
# NP -> nane
# VP -> segment
# VP -> kaz
# VP -> yönlendir
# NP -> edepsiz
# NP -> altı-maçlık
# NP -> üç-a
# NP -> şekilde.
# NP -> ustabaş
# NP -> reseptör
# NP -> tazminat
# VP -> dolu
# NP -> dosya
# NP -> yemin
# NP -> pazarlık
# NP -> soya
# VP -> yararlan
# NP -> pound
# NP -> kooperatif
# NUM -> 1.75
# NP -> megabillion
# NP -> balta
# NP -> milyoner
# NP -> meyve
# NP -> jigolo
# NP -> 131.34'de
# NUM -> 85
# NP -> eşya
# NP -> skandal
# NP -> suç
# NP -> gözetmen
# VP -> kur
# NP -> idam
# NP -> teknoloji
# NUM -> 2643.65
# NP -> v.
# NP -> bileşen
# NP -> %3.6'sını
# NP -> tv
# NP -> düşman
# NP -> rönesans
# VP -> rekor
# NP -> protestocu
# NP -> korumacılık
# NP -> teklifçileri
# NP -> materyal
# VP -> haber
# NP -> montaj
# NP -> buzdolabı
# NP -> elektro
# NP -> komutan
# NP -> bayrak
# NP -> %2.52'lik
# NP -> katılmadı.
# NP -> dramatize
# VP -> ata
# NP -> soyad
# NP -> ilga
# NP -> nahoş
# NP -> kıvılcım
# VP -> devret
# NP -> genişmeme
# NP -> oluşturdu.
# NP -> ödün
# NP -> prodüktör
# VP -> gerçek
# VP -> faktör
# NP -> tatminkar
# VP -> gerçekleş
# VP -> dahil
# NP -> 7580
# NP -> bulak
# NP -> %7.8
# VP -> çözül
# NP -> sap
# NP -> tirat
# NP -> revaç
# NP -> saygısızlık
# NP -> çizgi
# NP -> faydalanma
# NP -> leasing
# NP -> buyout
# NP -> ilave
# NUM -> 81
# NP -> abartma
# NP -> 3363949
# NP -> jonron
# NP -> nüfus-kontrolü
# NP -> sendika
# NP -> idare
# NP -> amca
# NP -> ozon
# NP -> parmaklık
# NP -> donanma
# NUM -> 4.8
# NP -> hareket
# NP -> demirbaş
# NP -> açıklama
# NP -> yolculuk
# NP -> safra
# NP -> ehil
# NP -> rüya
# NP -> rezillik
# NP -> amiral
# NP -> makara
# VP -> sür
# NP -> güçlük
# NP -> tela
# VP -> ucuz
# NP -> karat
# NP -> aygıt
# NP -> vitrin
# VP -> kaçır
# NUM -> 500
# NP -> dolay
# NP -> düşünme
# NP -> ziyaret
# NP -> farmasötik
# NP -> yumuşaklık
# NP -> detay
# NP -> sürücü
# NP -> 1141
# NP -> uyku
# NP -> bütünlük
# NP -> masa
# NP -> tedariğine
# NP -> meşguldu
# NP -> fast-food'un
# NP -> ithal
# VP -> şok
# VP -> dinle
# NP -> %15
# NP -> birleşim
# NP -> fiyat-seviyesi
# NP -> protesto
# NP -> fin
# NP -> vali
# NP -> kepek
# VP -> hal
# NP -> yozlaşma
# NP -> %6'nın
# NP -> defa
# NP -> takipçi
# NP -> efor
# NP -> standart
# NP -> 129.90
# NP -> aşk
# VP -> içeri
# NUM -> 1986
# NP -> karın
# NP -> karşılaştırma
# NP -> destekleme
# NP -> yen'den
# NP -> bank
# NP -> eczacı
# NUM -> 107
# NP -> tüp
# NP -> oyuncu
# NP -> single-b-2
# NP -> tatmin
# NP -> mısır
# VP -> sık
# VP -> maaş
# NP -> yengeç
# NP -> yükseltil
# NUM -> 6.4
# NP -> piyango
# VP -> kurtar
# NP -> talih
# VP -> opsiyon
# VP -> cevapla
# VP -> öldür
# NUM -> 95
# NP -> etek
# NP -> devre
# NP -> trajedi
# NP -> iğne
# NP -> halükarda
# NP -> kaolin
# NP -> belirsizlik
# VP -> alan
# NP -> icat
# NP -> villa
# NP -> boşan
# NP -> tümsek
# NP -> dek
# NP -> konut
# NP -> çürüt
# NP -> öksürük
# NP -> ten
# NP -> lisans
# NP -> vuruşçusunun
# NP -> ulaştırma
# NP -> abone
# NP -> bürokrat
# VP -> yayın
# NP -> küme
# NP -> alım-satımlarda
# NUM -> 3\/4
# NP -> kafes
# NP -> olumsuz
# NP -> tadilat
# NUM -> 1.05
# NP -> alevlen
# NP -> ünlü
# NP -> ortodoks
# NP -> tüyo
# NP -> bakkal
# NP -> kızgın
# NP -> inanç
# NP -> otomatik-kotasyon
# NP -> tahkikat
# NP -> garaj
# NP -> çöplük
# NP -> karşılık
# NP -> acınası
# NP -> megabit
# NP -> tıpın
# NP -> kadı
# NP -> mesele
# NP -> deyim
# VP -> güzel
# NP -> tehvili
# VP -> sars
# NP -> kuşak
# NP -> ab
# VP -> çeşit
# NP -> istikrar
# VP -> çalış
# VP -> hak
# NP -> leş
# NP -> karışım
# NP -> yasak
# NP -> yurtdışına
# NP -> düşürül
# VP -> katolik
# NP -> söğüş
# NP -> halı
# NP -> çeşitlilik
# NP -> vaka
# VP -> araştır
# NP -> etme
# NP -> otantik
# NP -> ipuc
# NP -> içme
# NP -> damlalık
# VP -> canlan
# NP -> omuz
# NP -> rastlantı
# NP -> ün
# NP -> maraton
# NP -> spiker
# VP -> ağırlık
# VP -> döndür
# NP -> imge
# NP -> mikroişlemci
# NP -> kartpostal
# NP -> kader
# NP -> ödememe
# NP -> yapımcılık
# NP -> macun
# NP -> görüntü
# VP -> şükret
# NP -> şamdan
# NP -> tanrı
# NP -> 1772.6
# VP -> bağla
# NP -> atıştırmalık
# NP -> zırh
# NP -> yönlü
# NP -> demir
# NP -> %23'ünü
# NP -> işbirliğ
# NP -> %4.5'lik
# NP -> şaka
# NP -> afet
# VP -> sallan
# NP -> fıstık
# NP -> 4.çeyrek
# NP -> kahve
# NP -> kartel
# VP -> destekle
# NP -> fiyatlandırma
# NP -> stagflasyon
# NP -> barış
# NP -> pico
# NP -> misafir
# VP -> vur
# NP -> çatışma
# VP -> sınıf
# NP -> teşebbüs
# VP -> hız
# NP -> ıslah
# VP -> imalatçı
# NP -> sovyet
# VP -> prens
# NP -> denetim
# VP -> düş
# NP -> heyelan
# NP -> ​​meslektaşlarına
# NP -> lira
# VP -> kurumsal
# NP -> antiviral
# NP -> yürüten
# NP -> 1.980
# NP -> çok
# NP -> vari
# NP -> uluslararasılaşma
# NP -> enstitü
# NP -> sakatla
# VP -> makine
# NP -> ilgili
# NP -> mikrop
# NP -> nesnellik
# NP -> final
# NP -> futbol
# NP -> hâla
# VP -> banyo
# NP -> kiracı
# NP -> terim
# VP -> doldur
# NP -> rahat
# VP -> takın
# NP -> yıldız
# NP -> 2660
# NP -> 212.5
# NP -> boyun
# NP -> folkun
# NP -> şebeke
# VP -> fon
# NP -> doktor
# NP -> balık
# NP -> vurucu
# NP -> advancer
# NP -> bourbon
# NP -> tökezle
# NP -> heyet
# NP -> baklagil
# VP -> bozul
# NP -> per
# NP -> fare
# VP -> sorgula
# VP -> ihtiyaç
# NUM -> 35
# NP -> piyasa
# VP -> dök
# NP -> ret
# VP -> biç
# VP -> masraf
# VP -> adam
# NP -> tekrar
# NP -> danışma
# NP -> tanker
# VP -> yapı
# VP -> katıl
# VP -> cumhuriyetçi
# NP -> teklik
# NP -> vadesiz
# NP -> bilgin
# NP -> yetişkin
# NP -> tar
# NP -> çemenotu
# NP -> mega-hisse
# NP -> bilişim
# NP -> hesap
# NP -> idareci
# NP -> devralım
# NP -> resmi
# NP -> stabilize
# NP -> süreliğine
# NP -> hasatı
# NP -> patinaj
# NP -> tan
# NP -> istasyon
# NP -> anlama
# VP -> azalt
# NP -> sepet
# NP -> plaka
# VP -> suçla
# NP -> ayıkla
# NP -> bilanço
# NP -> posta
# VP -> bas
# VP -> atış
# NP -> kaçakçı
# NP -> cuma
# NP -> gayret
# VP -> yenileş
# NP -> jilet
# NP -> sözlük
# NP -> sever
# NP -> kabile
# NP -> açgözlülük
# NP -> aylaklık
# NP -> 662
# VP -> din
# NP -> toplanan
# VP -> ayrım
# NP -> pezo
# NP -> parti
# NP -> eleman
# NP -> torun
# NP -> dizüstü
# NP -> 7.96
# NP -> edinim
# NUM -> 14
# NP -> motosiklet
# NP -> marksist
# NP -> dalgakıran
# NP -> ocak
# NP -> mütabakat
# NP -> bülten
# NP -> sevgi
# NP -> evlilik
# NP -> şasi
# NP -> 458.32'e
# NP -> fraksiyonel
# NP -> biyoteknoloji
# NP -> ödenme
# NP -> manastır
# NP -> irtibat
# NP -> finansçıları
# NP -> talep
# NP -> makul
# NP -> eş
# NP -> araştırma
# NP -> franchising
# NP -> gol
# NP -> somun
# NP -> teşkilat
# NP -> \
# NP -> tercih
# NP -> suikast
# NP -> şov
# NP -> şehire
# NP -> lok
# VP -> gözlemle
# NP -> 216.74'de
# NP -> hukuk
# NP -> arsa
# NP -> duvar
# NP -> 1.125$
# NP -> rahatsızlık
# NP -> ihraç
# NP -> testere
# NP -> dedektör
# NP -> hafriyat
# VP -> karala
# NP -> peş
# NP -> ,viroqua
# NP -> çanta
# NP -> klip
# VP -> tamam
# NP -> beta
# NP -> dayanak
# NP -> söylem
# NP -> kuş
# NP -> randevu
# VP -> ilişki
# NP -> kumla
# NP -> 88.100.000
# NP -> tasarım
# NP -> manşon
# NP -> kamyon
# NP -> volatiliteden
# NP -> 1,100
# NP -> cumartesi
# VP -> kaydet
# NP -> 65-gün
# NP -> bugün
# NP -> koruyuculuk
# VP -> inan
# VP -> yarar
# NP -> hindistanlı
# NP -> sıvılaş
# NP -> teminatçıya
# NUM -> 42
# VP -> uyan
# NP -> doksan
# NP -> mahkeme
# VP -> üret
# VP -> kuruluş
# NP -> teselli
# VP -> olabilir
# NP -> doğu
# NP -> başarızlığına
# NP -> finansman
# NP -> yanlış?
# NP -> temerrütünü
# NP -> terör
# NP -> bulantı
# NP -> şemsiye
# NP -> turna
# NP -> iade
# NP -> dispaşörleri
# NP -> perakendecilik
# NP -> takıl
# NP -> vakit
# NP -> 1930
# NP -> d
# NP -> şampanya
# NP -> pekiştir
# NP -> 3/4'de
# VP -> dolar
# NP -> aktivite
# NP -> favori
# NP -> nesil
# NUM -> dört
# NP -> kriter
# NP -> mentor
# NP -> arena
# NP -> dei
# NP -> kaydadeğer
# VP -> sendikalaş
# NP -> el
# NP -> gerekçe
# NP -> ayrımcılığın
# NP -> baskıncı
# NP -> deneme
# NP -> şeker
# VP -> ad
# NP -> fenomen
# VP -> tut
# NP -> çarşamba
# NP -> izahname
# VP -> küçük
# NP -> istatistik
# VP -> vazgeç
# NP -> duty-free
# NP -> yükselti
# NP -> dadır
# NP -> rütbe
# NP -> nebze
# NP -> mutabakat
# NP -> sağlık
# VP -> beklenti
# NP -> ülser
# NUM -> 57
# NP -> kasa
# VP -> bakan
# NUM -> 3/8
# VP -> danışman
# NP -> trilyonluk
# NP -> pabuç
# NP -> pastırma
# NP -> kompozit
# NP -> nörolog
# NP -> müdahale
# NP -> $'
# NP -> konkordato
# NP -> kazanç
# NUM -> 5/8
# NP -> %42
# VP -> yayıl
# NP -> yabancılaş
# NP -> servet
# NP -> düşünce
# NP -> kolon
# NP -> özgecilik
# NP -> 3.çeyrek
# NP -> bencillik
# NUM -> 24.4
# NP -> ''erkek
# NP -> 6.45
# VP -> kapa
# VP -> kaçın
# NP -> cıa
# VP -> gerilla
# NP -> spekülatör
# NP -> tarz
# NP -> argüman
# NP -> verdi.
# VP -> ters
# NP -> intikam
# NP -> göğüs
# VP -> girişimci
# VP -> hizmet
# NP -> hoşbeş
# NP -> geri
# NP -> dedektif
# VP -> kalk
# NP -> üniforma
# NP -> kanadalı
# NP -> patron
# NP -> sıra)
# VP -> dol
# VP -> ortaklık
# VP -> baskı
# NP -> uyuşmazlık
# NP -> delesyon
# VP -> eğit
# NP -> star
# NP -> arama
# VP -> aşağıla
# NP -> ruh
# NP -> şubat
# NP -> dostluk
# NP -> bulmaca
# NP -> çay
# NP -> trafik
# NP -> boy
# NP -> işçi
# NP -> ekip
# NP -> erteleme
# VP -> kına
# VP -> kapla
# NP -> bilmiş
# NP -> zor.
# NP -> baron
# NP -> kıyas
# NP -> video
# VP -> parçala
# VP -> canlandır
# NP -> resif
# NP -> tokuşlarını
# VP -> darbe
# NP -> coşku
# NP -> sağduyu
# NP -> gin
# NP -> data
# NP -> merkeziyetçilik
# NP -> devriye
# NP -> fotoğraf
# NP -> koşum
# NP -> kolestrol
# NP -> kaldırım
# NP -> çare
# NP -> yenilgi
# VP -> bay
# NP -> dinozor
# VP -> ol
# VP -> toparla
# NP -> %100
# NP -> dükkan
# NP -> ivme
# NP -> dolarlık
# VP -> bulundur
# NP -> pusula
# NP -> süpermarket
# NP -> 1.012
# NP -> 7.10
# NP -> gemi
# NP -> bakiş
# VP -> azınlık
# NP -> dölle
# NP -> tarım
# NP -> yanıt
# NP -> mektup
# NP -> ilköğretim
# VP -> uzaklaştır
# NP -> koruyucu
# VP -> çekici
# NP -> cüret
# VP -> yüksek
# VP -> parça
# NP -> tren
# NP -> sihir
# NP -> faaliyet
# NUM -> 700
# VP -> çöz
# NP -> depolama
# NP -> hâline
# NP -> müessese
# NP -> taş
# NP -> nerdeyse
# NP -> liste
# NP -> uluslararasılaştırılmasında
# NP -> nesile
# NP -> %0.6'lık
# NP -> kimyager
# NP -> amut
# VP -> güçlen
# NP -> yaratıcılık
# VP -> avukat
# NP -> post
# NP -> volatilitesine
# NP -> 7.875,%
# NP -> kesinti
# NP -> disket
# NP -> döşeme
# NP -> sirenleri
# VP -> düşük
# NP -> savuştur
# NP -> 1,120-806
# NP -> çaba
# NP -> tasdik
# VP -> endişe
# NP -> odeon
# NP -> rezervasyon
# NP -> miting
# NP -> müsteşar
# NP -> mark
# NP -> affet
# NP -> 70.000
# NP -> polis
# NP -> kabine
# NP -> (iki
# NP -> burası
# NP -> yayma
# NP -> şarkı
# NP -> sindir
# NP -> müfettiş
# NP -> kelepirci
# NP -> asansör
# NP -> mühendislik
# NP -> alım-satımda
# NP -> koleksiyon
# NP -> buhar
# VP -> heyecanlan
# NP -> %60'ına
# VP -> otur
# NP -> mentalite
# NP -> haciz
# NP -> sohbet
# NP -> arzu
# NP -> kule
# NP -> iman
# NP -> saat
# NP -> havale
# NP -> pazar
# NP -> daralt
# NP -> %42'sini
# NP -> işyer
# NP -> ima
# NUM -> 459.93
# NP -> promosyon
# NP -> tahribat
# NP -> içki
# NP -> samimiyet
# NP -> sürüm
# NP -> biracılık
# NP -> ban
# NP -> teyit
# NP -> zeka
# NP -> %8.03
# NP -> çerçeve
# NP -> ikraz
# NP -> dördün
# VP -> fiyatlandır
# NP -> şiketleri
# NP -> çevre
# NP -> 1845
# NP -> ıhlamur
# NP -> 3.çeyrekte
# VP -> pozisyon
# NP -> cinnet
# NP -> ilkokul
# NP -> mizah
# NP -> mikro-elektronik
# NP -> projeksiyon
# NP -> keyif
# VP -> zirve
# NP -> kurt
# NP -> uçak-elektronik
# NP -> pc
# NP -> çatlak
# NP -> intex
# NP -> eğitim
# NP -> brokerler
# NP -> 1191.86'de
# NP -> çevrecilik
# NP -> metrik
# NP -> ördek
# NUM -> 2662.91
# VP -> endeks
# NP -> sahne
# NP -> tecavüz
# VP -> ölç
# NP -> 1891
# NP -> feet
# NP -> galibiyet
# NP -> mermer
# NP -> sondajcı
# VP -> bitir
# NP -> had
# NP -> sadaka
# NP -> koçu
# NP -> yaşlı
# NP -> değerlendiyor
# NP -> kalpli
# NP -> sütyen
# NP -> 08:30
# VP -> yetki
# VP -> ilgilen
# NP -> korku
# NP -> alım-satımı
# NP -> kayış
# NP -> prenatal
# NP -> unsur
# NP -> suitlere
# NP -> uzay-bilim
# NP -> telaş
# NP -> termal
# NP -> kırışık
# NP -> dönemeç
# NP -> etiğini
# VP -> dağıtıcı
# NP -> terhis
# NP -> yogi
# NP -> işleme
# NP -> emeklilik
# NP -> portföy
# NP -> yalancı
# NUM -> 69
# NP -> bey
# VP -> konum
# NP -> sayaç
# NP -> mantıksızlık
# VP -> beyaz
# NP -> kese
# VP -> tasarla
# NP -> %70'ini
# NP -> dinamik
# NP -> tanıtım
# NP -> revize
# NP -> açma
# NP -> ferroelektrik
# NP -> öğütücü
# NP -> temsil
# VP -> siyah
# NP -> nesir
# NP -> volatile
# NP -> garantör
# NP -> 1074
# VP -> anlaş
# NP -> iplik
# NP -> kova
# NP -> 44796
# VP -> hissedar
# VP -> yanıl
# NP -> başkent
# NP -> muayene
# VP -> gör
# NP -> laboratuar
# NP -> %10'luk
# NP -> verimsizlik
# NP -> platin
# NP -> diyet
# NP -> kimya
# NP -> katılım
# NP -> esas
# NP -> deklarasyon
# NP -> sos
# NP -> borçlanma
# NP -> ihtiyat
# VP -> mantık
# NP -> parite
# NP -> sosyete
# NP -> zayıflık
# NP -> kambiyo
# VP -> bük
# VP -> borçlan
# NP -> tokat
# NP -> am
# NP -> hamilelik
# NP -> müzisyen
# NP -> tespit
# NP -> hikmet
# NP -> takdir
# NP -> açıkça
# NP -> iktidar
# NP -> efsane
# NP -> soygun
# NP -> kota
# NP -> megabayt
# NP -> teğmen
# VP -> üre
# VP -> az
# NP -> gücü
# VP -> faydalan
# NP -> doğrultu
# NP -> kontrat
# NP -> başka
# NP -> keselen
# NP -> 215.42
# NP -> .'dur
# VP -> şüpheli
# NP -> düzenbaz
# NP -> kovan
# NP -> franchise'larına
# VP -> tekrarla
# NP -> ölçekli
# NP -> tango
# NP -> cinsiyet
# NP -> c-yields
# NP -> numune
# NP -> 27.125$'a
# NP -> kıyamet
# NUM -> 1/2
# NP -> cephanelik
# NP -> manzara
# NP -> paddleball
# NP -> geyiriği
# NP -> son
# NP -> ter
# NP -> ayrılış
# NP -> kırıcı
# NP -> ayrıcalık
# NP -> pürüz
# NP -> lanet-torpido
# NP -> tema
# NUM -> altı
# NP -> 543.5
# NP -> konsensusunun
# NP -> sevinç
# NP -> mayın
# NP -> ameliyat
# NP -> kurnazlık
# VP -> ons
# NUM -> 1989
# NP -> sanatçı
# NP -> listening
# NP -> stimülatörle
# NP -> broker
# NP -> bitki
# VP -> bulgu
# NP -> koç
# NP -> toplam
# VP -> kaynak
# NP -> triphosphorous
# NP -> kez
# NP -> tanıklık
# NP -> tüy
# NP -> kampüs
# VP -> dönem
# NP -> takolarının
# NP -> sabitleş
# NP -> dürtü
# NP -> düzine
# VP -> umut
# VP -> geçmiş
# NP -> sendikasyon
# VP -> paketle
# NP -> abonman
# NP -> seneti
# NP -> katip
# VP -> yeni
# NP -> saygınlık
# VP -> yönetici
# VP -> gergin
# VP -> durgunlaş
# NP -> restorasyon
# NP -> verimlilik
# NP -> yürütme
# VP -> yok
# NP -> boşaltı
# NP -> teçhizat
# NP -> rövanş
# NP -> kabus
# NP -> beysbol
# NP -> benzersiz
# NP -> titanyum
# VP -> engel
# NP -> 1993'de
# NP -> ödenek
# NP -> muhafazakarlık
# NP -> alıcı
# NP -> kristal
# NP -> görünüyor.
# NP -> 1205.01
# VP -> çatırda
# VP -> hüküm
# VP -> paylaş
# VP -> üst
# NP -> konumsal
# NP -> polip
# NP -> deneyimsizlik
# NP -> beş-yıllık
# VP -> banka
# NP -> likit
# NP -> kadeh
# NP -> tabanca
# NP -> kapı
# NP -> mahalle
# NP -> stres
# NP -> tekli
# NP -> newport
# VP -> tak
# NP -> komite
# NP -> sprey
# NP -> temmuz
# NP -> gövde
# NP -> makro-ekonomik
# VP -> raporla
# NP -> anlaşmazlık
# NP -> güvensizlik
# NP -> sunucu
# NP -> filistinli
# NP -> nakit
# NP -> açan
# VP -> beceri
# VP -> sağlam
# NP -> işlem
# NP -> hariç
# NP -> kaçakçılık
# NP -> ayakkabı
# NP -> vize
# NP -> %50'sine
# NP -> glukozu
# NP -> silme
# NP -> kik
# VP -> aciliyet
# NP -> edeme
# NP -> pil
# NP -> saçma
# NP -> idealizm
# NP -> kolej
# NP -> konsunda
# NP -> teşkil
# NP -> 2161.9
# NUM -> 90
# NUM -> 1/4
# NP -> sermaye-kazanç
# NP -> stokunun
# VP -> birleştir
# NP -> kömür
# NP -> avukatlık
# NP -> konsept
# NP -> umur
# VP -> bak
# NP -> kapanış
# VP -> sarsıl
# NP -> 30-hisse
# VP -> yayımcı
# VP -> dik
# NP -> tutma
# NP -> elektronik
# NP -> kârlarının
# NP -> hayat
# NUM -> 3.23
# VP -> onar
# NP -> tersane
# NP -> 7.05
# NP -> cerrah
# NP -> koyucu
# NP -> dizi
# NP -> ekonomist
# VP -> taraftar
# VP -> evril
# VP -> don
# NP -> röportaj
# VP -> külçe
# VP -> art
# NP -> hepatit
# NP -> taşıyıcı
# NP -> masör
# NP -> kanunlaş
# NP -> kamyonet
# VP -> yazar
# NP -> otomotiv-emisyon
# NP -> yahudi
# NP -> nüsha
# NP -> noel
# VP -> yoğunlaş
# NP -> zam
# NUM -> 5\/8
# NUM -> 2009
# NP -> arıza
# NP -> yaran
# NP -> bayan
# NP -> kolektif
# NP -> gümrük
# NP -> taşımacılık
# NP -> %9
# NP -> şantaj
# NP -> vizyon
# NP -> artırım
# VP -> hisset
# VP -> sınırla
# VP -> ara
# NP -> saray
# NP -> glasnost
# VP -> şüphelen
# NP -> banliyö
# NP -> yemlik
# NP -> asimetrik
# NP -> papaz
# NP -> zaaf
# NUM -> 1994
# NP -> barometre
# NP -> vagon
# NP -> başvuru
# VP -> istek
# NUM -> 4/32
# NP -> sözel
# NP -> gayrimenkul
# NP -> biçimlendir
# NP -> atmosfer
# NP -> libre
# NP -> vinç
# NP -> mülk
# NP -> besi
# NP -> 2569.72
# NP -> seyirci
# NP -> yavru
# NP -> kılavuz
# NP -> anavatan
# NP -> kitap
# NP -> doku
# NP -> dolar-yen
# VP -> tepki
# NP -> tayfun
# NP -> maya
# NP -> liberalleş
# NP -> toplama
# NP -> çekirdek
# NP -> reji
# NP -> kaş
# VP -> git
# VP -> savaş
# NP -> arter
# NP -> aracı
# NP -> enfekte
# NP -> istifade
# NP -> 183.467
# NP -> teori
# NP -> çıkma
# VP -> uyum
# NP -> çeyrek
# NP -> %29
# NP -> konsantre
# NP -> 754'den
# VP -> vergi
# NP -> $'dan
# NP -> makiyetlerine
# NP -> diyoruz.
# NP -> alman
# NP -> değişik
# VP -> sorumluluk
# NP -> sosyolog
# NP -> federal
# NP -> oto
# VP -> belirle
# NP -> grev
# NP -> tasarı
# NP -> krema
# NP -> tali
# NP -> ortala
# VP -> aş
# NUM -> 7/8
# NP -> transplanttan
# NP -> kalega
# NP -> finanse
# NP -> disk
# NP -> onur
# NP -> ders
# NP -> verici
# NP -> kariyer
# NP -> emeklilik-
# NP -> filtre
# NP -> asyalı
# NP -> uyuşturucu
# NP -> japonyalı
# NP -> eşitlikçilik
# NP -> tezgahüstü
# NP -> referans
# NP -> guguk
# NP -> fonlamak
# NP -> şimdi
# NP -> şifre
# NP -> monetarist
# NP -> 454.86
# NP -> kirlilik
# VP -> benze
# NP -> dul
# NP -> temiz
# NP -> nakiti
# NP -> supraventriküler
# NP -> hapis
# NUM -> 8.65
# NP -> bursiyer
# NP -> kuyumcu
# NP -> gürültü
# NP -> ağaç
# NP -> sütun
# NP -> bağnazlık
# NP -> gezinti
# NP -> 98523
# NP -> kostüm
# NP -> patlak
# NP -> fakir
# VP -> taban
# VP -> kapsa
# NP -> vakıf
# NP -> cilve
# NP -> şarlatan
# VP -> tutum
# VP -> yığ
# NP -> dağ
# NP -> radar-tehdit
# NP -> nefes
# NP -> yen
# NP -> motif
# VP -> savun
# NP -> temyiz
# NP -> tenor
# NP -> faks
# NP -> simsar
# NP -> lisansladı
# NP -> 1947
# NUM -> 1/8
# NP -> norm
# NP -> yenileme
# NP -> bildirge
# NP -> ateşkes
# NP -> politikacı
# NP -> mahal
# VP -> yayınla
# NP -> korsan
# NP -> demeç
# VP -> tamamla
# NP -> ayrış
# NP -> paket
# NP -> somon
# NP -> turkuaz
# NP -> dönüm
# NP -> yükselme
# NUM -> 15
# NP -> çinli
# NP -> mezun
# VP -> bat
# NP -> iş-yönetim
# NP -> tanık
# NP -> 1199.32
# NP -> avaz
# NP -> kutup
# VP -> istisna
# NP -> kış
# NP -> programcılık
# NP -> ceset
# NP -> yıldırım
# NP -> sermaye
# VP -> kaybol
# NP -> 1975'de
# VP -> politika
# NP -> bağımlılık
# NP -> iletişim
# NP -> piskopos
# VP -> geliş
# NP -> malik
# NP -> motive
# VP -> planla
# NP -> dilekçe
# NP -> sapan
# NP -> bakma
# NP -> diet
# NP -> delin
# NP -> tiryaki
# NP -> kimse
# NP -> 213.97
# NP -> eksiklik
# NP -> damıtıcı
# NP -> kliring
# NP -> 219.19'de
# NUM -> 9
# VP -> emin
# NP -> acenta
# VP -> aktif
# NP -> balon
# NP -> islam
# NP -> mt
# NP -> aldat
# VP -> çıkar
# NP -> 6.kez
# NP -> revak
# NP -> sonuçla
# NP -> çıktı.
# NP -> karşı-devrimci
# VP -> uzunluk
# VP -> kaç
# NP -> cinayet
# NP -> alış-veriş
# NUM -> 12.5
# VP -> onay
# NUM -> 2200
# NP -> piyano
# VP -> araştırmacı
# VP -> kurtul
# NP -> espri
# NP -> ayaklanma
# NP -> 694
# NP -> 35670
# VP -> dön
# NP -> itfa
# NP -> indikatör
# NUM -> 465
# NP -> güncelle
# NP -> p53
# NP -> basit
# NP -> köprü
# VP -> hikaye
# NP -> sertifika
# NP -> baloncu
# NP -> figür
# NP -> hardal
# NP -> ajan
# NP -> varak
# VP -> tüken
# VP -> kışkırt
# NP -> bordro
# NP -> epileptik
# NP -> bağcık
# NP -> kışkırtma
# NP -> single-b
# NP -> manken
# NP -> hissi
# NP -> tel
# VP -> satı
# NP -> yoldaş
# NP -> tahmis
# NP -> diril
# NP -> bayii
# NP -> 130.46
# NP -> tahrip
# NP -> ana
# NP -> postala
# NP -> ünite/birim
# NP -> tasarımcı
# NP -> tekabül
# NP -> batarya
# NP -> fener
# NP -> %10.4
# NP -> lejyon
# VP -> ilet
# NP -> salınım
# NP -> yürürlük
# NP -> ikram
# NP -> kıyafet
# NP -> edebiyat
# VP -> profesyonel
# NP -> neon
# NP -> optik
# NP -> tenis
# NP -> sevkiyat
# VP -> karşı
# NP -> haşere
# NP -> yönelim
# NP -> sızıntı
# NUM -> 240
# VP -> sektör
# NP -> algı
# NP -> çarpı
# NP -> marina
# NP -> tahıl
# VP -> önlem
# VP -> artış
# NP -> nüfuz
# NP -> döngü
# NP -> klor
# NP -> örtü
# NP -> üstat
# NP -> kaldıraç
# NP -> reorganizasyon
# NP -> bahar
# NP -> ünvan
# VP -> önemsen
# NP -> kopuk
# NP -> nezaket
# NP -> lezzet
# NP -> 1974'deydi
# NP -> 1.222
# NP -> azaltım
# NP -> kitapçı
# VP -> başar
# NP -> 40.6
# NP -> hiddet
# NP -> aflatoksin
# NP -> uzmanlık
# NP -> yüksek.
# NP -> hareketlen
# VP -> kaynaklan
# NP -> referandum
# NP -> isabet
# NP -> egzersiz
# NP -> nakliyeci
# NP -> harcama
# VP -> yat
# VP -> aksa
# NP -> ilişkilerinde:
# VP -> dönüş
# NP -> mahsülü
# VP -> bono
# NP -> sabun
# NP -> telafi
# NP -> belirsizdir.
# VP -> böl
# VP -> söz
# NP -> tümor
# NP -> kafeterya
# NP -> traktör
# NP -> ekarte
# VP -> zayıfla
# NP -> kağıt
# NP -> lojistik
# VP -> oyna
# NP -> damızlık
# NP -> kabiliyet
# NP -> bildiri
# NP -> eylem
# NP -> fırlatma
# NP -> telgraf
# NP -> som
# NP -> gözlemci
# VP -> düşür
# NP -> limoni
# NP -> memurluk
# NP -> muhasebe
# NP -> çingene
# NP -> bilinç
# NP -> teneke
# NP -> denetçi
# NP -> masaüstü
# NP -> bezelye
# NP -> 2018
# NP -> arbede
# NP -> konuşmacı
# NUM -> 572
# VP -> sor
# NP -> transitde
# NP -> ithalatçı
# NP -> iptal
# NP -> gözlük
# VP -> net
# VP -> öğe
# NP -> mühimmat
# VP -> sıçra
# NUM -> 12.75
# NP -> 1990-model
# NP -> tutucu
# VP -> işletmeci
# NP -> bağırsak
# NP -> özürlü
# NP -> kaygılı
# NP -> %7.90
# NP -> atari
# NP -> isveçli
# NP -> nakavt
# NP -> yalan
# VP -> yasakla
# VP -> yumuşa
# NP -> %2'dir
# NP -> fast-track
# NP -> gölge
# NP -> kaset
# NP -> çökme
# NP -> ustabaşısı
# NP -> karne
# NP -> parlamento
# NP -> %2'lik
# NP -> seçki
# NP -> kürk
# NP -> yazarlık
# NP -> kadro
# NP -> iz
# NP -> konyak
# NP -> meditasyon
# VP -> değiştir
# NUM -> ı
# NP -> yapılanma
# VP -> davran
# NP -> doğurganlık
# VP -> sendele
# VP -> ateşle
# NP -> 4.375'den
# NP -> güruh
# NP -> 34.25$'den
# NP -> burger
# NP -> lakap
# NP -> $'lık
# NP -> %8.21
# NP -> rafine-petrol
# VP -> borç
# NP -> şık
# NP -> mikroskop
# NP -> paranın-çalışması
# NP -> meşruiyet
# NUM -> 400
# NP -> bankacı
# NP -> şüpheci
# VP -> kütüphane
# NP -> yerleşimcinin
# NP -> boyama
# VP -> onayla
# NP -> megawattlık
# NP -> mülteci
# NP -> lego
# NP -> çamaşır
# NP -> tehlikeli
# NP -> deccal
# NP -> katot
# NP -> müze
# NP -> hakimiyet
# NP -> grup'un
# NP -> gözardı
# VP -> merkez
# NP -> fan
# NP -> işlemci
# NP -> çayır
# NP -> `stay
# NP -> karakter
# NP -> kurma
# NP -> hasta
# NP -> uyaran
# NP -> veteriner
# VP -> düzenle
# NUM -> 1962
# NP -> tröst
# NP -> red
# NP -> litre
# NP -> çürü
# NP -> merhamet
# NP -> güreşçi
# NP -> sine
# NP -> ilerleyici
# NP -> .'dır
# VP -> geçerli
# NP -> anket
# NP -> 1970'de
# VP -> artır
# NP -> sermayedar
# NP -> tohum
# NP -> veto
# NP -> tik
# VP -> cihaz
# NP -> 9.62
# NP -> yayılım
# NP -> 1974-75'de
# NP -> şampuan
# NP -> tahliye
# VP -> kıyasla
# NP -> doyur
# NP -> finasman
# NP -> 130.13
# NUM -> 89
# VP -> titre
# NP -> infilakın
# NP -> koridor
# NP -> çizim
# NP -> komunist
# NP -> flaş
# VP -> gün
# VP -> salla
# NP -> arbs'in
# NP -> kamçı
# NP -> mühürle
# NP -> bakanlık
# NP -> demet
# VP -> ilgi
# VP -> in
# NP -> group
# NP -> kapitalizm
# NP -> 100-pay
# NUM -> 1960
# VP -> kabullen
# NP -> anti-kanser
# VP -> sıkıştır
# NP -> dağılma
# NP -> fişek
# NP -> kabartı
# NP -> tur
# NP -> netice
# NP -> beyin
# NP -> sorumsuzluk
# NP -> caydırıcı
# NP -> duayen
# NP -> z
# VP -> yakala
# NP -> suistimal
# NP -> çadır
# NP -> alarm
# NP -> etkileşim
# NP -> budak
# NP -> bütünleş
# NUM -> 66
# NP -> farz
# NP -> davranış
# NP -> içtihat
# NP -> beri
# NP -> faiz
# NP -> maliyet
# VP -> tanımla
# NUM -> 24
# NP -> döner
# NP -> vizon
# VP -> ipotek
# NP -> cümle
# NP -> herkes
# NP -> kalite
# VP -> etki
# NP -> farklılık
# NP -> etkinlik
# NP -> %40'ını
# NP -> neti
# NP -> stajyer
# NP -> dönemki
# NP -> istifa
# NP -> öncelik
# NP -> ahır
# NP -> veritaban
# NUM -> 11
# NP -> sebep:
# VP -> üzer
# VP -> ora
# NP -> yıkım
# NP -> sorumlu
# NP -> vade
# NP -> terk
# NP -> %11.1'ini
# NP -> 8:
# NP -> seks
# NP -> spekülasyon
# NP -> stop-ödeme
# NP -> kaplumbağa
# NP -> simülatör
# NP -> çığlık
# NP -> müzakelererin
# NP -> gayrimenkullerde
# NP -> bardak
# NP -> madenci
# VP -> sirkülasyon
# NP -> şirletler
# NUM -> 1979
# VP -> düzel
# NP -> multimedya
# NP -> erkek-kısır
# VP -> geç
# NP -> monolitlerin
# NP -> 3500
# NP -> dengesizlik
# NP -> utangaç
# NP -> mütevelli
# NP -> yakıt
# NP -> oil
# NP -> fırçala
# NP -> terzilik
# NP -> metanollu
# NP -> yuva
# NP -> öden
# NP -> muhalafeti
# NP -> şalo
# NP -> görgü
# NP -> sancak
# NP -> muadillerinden
# NP -> atık
# NP -> 1263.51
# NP -> çevreci
# NP -> operatif
# NP -> kural
# NP -> spektaküler
# NP -> olimpiyat
# VP -> panik
# NUM -> 6.5
# NP -> /4
# NP -> bowling
# VP -> oku
# VP -> takas
# VP -> yargıç
# NP -> müsrif
# VP -> yıllık
# NP -> 8,000
# NP -> kargaşa
# NP -> isyancı
# NP -> güreş
# VP -> ay
# NP -> yön
# NP -> toprak
# NP -> kasvet
# NP -> hakkımızdaki
# NP -> bilmiyorlar.
# NP -> bayıl
# NUM -> 1988
# NP -> sağ
# VP -> hatırla
# NP -> desen
# VP -> distribütör
# NP -> dezavantaj
# NP -> 2596.72
# NP -> tarafsız
# NP -> müzik
# NP -> tip
# NP -> deflatör
# NP -> çekim
# NP -> aciz
# NP -> sosyal
# NP -> opec
# NP -> alev
# VP -> atan
# NP -> mikroskobik
# NP -> çizelge
# NP -> puro
# NP -> stratosferik
# NP -> revizyon
# VP -> yapımcı
# NP -> ört
# VP -> kuvvet
# NUM -> 1987
# NP -> es
# NP -> yarışma
# NP -> %14.1
# NP -> 1.059.04
# VP -> şekil
# NP -> girişim
# NP -> mevki
# NP -> uyarı
# NP -> gençlik
# NP -> burs
# NP -> hard
# NP -> zafer
# VP -> ben
# NP -> kahraman
# NP -> canlandırma
# NP -> milyonlarca
# NP -> 51-nakit
# NP -> realizasyonları
# VP -> yağ
# NP -> bellek
# NP -> yor
# NP -> vesile
# NP -> göç
# NP -> depozito
# NP -> istihdam
# VP -> gösterge
# NP -> iyileştir
# VP -> aç
# VP -> duyur
# NP -> 13.4
# NUM -> 10.5
# NUM -> 23
# NP -> solo
# NP -> inşaat
# NP -> dondurma
# NP -> gayrimenkullerin
# NP -> kavga
# NP -> aracılık
# NP -> mahkum
# NP -> kavanoz
# NP -> emek-yönetim
# NP -> hidroelektrik
# VP -> süre
# NP -> alışveriş
# NP -> akraba
# VP -> etkile
# NP -> parçalan
# VP -> sök
# NP -> dayanışma
# VP -> bomba
# NP -> fizyoloji
# NP -> çubuk
# NP -> ölçek
# VP -> ertele
# NP -> implant
# NP -> burbon
# NP -> öğle
# NP -> bıçak
# NP -> kapitalist
# NP -> oğul
# NP -> spot
# NP -> ham
# NP -> küresel
# VP -> gel
# VP -> iddia
# NP -> dev
# VP -> teşhis
# NP -> diyabet
# NP -> %0,3
# VP -> şımar
# NP -> doldurma
# VP -> engelle
# NP -> vurul
# NP -> süpervizörleri
# NP -> gizem
# NP -> karmaşa
# NP -> suitinde
# NP -> devam
# NP -> 2149.3
# NP -> enstrüman
# NP -> spor
# NP -> dikte
# NP -> inat
# VP -> çağır
# NP -> fantezi
# VP -> ayrılık
# NP -> deniz
# VP -> yatırım
# NP -> 7.60
# NP -> sıkboğaz
# NUM -> 13/16
# VP -> husus
# NP -> gezi
# NP -> sınıfla
# NP -> özet
# NP -> yonga
# NP -> 'dür
# NP -> mobil
# NP -> 13.000
# NP -> profesör
# NP -> sinyal
# VP -> kuru
# NP -> patlama
# NP -> tomurcuk
# NP -> enkaz
# NP -> yardları
# NP -> nam
# NP -> kuaför
# VP -> amaç
# NP -> 3090
# NP -> piko
# NP -> edep
# NP -> ortalık
# NP -> kamu
# NP -> çölümsü
# NP -> bucak
# NP -> gider
# VP -> uyandır
# NP -> gel-gitlerden
# VP -> tahvil
# NP -> finiş
# NUM -> 2002
# NP -> harç
# NP -> inşa
# NP -> feragat
# NP -> niş
# NP -> eşitlikçiliği
# NP -> domuz
# NUM -> 18
# NP -> kapatma
# NP -> ​​yaptı
# NUM -> on
# NP -> başarısızlık
# NP -> kullanım
# NP -> tören
# NP -> avrupalı
# NP -> yeniyetme
# NP -> verme
# NP -> %26
# NP -> kuyu
# NP -> 455.63
# NP -> ipucu
# NP -> tanıma
# NP -> sırılsıklam
# NP -> banka-dolandırıcılık
# NP -> %6.4'ün
# NP -> şimşek
# NP -> metin
# NP -> reyting
# NP -> 9.5'di
# NP -> stadyum
# NP -> psikobiyoloji
# NP -> çalıntı
# NP -> imalat
# NP -> segman
# VP -> hazırla
# NP -> kasırga
# NP -> memur
# NP -> kapak
# NP -> antreman
# NP -> grafik
# NP -> propan
# NP -> karavan
# NP -> resepsiyon
# NP -> santimetre
# NP -> rekabet
# VP -> yuvarla
# NP -> içim
# NP -> franchiselarını
# NP -> türlü
# NP -> maden
# NP -> -110
# NP -> çarptır
# NP -> atak
# VP -> reform
# NP -> kromozom
# NP -> savunmasızlık
# NP -> soruşturmacı
# NP -> olacak
# NUM -> 32
# NP -> amonyum
# NP -> ölçüm
# NP -> diplomasi
# NP -> kaya
# NP -> %12'si
# NP -> facia
# NP -> yerinde
# NP -> bileşim
# NP -> çarpan
# NP -> maske
# NP -> mat
# NP -> doğa
# NP -> koro
# NP -> tesisat
# VP -> tüket
# NP -> tarama
# NP -> elektrolüminesans
# VP -> karşılaş
# VP -> vurgula
# NP -> kalıntı
# NP -> rafineri
# NP -> yen'lik
# NP -> üretkenlik
# NP -> rodeo
# NP -> demilitarize
# NP -> havalandırma
# VP -> numara
# NP -> akşam
# VP -> hazır
# NP -> yayınev
# NP -> saldırgan
# NP -> seremoni
# NP -> denizaşırı
# NP -> pısırık
# NP -> birikim
# NP -> peşinde
# NP -> seyir
# NP -> 14.560.000
# NP -> temin
# NP -> buzdağ
# NP -> aktarma
# NP -> vergilendirilebilir-eşdeğer
# NP -> gebelik
# NP -> centilmenlik
# NP -> açmaz
# NP -> espiyonaj
# VP -> tanım
# VP -> değiş
# NP -> komut
# NP -> tasavvur
# NP -> imparatorluk
# NP -> renk
# NP -> mega
# VP -> önce
# VP -> fiyat
# NP -> kıymet
# NP -> lig
# NP -> iyilik
# NP -> %5'i
# NP -> gürle
# NP -> verit
# NP -> antifriz
# NUM -> 8.9
# VP -> kültür
# NP -> %25'inin
# NP -> /2
# NP -> tasvir
# NP -> minimal
# NP -> çift-a'
# VP -> dikil
# NP -> şatafat
# NP -> tekstil
# NP -> fırtına
# VP -> çek
# NP -> engelleyici
# VP -> süpür
# VP -> şüphe
# NP -> işgal
# NP -> seyahat
# NP -> genişleme
# NP -> memnuniyet
# VP -> kullan
# NP -> fırın
# NP -> organ
# NP -> buldozer
# VP -> cay
# VP -> üye
# NP -> show
# NP -> stratejist
# NP -> duyduran
# NUM -> 1999
# NP -> tablo
# NP -> deney
# NP -> ayrılma
# NP -> 80,000
# VP -> fatura
# NP -> anı
# NP -> köpekbalık
# NP -> parsel
# NP -> şah
# NP -> kıdem
# NP -> saçmalık
# VP -> getir
# NP -> iletim
# NP -> mutluluk
# NP -> atıcı
# NP -> bisikletçi
# NP -> ettir
# VP -> hafifle
# VP -> görev
# NP -> 463.28
# NP -> gri
# NP -> huylu
# NP -> ova
# NP -> kum
# NP -> çekicilik
# NP -> halef
# NP -> rezerv
# NP -> çanak
# NP -> ustalık
# NP -> şifrele
# NP -> başlık
# NP -> muz
# NP -> kapasitör
# NP -> oşinografik
# NP -> sörfçü
# NP -> editoryal
# NP -> yedekle
# NP -> doğaçlama
# NP -> gönül
# NP -> lansman
# NP -> taklit
# NUM -> 9000
# NP -> kiralama
# VP -> sıfırla
# NP -> anlaşıl
# NP -> 1994'de
# NP -> çalgı
# NP -> iskontalarla
# NP -> kuzey
# NP -> bütçeciler
# NP -> sıçan
# VP -> hayalet
# NP -> zımni
# NP -> hortum
# NP -> yükümlülük
# NP -> elçi
# NP -> akın
# NP -> tahakkuk
# VP -> azal
# NP -> savunmacılarına
# NP -> çimento
# VP -> tedavül
# NP -> ressam
# NP -> pembe
# NP -> tatlılık
# NP -> kod
# NP -> fiyat-bilinçli
# VP -> serp
# NP -> 1507.37
# NUM -> 1992
# NP -> 4400
# VP -> cent
# NP -> ünite/birime
# NP -> açıklanan
# NP -> reasürans
# VP -> sosyalist
# NP -> romancı
# NP -> 1995'de
# NP -> isim
# NP -> pasifize
# NP -> damgala
# NP -> balina
# NP -> gezegen
# NP -> river
# NP -> kravat
# VP -> kat
# NP -> nakarat
# NP -> nisan
# NP -> düzeltme
# NP -> 1o
# NP -> pejmürde
# NP -> portre
# NP -> par
# NP -> ücret
# NP -> talihsizlik
# NP -> 8.35
# NP -> şalter
# NP -> diagnostik
# NP -> popüler
# NP -> kast
# VP -> dengele
# NP -> azalma
# NP -> öneri
# NP -> yandaş
# NP -> entrika
# NP -> toksin
# NP -> takasçı
# NP -> kemik
# NP -> çan
# NP -> biyolojik
# NP -> kurmay
# NP -> %0,9
# NP -> anonim
# NP -> satın
# NP -> saf
# NP -> %8.95'lik
# NP -> seviş
# NP -> peçete
# NP -> %4.35'lik
# NP -> uygunluk
# NP -> watt
# NP -> denizcilik
# NP -> dijital
# NP -> görüyor.
# NP -> öd
# NP -> dörtlü
# NP -> öğretim
# NP -> yalpala
# NP -> yelek
# VP -> kötü
# NP -> cumhuriyet
# NP -> ekim
# NP -> film
# NP -> okyanus
# NP -> rezervuar
# NP -> ticaret
# NP -> petrokimya
# NP -> antlaşma
# NP -> ingiltere
# NP -> manevra
# NP -> acele
# NP -> hammade
# NP -> çarpışma
# NP -> konsey
# NP -> nakliyat
# VP -> uzman
# NP -> cop
# VP -> biz
# VP -> katlan
# VP -> bilin
# VP -> ısın
# VP -> meşgul
# NP -> pazaryer
# NP -> franchise'ın
# NP -> prenses
# NP -> tanış
# NP -> maskele
# ...
# NUM -> 10.3
# NUM -> 59
# NUM -> 130
# NUM -> 4.11
# NUM -> 50.59
# NUM -> 142.85
# NUM -> 1.49
# NUM -> 1961
# NUM -> 6050
# NUM -> ıv
# NUM -> 500.2
# NUM -> 130.76
# NUM -> 2.15
# NUM -> 730070
# NUM -> 9.2
# NUM -> 2683.2
# NUM -> 49000
# NUM -> 25.25
# NUM -> 4.27
# NUM -> 368.24
# NUM -> 184
# NUM -> 143.6
# NUM -> 4.31
# NUM -> 39300
# NUM -> 40.4
# NUM -> 36.6
# NUM -> 14580000
# NUM -> 8.375
# NUM -> 108.4
# NUM -> 11.6
# NUM -> 210
# NUM -> 11.4
# NUM -> 5.37
# NUM -> 20.6
# NUM -> 19.2
# NUM -> 53.9
# NUM -> 148
# NUM -> 30.1
# NUM -> 35.38
# NUM -> 376.36
# NUM -> 2.38
# NUM -> 28.6
# NUM -> 3.68
# NUM -> 40000
# NUM -> 2.87
# NUM -> 94425000
# NUM -> 11.0
# NUM -> 39.19
# NUM -> 691.09
# NUM -> 7.3
# NUM -> 168
# NUM -> 897.2
# NUM -> 0.03
# NUM -> 2.14
# NUM -> 170330000
# NUM -> 552302
# NUM -> 7.12
# NUM -> 986
# NUM -> 1956
# NUM -> 21.6
# NUM -> 295.7
# NUM -> 92.42
# NUM -> 111
# NUM -> 251.2
# NUM -> 1.8578
# NUM -> 11820000
# NUM -> 711.9
# NUM -> 11.8
# NUM -> 54.51
# NUM -> 373.8
# NUM -> 272.0
# NUM -> 47.46
# NUM -> 94.243
# NUM -> 765
# NUM -> 1.603
# NUM -> 2.57
# NUM -> 589
# NUM -> 2210
# NUM -> 487
# NUM -> 30\/32
# NUM -> 9.75
# NUM -> 18.69
# NUM -> 10.2
# NUM -> 29/32
# NUM -> 1.68
# NUM -> 1210.7
# NUM -> 307.2
# NUM -> 108.28
# NUM -> 141.65
# NUM -> 877.6
# NUM -> 63.52
# NUM -> 44.6
# NUM -> 368.15
# NUM -> 275000
# NUM -> 822
# NUM -> 5.04
# NUM -> 601.3
# NUM -> 7.4
# NUM -> 354000
# NUM -> 28.3
# NUM -> 1900
# NUM -> 166.9
# NUM -> 5.8125
# NUM -> 43.3
# NUM -> 145
# NUM -> 8.32
# NUM -> 92
# NUM -> 8.38
# NUM -> 27.0
# NUM -> 80000
# NUM -> 35587.85
# NUM -> 2.69
# NUM -> 407
# NUM -> 488
# NUM -> 914
# NUM -> 448
# NUM -> 101.98
# NUM -> 16.1
# NUM -> 1.54
# NUM -> 220
# NUM -> 925
# NUM -> 75.2
# NUM -> 191.1
# NUM -> 12283217
# NUM -> 8.62
# NUM -> 415
# NUM -> 0.45
# NUM -> 58.97
# NUM -> 99.14
# NUM -> 99.23
# NUM -> 185
# NUM -> 108625
# NUM -> 141.52
# NUM -> 0.53
# NUM -> 309381
# NUM -> 730
# NUM -> 44.125
# NUM -> 5088774
# NUM -> 433.5
# NUM -> 8.7
# NUM -> 2.21
# NUM -> 20.125
# NUM -> 257.8
# NUM -> 190
# NUM -> 5.94
# NUM -> 100.8
# NUM -> 423
# NUM -> 456.2
# NUM -> 176.7
# NUM -> 643.4
# NUM -> 97.85
# NUM -> 8.22
# NUM -> 117.94
# NUM -> 6.07
# NUM -> 4.75
# NUM -> 6.95
# NUM -> 195.19
# NUM -> 884
# NUM -> 7.81
# NUM -> 1.5885
# NUM -> 112
# NUM -> 21.4
# NUM -> 1.6145
# NUM -> 425000
# NUM -> 1701.7
# NUM -> 31000
# NUM -> 7.2
# NUM -> 626.3
# NUM -> 1920
# NUM -> 663
# NUM -> 780
# NUM -> 25.875
# NUM -> 747
# NUM -> 4.12
# NUM -> 0.44
# NUM -> 3481887
# NUM -> 283.2
# NUM -> 344.354
# NUM -> 499.4
# NUM -> 575000
# NUM -> 1610
# NUM -> 11.9
# NUM -> 2.73
# NUM -> 76.4
# NUM -> 4.9
# NUM -> 1070000
# NUM -> 9756
# NUM -> 25.78
# NUM -> 1.85
# NUM -> 13.02
# NUM -> 3.16
# NUM -> 18.7
# NUM -> 8590
# NUM -> 376000
# NUM -> 155.0
# NUM -> 0.39
# NUM -> 19395
# NUM -> 155650000
# NUM -> 12.9375
# NUM -> 13/32
# NUM -> 2600
# NUM -> 1.37
# NUM -> 14.95
# NUM -> 9.76
# NUM -> 784.5
# NUM -> 245.3
# NUM -> 0.23
# NUM -> 654.5
# NUM -> 41.2
# NUM -> 3426.33
# NUM -> 75.5
# NUM -> 3.55
# NUM -> 930
# NUM -> 673
# NUM -> 678
# NUM -> 177
# NUM -> 6.19
# NUM -> 33270
# NUM -> 9.3
# NUM -> 6500000
# NUM -> 25.8
# NUM -> 51
# NUM -> 785
# NUM -> 9.81
# NUM -> 540.9
# NUM -> 10.7
# NUM -> 36.125
# NUM -> 2.09
# NUM -> 2423.9
# NUM -> 313800
# NUM -> 108
# NUM -> 369000
# NUM -> 353
# NUM -> 192
# NUM -> 57000
# NUM -> 27.8
# NUM -> 452
# NUM -> 44400
# NUM -> 2.63
# NUM -> 194
# NUM -> 8.59
# NUM -> 21.98
# NUM -> 223.3
# NUM -> 14.11
# NUM -> 329.2
# NUM -> 78.64
# NUM -> 3.64
# NUM -> 13.0
# NUM -> 2007
# NUM -> 17.73
# NUM -> 1.2
# NUM -> 161
# NUM -> 39.31
# NUM -> 4.92
# NUM -> 390.5
# NUM -> 53
# NUM -> 2189.7
# NUM -> 2157656
# NUM -> 2600000
# NUM -> 42.25
# NUM -> 34230
# NUM -> 88
# NUM -> 761.38
# NUM -> 10.875
# NUM -> 08:01
# NUM -> 8.07
# NUM -> 26.23
# NUM -> 115
# NUM -> 2.66
# NUM -> 1150000
# NUM -> 12.06
# NUM -> 231
# NUM -> 119.88
# NUM -> 18.5
# NUM -> 52.75
# NUM -> 5.01
# NUM -> 382.9
# NUM -> 179.916
# NUM -> 26.81
# NUM -> 2.8
# NUM -> 10.4
# NUM -> 19.3
# NUM -> 39.68
# NUM -> 368.25
# NUM -> 0.6
# NUM -> 39.5
# NUM -> 515
# NUM -> 25.96
# NUM -> 176100000
# NUM -> 350.0
# NUM -> 35486.38
# NUM -> 103.0
# NUM -> 425
# NUM -> 680
# NUM -> 370.6
# NUM -> 786100
# NUM -> 28.7
# NUM -> 165
# NUM -> 210.2
# NUM -> 2023
# NUM -> 7.84
# NUM -> 31.2
# NUM -> 102.5
# NUM -> 2.79
# NUM -> 1.38
# NUM -> 250000
# NUM -> otuz
# NUM -> 750000
# NUM -> 1.45
# NUM -> 10.35
# NUM -> 461.2
# NUM -> 7.904
# NUM -> 215.48
# NUM -> 30.88
# NUM -> 21.25
# NUM -> 335.7
# NUM -> 17.92
# NUM -> 774000
# NUM -> 158
# NUM -> 19.51
# NUM -> 19.93
# NUM -> 114
# NUM -> 446.5
# NUM -> ııı
# NUM -> 2.61
# NUM -> 234
# NUM -> 22.3
# NUM -> 28.0
# NUM -> 117.2
# NUM -> 142.25
# NUM -> 155
# NUM -> 148.85
# NUM -> 153
# NUM -> 89.75
# NUM -> 1247.87
# NUM -> 130000
# NUM -> 87.37
# NUM -> 1.02
# NUM -> 6.94
# NUM -> 44877
# NUM -> 814000
# NUM -> 505
# NUM -> 38000
# NUM -> 9.78
# NUM -> 129.6
# NUM -> 6.8
# NUM -> 517500
# NUM -> yedinci
# NUM -> 16800000
# NUM -> 462.9
# NUM -> 3.54
# NUM -> 0.1
# NUM -> 4.22
# NUM -> 0.71
# NUM -> 25000
# NUM -> 3377.43
# NUM -> 8.81
# NUM -> 329600
# NUM -> 1.0
# NUM -> 1.8667
# NUM -> 6.31
# NUM -> 216.49
# NUM -> 129.38
# NUM -> 2.1
# NUM -> 497.1
# NUM -> 2387226
# NUM -> 904000
# NUM -> 402.7
# NUM -> 6.52
# NUM -> 17.375
# NUM -> 1.62
# NUM -> 195.4
# NUM -> 501.61
# NUM -> 83
# NUM -> 702.4
# NUM -> 18.0
# NUM -> 265.79
# NUM -> 13.32
# NUM -> 251.8
# NUM -> 7\/16
# NUM -> 12.9
# NUM -> 528.4
# NUM -> 14.85
# NUM -> 1435
# NUM -> 476.5
# NUM -> 7\/32
# NUM -> 428000
# NUM -> 0.35
# NUM -> 22.125
# NUM -> 11:54
# NUM -> 103
# NUM -> 1.73
# NUM -> 191.75
# NUM -> 320
# NUM -> 145.45
# NUM -> 22.8
# NUM -> 378.87
# NUM -> 26.1
# NUM -> 371.1
# NUM -> 1.4
# NUM -> 50.875
# NUM -> 87.1
# NUM -> 111.2
# NUM -> 22.6
# NUM -> 2117.1
# NUM -> 1.8485
# NUM -> 73
# NUM -> 180000
# NUM -> 4000
# NUM -> 370
# NUM -> 32.7
# NUM -> 410.5
# NUM -> 470.8
# NUM -> 8.05
# NUM -> 2.59
# NUM -> 291.6
# NUM -> 7.73
# NUM -> 36.13
# NUM -> 160
# NUM -> 56.9
# NUM -> 135.9
# NUM -> 91.21
# NUM -> 6727042
# NUM -> 42.7
# NUM -> 950
# NUM -> 30.6
# NUM -> 19.7
# NUM -> 10873
# NUM -> 128
# NUM -> 110
# NUM -> 2.75
# NUM -> 200000
# NUM -> 394.4
# NUM -> 5.9
# NUM -> 918.4
# NUM -> 12.345
# NUM -> 201.2
# NUM -> 5.32
# NUM -> 3.25
# NUM -> 299
# NUM -> 349
# NUM -> 1.01
# NUM -> 40.125
# NUM -> 1380000
# NUM -> 7.51
# NUM -> 256000
# NUM -> 2.68
# NUM -> 1400000
# NUM -> 4.49
# NUM -> 49.0
# NUM -> 58
# NUM -> 3.56
# NUM -> 4.03
# NUM -> 2.125
# NUM -> 200
# NUM -> 395000
# NUM -> 173.5
# NUM -> 2.33
# NUM -> 117
# NUM -> 91/2
# NUM -> 12000
# NUM -> 1.31
# NUM -> 527.39
# NUM -> 12500000
# NUM -> 34996.08
# NUM -> 125075
# NUM -> 2.36
# NUM -> 4.0
# NUM -> 12.05
# NUM -> 2.7
# NUM -> 105.2
# NUM -> 395700
# NUM -> 2100
# NUM -> 293.9
# NUM -> 2052.1
# NUM -> 8.03
# NUM -> 206
# NUM -> 21\/32
# NUM -> 0.06
# NUM -> 336
# NUM -> 2.34
# NUM -> 625.4
# NUM -> 127
# NUM -> 22.61
# NUM -> 15.5
# NUM -> 122.7
# NUM -> 348.2
# NUM -> 24.9
# NUM -> 28.375
# NUM -> 4695
# NUM -> 1035000
# NUM -> 60000
# NUM -> 62.7
# NUM -> 1.06
# NUM -> 24.3
# NUM -> 128.19
# NUM -> 2687.53
# NUM -> 1761.0
# NUM -> 403
# NUM -> 438845
# NUM -> 3.46
# NUM -> 2.9428
# NUM -> 141.7
# NUM -> 5.23
# NUM -> 525000
# NUM -> 452.76
# NUM -> 8.328
# NUM -> 0.51
# NUM -> 5.2
# NUM -> 881969
# NUM -> 734.8
# NUM -> 498
# NUM -> 1.08
# NUM -> 4.35
# NUM -> 78.625
# NUM -> 174.5
# NUM -> 99.385
# NUM -> 415.3
# NUM -> 496
# NUM -> 105.4
# NUM -> 268.6
# NUM -> 81.125
# NUM -> 3.26
# NUM -> 26.9
# NUM -> 1996
# NUM -> 14.44
# NUM -> 126630000
# NUM -> 4.32
# NUM -> 416
# NUM -> 422.1
# NUM -> 351.5
# NUM -> 848.7
# NUM -> 700.0
# NUM -> 13.05
# NUM -> 39
# NUM -> 368.5
# NUM -> 2080
# NUM -> 1.44
# NUM -> 44.3
# NUM -> 813
# NUM -> 502
# NUM -> 204
# NUM -> 394
# NUM -> 62.25
# NUM -> 334.5
# NUM -> 141.9
# NUM -> 12.4
# NUM -> 715.1
# NUM -> 9.8
# NUM -> 35544.87
# NUM -> 2.62
# NUM -> 1425035
# NUM -> 1.26
# NUM -> 12.375
# NUM -> 1214
# NUM -> 20.42
# NUM -> vıı
# NUM -> 2057750000
# NUM -> 4830
# NUM -> 208
# NUM -> 3.53
# NUM -> %
# NUM -> 43.5
# NUM -> 15.625
# NUM -> 613.7
# NUM -> 551
# NUM -> 4.7
# NUM -> 1.8415
# NUM -> 1700
# NUM -> 355
# NUM -> 213
# NUM -> 1.5805
# NUM -> 7.9
# NUM -> 15.6
# NUM -> 1.5795
# NUM -> 32.125
# NUM -> 366.85
# NUM -> 675400000
# NUM -> 6.6
# NUM -> 340.7
# NUM -> 34
# NUM -> 4.97
# NUM -> 0.94
# NUM -> 17:00
# NUM -> 268.98
# NUM -> 1.592
# NUM -> 1.55
# NUM -> 430.3
# NUM -> 518.7
# NUM -> 2.19
# NUM -> 54.875
# NUM -> 2.78
# NUM -> 1.5753
# NUM -> 2170
# NUM -> 8.52
# NUM -> 93.75
# NUM -> 224
# NUM -> 1.39
# NUM -> 380
# NUM -> 3.625
# NUM -> 7.52
# NUM -> 01:20
# NUM -> 247.6
# NUM -> 332.38
# NUM -> 1.5775
# NUM -> 1.81
# NUM -> 21.5
# NUM -> 1.16
# NUM -> 225000
# NUM -> 2015
# NUM -> 11.125
# NUM -> 679.5
# NUM -> 0.004
# NUM -> 8.19
# NUM -> 279.8
# NUM -> 1111
# NUM -> 1848000
# NUM -> 52.1
# NUM -> 1200
# NUM -> 3.48
# NUM -> 104
# NUM -> 33.3
# NUM -> 7.7
# NUM -> 8.56
# NUM -> 486.1
# NUM -> 33.375
# NUM -> 873.9
# NUM -> 16.25
# NUM -> 9.671
# NUM -> 588350000
# NUM -> 1.5
# NUM -> 5600
# NUM -> 466
# NUM -> 6.66
# NUM -> 724.4
# NUM -> 7.62
# NUM -> 25.0
# NUM -> 33
# NUM -> 1.9
# NUM -> 95.2
# NUM -> 26000
# NUM -> 580
# NUM -> 2.77
# NUM -> 64
# NUM -> 191.4
# NUM -> 07:13
# NUM -> 515.1
# NUM -> 3.84
# NUM -> 31.4
# NUM -> 2.45
# NUM -> 13.63
# NUM -> 15000
# NUM -> 0.11
# NUM -> 204.8
# NUM -> 1048500000
# NUM -> 650
# NUM -> 395374
# NUM -> 09:38
# NUM -> 194.0
# NUM -> 135860000
# NUM -> 141.45
# NUM -> 366.55
# NUM -> 3.2
# NUM -> 135.6
# NUM -> 73100
# NUM -> 1/32
# NUM -> 833.6
# NUM -> 110000
# NUM -> 89.6
# NUM -> 50.1
# NUM -> 65.53
# NUM -> 582
# NUM -> 1.69
# NUM -> 111.48
# NUM -> 18.6
# NUM -> 8930000
# NUM -> 2613.73
# NUM -> 3425.22
# NUM -> 300000
# NUM -> 135000
# NUM -> 522.3
# NUM -> 623
# NUM -> 0.8
# NUM -> 36.25
# NUM -> 23.65
# NUM -> 39.55
# NUM -> 4346
# NUM -> 37300
# NUM -> 435
# NUM -> 6.76
# NUM -> 9.87
# NUM -> 331.4
# NUM -> 4.199
# NUM -> 129.97
# NUM -> 4.6875
# NUM -> 175.2
# NUM -> 2.91
# NUM -> 2135.5
# NUM -> 42.455
# NUM -> 2.17
# NUM -> 71.36
# NUM -> 527
# NUM -> 6.84
# NUM -> 44.08
# NUM -> 5.42
# NUM -> 869
# NUM -> 5.1
# NUM -> 4.25
# NUM -> 0.37
# NUM -> 110625
# NUM -> 201
# NUM -> 52.5
# NUM -> 279.39
# NUM -> 278.7
# NUM -> 72.6
# NUM -> 1.59
# NUM -> 4.07
# NUM -> 35.28
# NUM -> 99.1875
# NUM -> 4.6
# NUM -> 3.95
# NUM -> 15.8
# NUM -> 2603.48
# NUM -> 248.3
# NUM -> 10.1
# NUM -> 9232
# NUM -> 2.375
# NUM -> 51.65
# NUM -> 0.36
# NUM -> 190.1
# NUM -> 1976
# NUM -> 43.34
# NUM -> 1.22
# NUM -> 20.375
# NUM -> 5.77
# NUM -> 38
# NUM -> 493
# NUM -> 1.255
# NUM -> 975.0
# NUM -> 1.15
# NUM -> 0.14
# NUM -> 1.83
# NUM -> 50000
# NUM -> 106
# NUM -> 13.15
# NUM -> 38.7
# NUM -> 252
# NUM -> 1.19
# NUM -> 478
# NUM -> 1.72
# NUM -> trilyon
# NUM -> 56
# NUM -> 110.4
# NUM -> 105.39
# NUM -> 57.5
# NUM -> 750
# NUM -> 4.66
# NUM -> 981.2
# NUM -> 249.5
# NUM -> 991
# NUM -> 42.9
# NUM -> 45000
# DET -> birçok
# DET -> her
# DET -> birkaç
# DET -> hiçbir
# ADV -> inatla
# ADV -> kilitlen
# ADV -> öylesine
# ADV -> aniden
# ADV -> şimdilik
# ADV -> özenle
# ADV -> sebepsizce
# ADV -> uğruna
# ADV -> ayrıca
# ADV -> yılla
# ADV -> ansızın
# ADV -> anında
# ADV -> üstünkörü
# ADV -> içinde
# ADV -> sessizce
# ADV -> sayıca
# ADV -> ortalamada
# ADV -> beraberinde
# ADV -> zekice
# ADV -> yukarıdan
# ADV -> ayakta
# ADV -> nihayet
# ADV -> kabaca
# ADV -> nereden
# ADV -> adına
# ADV -> nedeniyle
# ADV -> içtenlikle
# ADV -> muhakkak
# ADV -> bana
# ADV -> vasıtasıyla
# ADV -> günlüğüne
# ADV -> katiyen
# ADV -> yüzünden
# ADV -> yüzden
# ADV -> bıçakla
# ADV -> düpedüz
# ADV -> oradan
# ADV -> resmen
# ADV -> tembelce
# ADV -> bundan
# ADV -> nasılsa
# ADV -> saatlerce
# ADV -> ezbere
# ADV -> apaçık
# ADV -> ölümüne
# ADV -> tamamen
# ADV -> pal
# ADV -> bakarak
# ADV -> peki
# ADV -> dikkatle
# ADV -> pekala
# ADV -> tümüyle
# ADV -> esinlen
# ADV -> günde
# ADV -> çoğunlukla
# ADV -> kıkırda
# ADV -> düşüncesizce
# ADV -> kendince
# ADV -> fazlaca
# ADV -> tıpkı
# ADV -> kabilinden
# ADV -> nadiren
# ADV -> sonradan
# ADV -> memnuniyetle
# ADV -> neredeyse
# ADV -> açıkçası
# ADV -> haftaya
# PRON -> hep
# ADV -> bazen
# ADV -> yıllığına
# ADV -> hâlihazırda
# ADV -> böylece
# ADV -> seneye
# ADV -> belki
# ADV -> halihazırda
# ADV -> ille
# ADV -> böylesine
# ADV -> dikine
# ADV -> epey
# ADV -> kısaca
# ADV -> sertleş
# ADV -> geçenlerde
# ADV -> yakından
# ADV -> yukarıda
# ADV -> genelde
# ADV -> yanlışlıkla
# ADV -> yalnızca
# ADV -> şahsen
# ADV -> şimdiden
# ADV -> titizlikle
# ADV -> bize
# ADV -> elbette
# ADV -> doğrusu
# ADV -> sayesinde
# ADV -> acilen
# ADV -> nispeten
# ADV -> şiddetle
# ADV -> cömertçe
# ADV -> tekrardan
# ADV -> özellikle
# ADV -> asla
# ADV -> yolla
# ADV -> gerçi
# ADV -> sabahleyin
# ADV -> kurnazca
# ADV -> zamanında
# ADV -> kısmen
# ADV -> gitgide
# ADV -> rahatlıkla
# ADV -> ölesiye
# ADV -> ileride
# PP -> hem
# ADV -> sabahları
# ADV -> sırasıyla
# ADV -> iken
# ADV -> yerine
# ADV -> tamamıyla
# ADV -> delir
# ADV -> gerçekte
# ADV -> bayağı
# ADV -> dünyada
# ADV -> galiba
# ADV -> fazlasıyla
# ADV -> gayet
# ADV -> üzerine
# ADV -> aylarca
# ADV -> bakımdan
# ADV -> basitçe
# ADV -> dahası
# ADV -> gizlice
# ADV -> başkaca
# ADV -> aynen
# ADV -> sabaha
# ADV -> nereye
# ADV -> kopar
# ADV -> hükmen
# ADV -> nihayetinde
# ADV -> tahminen
# ADV -> boyuna
# ADV -> derinlemesine
# ADV -> üfle
# ADV -> yürekten
# ADV -> kayıtsızca
# ADV -> aracılığıyla
# ADV -> bunda
# ADV -> yakınlarda
# ADV -> haliyle
# ADV -> derhal
# ADV -> gittikçe
# ADV -> başlangıçta
# ADV -> görünmez
# ADV -> maalesef
# ADV -> detaylı
# ADV -> kısacası
# ADV -> yoluyla
# ADV -> basitleş
# ADV -> nitekim
# PP -> oysa
# ADV -> hafifçe
# ADV -> nezdinde
# ADV -> bizzat
# ADV -> aslen
# ADV -> geceleri
# ADV -> yeniden
# ADV -> oraya
# ADV -> üzerinde
# ADV -> baştan
# ADV -> hâlâ
# ADV -> birdenbire
# ADV -> haksızca
# ADV -> alenen
# ADV -> daha
# ADV -> saatinde
# ADV -> lütfen
# ADV -> sonuçta
# ADV -> zaten
# ADV -> esasen
# ADV -> tesadüfen
# ADV -> yağla
# ADV -> sadece
# ADV -> hayretle
# ADV -> kendiliğinden
# ADV -> böylelikle
# ADV -> yanaş
# ADV -> aralıkta
# ADV -> hızla
# ADV -> illa
# ADV -> sonunda
# ADV -> salt
# ADV -> yeterince
# ADV -> umumiyetle
# ADV -> aksine
# ADV -> öylece
# ADV -> sahiden
# ADV -> başlan
# ADV -> doğrul
# ADV -> öncelikle
# ADV -> eskiden
# ADV -> nerede
# ADV -> keşke
# ADV -> derinden
# ADV -> ardından
# ADV -> tersine
# ADV -> çabucak
# ADV -> sanki
# ADV -> giderek
# ADV -> pek
# ADV -> kasten
# ADV -> bilhassa
# ADV -> burada
# ADV -> birazcık
# ADV -> pahasına
# PP -> ancak
# ADV -> ondan
# ADV -> uyarınca
# ADV -> kesinlikle
# ADV -> zarfında
# ADV -> delikanlı
# ADV -> bakımından
# ADV -> münhasıran
# ADV -> muhtemelen
# ADV -> çoktan
# ADV -> orada
# ADV -> sürekli
# ADV -> sana
# ADV -> hesabına
# ADV -> birden
# ADV -> fiilen
# ADV -> zararına
# ADV -> yanında
# ADV -> genellikle
# ADV -> mutlaka
# ADV -> daima
# ADV -> ustalıkla
# ADV -> direkt
# ADV -> hemen
# ADV -> kaygısızca
# ADV -> çalkala
# ADV -> aslında
# ADV -> şimdilerde
# PP -> hatta
# ADV -> adeta
# ADV -> derhâl
# ADV -> halen
# ADV -> hala
# ADV -> kolaylıkla
# ADV -> çılgınca
# ADV -> iyice
# ADV -> yakında
# ADV -> süresince
# ADV -> çaresizce
# ADV -> yine
# ADV -> gerçekten
# ADV -> önceden
# ADV -> dolayısıyla
# ADV -> ilaveten
# ADV -> işte
# ADV -> ortaklaşa
# ADV -> mesela
# ADV -> henüz
# ADV -> tesadüfi
# ADV -> esnasında
# ADV -> külliyen
# ADV -> oldukça
# ADV -> bugünlerde
# ADV -> kendinden
# ADV -> yavaşça
# ADV -> etraflıca
# PP -> yanısıra
# PP -> nazaran
# PP -> dair
# PP -> takdirde
# PP -> ötürü
# PP -> istinaden
# PP -> evvel
# PP -> göre
# PP -> rağmen
# PP -> boyunca
# PP -> aşkın
# PP -> takiben
# PP -> ile
# PP -> karşın
# PP -> üzere
# PP -> dolayı
# PP -> yana
# PP -> diye
# PRON -> birbiri
# PRON -> sen
# PRON -> hepsi
# PRON -> diğeri
# PRON -> nere
# PRON -> kendi
# PRON -> siz
# PRON -> birbirleri
# PRON -> tümü
# PRON -> hiçbiri
# PP -> olsun
# PP -> ve
# PP -> örneğin
# PP -> gerekse
# PP -> yoksa
# PP -> ama
# PP -> neyse
# PP -> da
# PP -> dahi
# PP -> zira
# PP -> ister
# PP -> çünkü
# INTJ -> ya
# PP -> fakat
# PP -> yani
# PP -> vb
# PP -> ila
# PP -> şayet
# PP -> vs
# PP -> veya
# AUX -> değil
# AUX -> mi
# X -> %3.5
# X -> %7.875
# X -> %8.01
# X -> 21:00-22:30
# X -> %83
# X -> tefek
# X -> %7.986
# X -> %95
# X -> %8.2
# X -> derli
# X -> %17
# X -> 89-107
# X -> @
# X -> %11.3
# X -> %9.5
# X -> allak
# X -> %7.01
# X -> %7.88
# X -> %24
# X -> %6.90
# X -> 2-3
# X -> %9.4
# X -> 3-4
# X -> 1989-86
# X -> 20-21
# X -> %99
# X -> 1989-1
# X -> %61
# X -> %6.8
# X -> 13:30-18:00
# X -> %1.9
# X -> 1989-85
# X -> %9.39
# X -> _
# X -> %14
# X -> 4-5
# X -> %7.10
# X -> %3.4
# X -> %9.90
# X -> %8.61
# X -> %3.846
# X -> %7.53
# X -> 89-136
# X -> %1
# X -> %10.48
# X -> 1997-2000
# X -> 2-23
# X -> %2.9
# X -> 1962-63
# X -> %4.8
# X -> %25
# X -> %6.5
# X -> 1995-1999
# X -> %0.25
# X -> %18
# X -> %3.75
# X -> 1991-1996
# X -> %7.6
# X -> %7.52
# X -> %0.3
# X -> %5.2
# X -> %46
# X -> %10.03
# X -> 5-10
# X -> %7
# X -> %1.4
# X -> %6.4
# X -> %3.43
# X -> 800-900
# X -> %9.6
# X -> %3.9
# X -> %3.1
# X -> 231-191
# X -> %8
# X -> %60
# X -> %65
# X -> %7.92
# X -> %68
# X -> 14-16
# X -> %7.73
# X -> ışıl
# X -> %6
# X -> 22-23
# X -> %69
# X -> %19
# X -> %4.4
# X -> %85
# X -> %27.1
# X -> %3.3
# X -> %3.865
# X -> %44
# X -> 747-400
# X -> %6.15
# X -> %51.4
# X -> 1989-1987
# X -> %99.1875
# X -> %16
# X -> %7.55
# X -> 21-23
# X -> 89-52
# X -> %11
# X -> %2.7
# X -> %3.7
# X -> %9.19
# X -> %8.42
# X -> %0.2
# X -> %7.82
# X -> %5.4
# X -> dobra
# X -> %4
# X -> %8.9
# X -> %1.7
# X -> %2.45
# X -> %36
# X -> %9.617
# X -> %37
# X -> 2003-2005
# X -> 5-12
# X -> 20-23
# X -> %0.32
# X -> %0.5
# X -> tokuş
# X -> 1989-83
# X -> %5.3
# X -> bullak
# X -> 1982-85
# X -> %13
# X -> %7.71
# X -> %22
# X -> %80
# X -> 1989-84
# X -> %2
# X -> %12
# X -> %8.292
# X -> %51
# X -> %7.31
# X -> %7.227
# X -> 1991-1992
# X -> %4.7
# X -> %7.78
# X -> %7.75
# pp -> ki
# INTJ -> oh
# INTJ -> yaşasın
# INTJ -> hadi
# INTJ -> aman
# INTJ -> ah
# INTJ -> e
# INTJ -> haydi
# INTJ -> ha
# INTJ -> vay
# INTJ -> of
# INTJ -> eh

# %%
with open("tr_syntactic_parser/grammar/grammar_all.txt","w", encoding='utf-8') as f:
    f.write(grammar_all)

print("Grammar was saved to :", "tr_syntactic_parser/grammar/grammar_all.txt")
# Out:
# Grammar was saved to : tr_syntactic_parser/grammar/grammar_all.txt

# %% [markdown]
# # TEST

# %%
temp_lexicon = lexicon.copy()

for key in temp_lexicon.keys():
    temp_lexicon[key] = temp_lexicon[key][0:5]

    
temp_lexicon
# Out:
# {'NOUN': ['35-uluslu', 'bakiye', 'amerikalı', 'broncs', 'ikmal'],
#  'PROPN': ["mcdonald's'ın", 'asheville', 'hud', 'marsam', 'cannes'],
#  'VERB': ['çıldır', 'yayın', 'kuvvet', 'bollaş', 'magazin'],
#  'PUNCT': ['-', '…', '$', '”', '?'],
#  'ADJ': ['atomik', 'yayın', 'kuvvet', '1987', 'diplomatik'],
#  'NUM': ['1300000', '8.347', '3\\/4', '1987', '142.75'],
#  'DET': ['bir', 'birçok', 'her', 'birkaç', 'hiçbir'],
#  'ADV': ['kat', 'inatla', 'var', 'karşı', 'dol'],
#  'ADP': ['yanısıra', 'yukarı', 'birlikte', 'nazaran', 'gibi'],
#  'PRON': ['birbiri', 'sen', 'hepsi', 'biz', 'ne'],
#  'CCONJ': ['hem', 'olsun', 'ne', 've', 'örneğin'],
#  'AUX': ['değil', 'mi'],
#  'X': ['%3.5', '%7.875', '%8.01', '21:00-22:30', '%83'],
#  'SCONJ': ['eğer', 'ki'],
#  'INTJ': ['oh', 'yaşasın', 'hadi', 'aman', 'ah']}

# %%
temp = {}
for key,value in lexicon.items():
    for val in value:
        if val in temp.keys(): temp[val].append(key)
        else: temp[val] = [key]

# %%
temp["."]
# Out:
# ['VERB', 'PUNCT']

# %%
import pandas as pd
df = pd.DataFrame({
    "Combined Tags" : list(verb_suff_comb.keys()),
    "Suffixes" : list(verb_suff_comb.values())
})
for i in range(len(df)):
    key = df["Combined Tags"][i]
    if "Past" in key: tense = "PAST"
    elif "Prog" in key: tense = "PRE"
    elif "Fut" in key: tense = "FUT"
    else: continue

    if "1" in key: finalkey = tense+"1"
    elif "2" in key: finalkey = tense+"2"
    elif "3" in key: finalkey = tense+"3"
    else: finalkey = tense+"3"
    
    df.loc[i,"CNF Tag"] = finalkey

# %%
df
# Out:
#      Combined Tags                                           Suffixes CNF Tag
# 0             Past  [ydi, tı, du, tu, ydı, dü, tü, ydu, dı, ydü, d...   PAST3
# 1          NegPast                                       [medi, madı]   PAST3
# 2            Prog1                                  [iyor, ıyor, yor]    PRE1
# 3          FutA1sg                                           [eceğim]    FUT1
# 4         PastA1sg                               [dım, dum, dim, tım]   PAST1
# 5         PastA1pl                                    [dük, dık, dik]   PAST1
# 6              Fut                                            [yecek]    FUT3
# 7   UnablePastA3pl                                         [emediler]   PAST3
# 8           FutCop                                          [ecektir]    FUT3
# 9       NegFutA1pl                                        [meyeceğiz]    FUT1
# 10          NegFut                                 [meyecek, mayacak]    FUT3
# 11    NegProg1A3pl                                         [mıyorlar]    PRE1
# 12        NegProg1                                            [miyor]    PRE1
# 13        PastA3pl                                     [tiler, dılar]   PAST3
# 14         AorPast                                              [rdı]   PAST3
# 15      NegFutA3pl                                       [meyecekler]    FUT3
# 16        Prog2Cop                                         [maktadır]    PRE2
# 17        NarrPast                                     [mişti, mıştı]   PAST3
# 18           Prog2                                            [mekte]    PRE2
# 19        PastA2sg                                              [din]   PAST2
# 20       Prog1Past                                           [iyordu]   PAST1
# 21       Prog1A1sg                                           [ıyorum]    PRE1
# 22        PastA2pl                                            [dunuz]   PAST2
# 23       Prog1A3pl                                  [yorlar, ıyorlar]    PRE1
# 24       Prog1A2sg                                          [ıyorsun]    PRE1
